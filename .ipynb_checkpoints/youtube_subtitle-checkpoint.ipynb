# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
### change the url
# http://video.google.com/timedtext?lang=en&v=
url = requests.get("http://video.google.com/timedtext?lang=en&v=F855i1Tzx_g&index=39&list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI")

# %%
soup = BeautifulSoup(url.text, 'html.parser')
content = soup.findAll('text')

# %%
# creating a dataframe from the content
lines = []
for line in content:
    lines.append(str(line))
    
df = pd.DataFrame(lines)
# Out:
# bs4.element.ResultSet

# %%
# splitting rows
df = pd.DataFrame(df[0].str.split('">',1).tolist(),
                                   columns = ['time','text'])

s = df['time'].apply(lambda x: x.split(' '))
df['start'] = s.apply(lambda x: x[-1])
df['duration'] = s.apply(lambda x: x[1])

df = df.drop(['time'], axis=1)

# %%
df['duration'] = df['duration'].str.replace('dur="','')
df['start'] = df['start'].str.replace('start="','')
df['text'] = df['text'].str.replace('</text>','')
df['duration']= df['duration'].str.replace('"','')
df['text'] = df['text'].str.replace('\n',' ')

# %%
# dataframe sanity check
df
# Out:
#                                                    text     start duration
# 0                Mr. Spicer: Good afternoon, everybody.         0    2.035
# 1                                    Thanks for coming.     2.035    0.867
# 2     Last night, the President was honored to announce     2.902    3.771
# 3     Judge Neil Gorsuch as his nominee to serve as the     6.673    3.103
# 4                    next Justice of the Supreme Court.     9.776    1.501
# 5            It was an unbelievably phenomenal evening.    11.277     2.97
# 6      Immediately after being announced, Judge Gorsuch    14.247    2.402
# 7     was honored to meet with Maureen and Father Sc...    16.649    2.937
# 8          As some of you have reported, his first call    19.586    2.569
# 9     after coming back behind the podium was to Mer...    22.155    2.269
# 10    Garland who had also note, has already come ou...    24.424    2.536
# 11           say Judge Gorsuch deserves a fair hearing.     26.96    2.669
# 12     In less than 24 hours, Judge Gorsuch has already    29.629    2.803
# 13        received a wide-spread praise from across the    32.432    2.269
# 14        political spectrum as an inspired choice with    34.701    3.036
# 15           sterling academic credentials; a brilliant    37.737    3.237
# 16           legal mind; and, a steadfast commitment to    40.974    3.336
# 17                           constitutional principles.     44.31    2.203
# 18      During his long career in public service, Judge    46.513    2.669
# 19             Gorsuch has enjoyed bipartisan approval,    49.182    2.536
# 20            having previously been confirmed by voice    51.718    2.302
# 21                                     vote to the U.S.     54.02    1.402
# 22               Court of Appeals for the 10th Circuit.    55.422    3.203
# 23             In fact, 12 current Democratic senators,    58.625    2.803
# 24    including Minority Leader, Chuck Schumer, Senator    61.428    2.535
# 25    Dianne Feinstein, Senator Leahy were all in of...    63.963    3.337
# 26                  when he was first confirmed without      67.3    2.102
# 27                                  opposition in 2006.    69.402    2.636
# 28        With as many as eight Democrats like, Senator    72.038    2.202
# 29               Blumenthal, Durbin, McCaskill, already     74.24    2.336
# ...                                                 ...       ...      ...
# 1307   General Flynn, when he was up here, offered some  2795.125    1.802
# 1308  criticism about the Obama Administration&amp;#...  2796.927    2.269
# 1309                             of Iran in particular.  2799.196    1.702
# 1310        Is that something we should be expecting to  2800.898    2.002
# 1311      hear more for this administration, whether it    2802.9    1.701
# 1312  be on foreign policy or other issues, criticis...  2804.601    2.469
# 1313             previous administration going forward?   2807.07    3.437
# 1314  Mr. Spicer: I think in areas where there&amp;#...  2810.507    1.769
# 1315  to be a sharp difference, particularly in nati...  2812.276    2.035
# 1316    security, in contrasting the policies that this  2814.311    3.103
# 1317    President is seeking to make the country safer,  2817.414    2.903
# 1318  stronger, more prosperous, he&amp;#39;s going ...  2820.317    2.336
# 1319        distinctions and contrasts out, but in this  2822.653    3.436
# 1320  particular area, I think that the President wh...  2826.089    2.937
# 1321   comes -- came to the Iran nuclear deal was very,  2829.026    3.336
# 1322     very adamant in his opposition to the deal and  2832.362    3.804
# 1323                               to its implications.  2836.166    1.301
# 1324  And so, he&amp;#39;s going to continue to make...  2837.467    2.903
# 1325  the American people know that some of these de...   2840.37    3.904
# 1326    you know, things that were left by the previous  2844.274    2.503
# 1327    administration that he wants to make very clear  2846.777    3.069
# 1328   what his position is and his opposition to them.  2849.846    2.236
# 1329  And you know, the action and the notice that h...  2852.082    2.669
# 1330  Iran on today is something that is important b...  2854.751    4.104
# 1331                  I think the American people voted  2858.855    1.502
# 1332                                   on change again.  2860.357    1.101
# 1333  This is another issue that he was very clear a...  2861.458    1.902
# 1334                     So, with that, thank you guys.   2863.36    1.168
# 1335                     I&amp;#39;ll see you tomorrow.  2864.528    0.801
# 1336                        Take care, have a good day.  2865.329    1.268
#
# [1337 rows x 3 columns]

# %%
## change 1_23_17 to the respective file
df.to_csv('transcripts/1_23_17-transcript.csv', sep=',', index=False)
