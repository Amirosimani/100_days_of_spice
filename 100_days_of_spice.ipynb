# %%
# install youtubedl library
# sudo -H pip install --upgrade youtube-dl

# %%
import os

# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime

# %% [markdown]
# ## download youtube video

# %%
# downloading all the videos from the playlist - mp4 & highest quality
# latest: 39 videos from 1/23/17 to 4/3/17
# https://www.youtube.com/playlist?list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI

# os.system("youtube-dl -f 'bestvideo[ext=mp4]/best[ext=mp4]/best' -citk https://www.youtube.com/playlist?list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI")


# os.system("youtube-dl -f bestvideo+bestaudio https://www.youtube.com/watch?v=hTpoxrEbKFk&list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI&index=39")

# %%
## files to delet

#President Trump Holds a Press Conference-Ct0H_ndjavM.mp4
#President Trump and Prime Minister Trudeau-vqkb-sJ31S4.mp4
#President Trump and PM May Joint Press Conference-8TYCHq9cAS8.mp4
#Joint Statment by President Trump and Prime Minister Shinzō Abe-ntlqA33SL-k.mp4
#Joint Press Conference-IbpsmS2BTLo.mp4"

# %% [markdown]
# ## Extracting stills from videos

# %%
import cv2
import math
import numpy as np


cv2.__version__ # this will print the version of your opencv2

# %%
# def extract_stills(videoFile, extraction_rate, output_address, output_name):
#     """This function takes the location of a video and extract stills based on the user desired rate.
#     It requires importing cv2 and math libraries.
    
#     parameters
#     video: locaiton of the video - string
#     extraction_rate: rate of extracting stills in seconds - int"""
    
#     # setting up the file
#     vidcap = cv2.VideoCapture(videoFile)
    
#     # setting up parameters
#     seconds = 1000
#     fps = int(round(vidcap.get(cv2.CAP_PROP_FPS))) # Gets the frames per second
#     total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
#     duration = (round(total_frames/fps) -1)*1000
    
#     location = output_address + output_name + '%d.jpg'
#     #extracting every 'extraction_rate' of the video
#     for i in range(0, duration, extraction_rate * 1000):
#         vidcap.set(cv2.CAP_PROP_POS_MSEC,i)
#         success,image = vidcap.read()
#         j = i/1000
# #         return cv2.imwrite(location % j, image)     # save frame as JPEG file


# # import cv2
# # import os

# # def video_to_frames(video, path_output_dir):
# #     # extract frames from a video and save to directory as 'x.png' where 
# #     # x is the frame index
# #     vidcap = cv2.VideoCapture(video)
# #     count = 0
# #     while vidcap.isOpened():
# #         success, image = vidcap.read()
# #         if success:
# #             cv2.imwrite(os.path.join(path_output_dir, '%d.png') % count, image)
# #             count += 1
# #         else:
# #             break
# #     cv2.destroyAllWindows()
# #     vidcap.release()

# # video_to_frames('../somepath/myvid.mp4', '../somepath/out')

# %%
# # fourcc = cv2.VideoWriter_fourcc(*'H264')

# # setting up the file
# videoFile = '/Users/Amiros/GitHub/100_days_of_spice/3_31_17 - White House Press Briefing-Nr8Mu0-vPsQ.mp4'
# vidcap = cv2.VideoCapture(videoFile)
# success,image = vidcap.read()

# # setting up parameters
# seconds = 1000
# fps = int(round(vidcap.get(cv2.CAP_PROP_FPS))) # Gets the frames per second
# total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
# duration = (round(total_frames/fps) -1)*1000

# #extracting every 'second' of the video
# for i in range(0, duration, seconds):
#     vidcap.set(cv2.CAP_PROP_POS_MSEC,i)
#     success,image = vidcap.read()
#     j = i/1000
#     cv2.imwrite("/Users/Amiros/GitHub/100_days_of_spice/images/4_3_17/4_3_17__%d.jpg" % j, image)     # save frame as JPEG file

# %% [markdown]
# ## Detecting Sean's face

# %%
# from cognitive_face import face as CF
# from urllib3 import util

# %%
# KEY = 'e3b77a2e317244f2a7198e9387190a64'
# CF.Key.set(KEY)

# %%
# img_url = 'http://i2.cdn.cnn.com/cnnnext/dam/assets/170121181022-sean-spicer-donald-trump-inauguration-crowd-bts-00002515-large-169.jpg'
# result = CF.detect(img_url)

# %%
# CF.detect('https://upload.wikimedia.org/wikipedia/commons/3/3f/Press_secretary_Sean_Spicer.jpg')
# # CF.detect('https://img.washingtonpost.com/wp-apps/imrs.php?src=https://img.washingtonpost.com/rf/image_960w/2010-2019/WashingtonPost/2017/01/25/Production/Daily/A-Section/Images/AFP_KO6YL.jpg&w=480')

# %%
# face_ids = ['e13dd2b8-c9a4-4035-86a8-6b37ac6ce77b', '2850cf17-4ea9-4285-86bb-d29c703338f1', '92f34cee-7038-476a-827c-b6f1e31de989']

# CF.group(face_ids)

# %%
# CF.find_similars(help)

# %% [markdown]
# # Detecting emotions

# %%
import http.client, urllib, base64, requests
import cognitive_face as CF 
from cognitive_face import util
import time
import os

# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime
# Out:
# ERROR:root:Line magic function `%install_ext` not found.

# %%
#Emotion Analysis parameters
_url = 'https://api.projectoxford.ai/emotion/v1.0/recognize'
_key = 'ead17ccf578a40b88f2bb425d11d4a66'  ######### Here you have to paste your primary key for EMOTION API
_maxNumRetries = 5

#Face detection parametrs
CF.Key.set('d78211e12bba41a991382ade5d68745b') ######### set the key for FACE API
# Out:
# time: 4.22 ms

# %%
# Image path
urlImage= ''

# Emtional Anlaysis function
def processRequest( json, data, headers, params ):

    retries = 0
    result = None

    while True:

        response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )

        if response.status_code == 429: 

            print( "Message: %s" % ( response.json()['error']['message'] ) )

            if retries <= _maxNumRetries: 
                time.sleep(1) 
                retries += 1
                continue
            else: 
                print( 'Error: failed after retrying!' )
                break

        elif response.status_code == 200 or response.status_code == 201:

            if 'content-length' in response.headers and int(response.headers['content-length']) == 0: 
                result = None 
            elif 'content-type' in response.headers and isinstance(response.headers['content-type'], str): 
                if 'application/json' in response.headers['content-type'].lower(): 
                    result = response.json() if response.content else None 
                elif 'image' in response.headers['content-type'].lower(): 
                    result = response.content
        else:
            print( "Error code: %d" % ( response.status_code ) )
            print( "Message: %s" % ( response.json()['error']['message'] ) )

        break
        
    return result


headers = dict()
headers['Ocp-Apim-Subscription-Key'] = _key
headers['Content-Type'] = 'application/json' 

json = { 'url': urlImage } 
data = None
params = None
# Out:
# time: 58.6 ms

# %%
# Face detect function
def detect(image, face_id=True, landmarks=False, faceRectangle= False, attributes='gender'):
    
    url = 'detect'
    headers, data, json = util.parse_image(image)
    params = {
        'returnFaceId': face_id and 'true',
        'returnFaceLandmarks': landmarks and 'false',
        'returnFaceAttributes': attributes,
    }

    return util.request('POST', url, headers=headers, params=params, json=json,
                        data=data)
# Out:
# time: 8.59 ms

# %%
# generate a fake url list to replicate S3 condition

#### ATTNTION ----- change '4641' to match the number of last image+1 -----#######
#### ATTNTION ----- change '1_23_17/1_23_17___%d.jpg' to match the path and names on your S3 bucket -----#######

url_list = []
for i in range(0,4641,1):
    url = "https://s3.amazonaws.com/100daysofspice/1_31_17/1_31_17___%d.jpg" % i
    url_list.append(url)
# Out:
# time: 10.1 ms

# %%
# Face Detection & Emotion Analysis - UPDATED
processed = {}
face_detection = {}
count = 0

for single_image in url_list:
 
    try:
        face_detection[count] = detect(single_image)

        json = { 'url': single_image } 
        processed[count] = processRequest(json, data, headers, params)  
    except:
        pass

    try:
        if face_detection[count][0]['faceRectangle'] == processed[count][0]['faceRectangle']:
            face_detection[count][0].update(processed[count][0])
            face_detection[count][1].update(processed[count][1])
        if  face_detection[count][0]['faceRectangle'] == processed[count][1]['faceRectangle']:
            face_detection[count][0].update(processed[count][1])
            face_detection[count][1].update(processed[count][0])
    except:
        pass
    
    count += 1
    
    time.sleep(3)
# Out:
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# ...
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# time: 5h 42min 53s

# %%
# face_detection

# %%
# Save the result as Json
#### ATTNTION ----- update '1_23_17.json' to the name of your current folder #######

import json
with open('/Users/Amiros/GitHub/100_days_of_spice/json/1_31_17.json', 'w') as fp:
    json.dump(face_detection, fp, sort_keys=True)
# Out:
# time: 191 ms

# %% [markdown]
# ## json to csv

# %%
import json
import csv
# Out:
# time: 5.29 ms

# %%
"""
This can probably be improved but serves the purpose of our analysis.
I used Chris's schema so it will be useful for Quarz analysis.

"""

EMOTIONS = [
    'contempt',
    'fear',
    'sadness',
    'disgust',
    'anger',
    'neutral',
    'happiness',
    'surprise',
]


CSV_COLUMNS = [
    'url',
    'frame_time',
    'sean_happiness',
    'sean_neutral',
    'sean_anger',
    'sean_contempt',
    'sean_suprise',
    'sean_sadness',
    'sean_fear'
]
# Out:
# time: 4.68 ms

# %%
with open('/Users/Amiros/GitHub/100_days_of_spice/json/1_31_17.json') as data_file:    
    json_data = json.load(data_file)
    
json_data = {int(k):v for k,v in json_data.items()} #converting keys to integer   
frame_keys = sorted(json_data.keys())
# Out:
# time: 25 ms

# %%
csv_data = []
   
for key in frame_keys:
    url = 'https://s3.amazonaws.com/100daysofspice/1_31_17/1_31_17___%d.jpg' % key
    frame = json_data[key]
        
    row = {
        #'frame': frame,
        'url': url,
        'frame_time': key,
    }
    
    if len(frame) > 1:
        for face in frame:
            if face['faceAttributes']['gender'] == 'male':
                prefix = 'sean_'
                try:
                    for emotion in EMOTIONS:
                        row[prefix + emotion] = face['scores'][emotion]
                except:
                    pass
                
            row.pop("frame", None)        
      
    elif len(frame) == 1:
        for face in frame:
            if face['faceAttributes']['gender'] == 'male':
                prefix = 'sean_'
                try:
                    for emotion in EMOTIONS:
                    #print(face['scores'][emotion])
                        row[prefix + emotion] = face['scores'][emotion]
                except:
                    pass
                ### assign emotions vale to each candidate and change the name to the respective one 
          
        row.pop("frame", None)        

    csv_data.append(row)
# Out:
# time: 34.1 ms

# %%
import pandas as pd
df = pd.DataFrame(csv_data)
# Out:
# time: 1.17 s

# %%
df
# Out:
#       frame_time  sean_anger  sean_contempt  sean_disgust     sean_fear  \
# 0              0    0.005504       0.000894      0.002836  4.801955e-05
# 1              1    0.007709       0.002856      0.003567  5.642760e-05
# 2              2    0.012600       0.079869      0.022152  2.675390e-04
# 3              3    0.025501       0.033740      0.042702  7.675677e-04
# 4              4    0.007229       0.002177      0.004056  1.262398e-04
# 5              5    0.025321       0.001942      0.018166  9.233483e-05
# 6              6    0.117841       0.006525      0.007059  1.154274e-03
# 7              7    0.013516       0.013069      0.004960  1.342704e-05
# 8              8    0.088563       0.011122      0.038271  1.234495e-04
# 9              9    0.035057       0.000916      0.015588  1.951357e-04
# 10            10    0.016947       0.001590      0.005634  7.981528e-05
# 11            11    0.020225       0.001053      0.011411  1.908366e-04
# 12            12    0.127195       0.006455      0.047883  5.753033e-04
# 13            13    0.030090       0.000686      0.009786  1.124430e-03
# 14            14    0.071039       0.005613      0.009648  1.359061e-04
# 15            15    0.020403       0.004358      0.008762  1.807859e-05
# 16            16    0.046800       0.006548      0.017401  2.924982e-04
# 17            17    0.007875       0.000484      0.004443  2.391243e-05
# 18            18    0.010505       0.000109      0.004239  1.940335e-05
# 19            19    0.003031       0.000131      0.000277  4.346209e-07
# 20            20    0.056540       0.014067      0.039606  5.493721e-04
# 21            21    0.014205       0.023606      0.029103  5.506415e-04
# 22            22    0.000934       0.000598      0.000571  5.241815e-06
# 23            23    0.002574       0.000448      0.000946  5.929880e-06
# 24            24    0.000851       0.000149      0.000140  8.201590e-07
# 25            25    0.015942       0.000204      0.004965  3.733574e-05
# 26            26    0.001684       0.000046      0.000307  7.249183e-07
# 27            27    0.014321       0.000177      0.001984  8.238173e-06
# 28            28    0.025379       0.001697      0.011432  5.635630e-04
# 29            29    0.006846       0.000661      0.003670  2.553502e-05
# ...          ...         ...            ...           ...           ...
# 1900        2390    0.181250       0.007338      0.050053  4.933709e-04
# 1901        2391    0.061591       0.011105      0.012740  2.675791e-04
# 1902        2392    0.273940       0.006108      0.076137  7.386535e-04
# 1903        2393    0.214458       0.028159      0.079012  4.719026e-04
# 1904        2394    0.087446       0.010839      0.029454  5.834025e-04
# 1905        2395    0.072849       0.015022      0.012419  2.754045e-04
# 1906        2396    0.170620       0.005452      0.061629  1.850226e-03
# 1907        2397    0.148248       0.004391      0.028351  9.184079e-04
# 1908        2398    0.102599       0.010187      0.075920  1.876591e-03
# 1909        2399    0.091996       0.012574      0.037164  5.893340e-04
# 1910        2400    0.286174       0.005760      0.063747  5.968183e-04
# 1911        2401    0.147305       0.008404      0.050920  8.378921e-04
# 1912        2402    0.341099       0.009622      0.080920  1.014442e-03
# 1913        2403    0.294226       0.007486      0.058928  7.637575e-04
# 1914        2404    0.259620       0.005693      0.072938  6.404530e-04
# 1915        2405    0.331823       0.006765      0.078499  9.016876e-04
# 1916        2406    0.412446       0.008411      0.119055  1.623739e-03
# 1917        2407    0.167748       0.007591      0.067005  1.475782e-03
# 1918        2408    0.140187       0.015631      0.072157  3.977892e-03
# 1919        2409    0.302644       0.005839      0.103769  1.381772e-03
# 1920        2410    0.177812       0.005078      0.067088  4.586471e-04
# 1921        2411    0.039891       0.018416      0.004159  8.995001e-06
# 1922        2412    0.434636       0.002503      0.036420  1.097102e-04
# 1923        2413    0.217808       0.011919      0.085256  2.878308e-03
# 1924        2414    0.076710       0.018154      0.031413  3.941355e-04
# 1925        2415    0.445835       0.003522      0.045834  5.016795e-04
# 1926        2416    0.221406       0.020874      0.029294  8.551132e-05
# 1927        2417    0.125400       0.007917      0.012314  1.196824e-04
# 1928        2418    0.292473       0.016396      0.046040  2.369161e-03
# 1929        2419    0.229082       0.008047      0.046704  5.236078e-04
#
#       sean_happiness  sean_neutral  sean_sadness  sean_surprise  \
# 0           0.890493      0.087896      0.010910       0.001419
# 1           0.943167      0.030105      0.010142       0.002398
# 2           0.426960      0.405314      0.049232       0.003606
# 3           0.173726      0.661514      0.050155       0.011894
# 4           0.008898      0.848861      0.127756       0.000897
# 5           0.000141      0.721242      0.232193       0.000903
# 6           0.000424      0.816343      0.008071       0.042583
# 7           0.002964      0.963098      0.000620       0.001759
# 8           0.001542      0.832256      0.004619       0.023502
# 9           0.000313      0.879365      0.061389       0.007176
# 10          0.000080      0.716534      0.258797       0.000339
# 11          0.000202      0.925939      0.020635       0.020344
# 12          0.002469      0.551708      0.003659       0.260057
# 13          0.000059      0.856326      0.008241       0.093689
# 14          0.000144      0.896510      0.005538       0.011372
# 15          0.000530      0.955952      0.002460       0.007518
# 16          0.002239      0.874982      0.003814       0.047923
# 17          0.000196      0.888840      0.097548       0.000589
# 18          0.000003      0.717937      0.266961       0.000226
# 19          0.000003      0.704254      0.292298       0.000005
# 20          0.004985      0.824186      0.003900       0.056167
# 21          0.687707      0.121411      0.120381       0.003037
# 22          0.002837      0.803427      0.191593       0.000035
# 23          0.000270      0.910945      0.084716       0.000094
# 24          0.000021      0.835491      0.163336       0.000011
# 25          0.000008      0.892298      0.084212       0.002333
# 26          0.000005      0.733494      0.264458       0.000006
# 27          0.000001      0.717483      0.265903       0.000123
# 28          0.000358      0.876704      0.068643       0.015224
# 29          0.000629      0.938199      0.048939       0.001029
# ...              ...           ...           ...            ...
# 1900        0.000798      0.601374      0.003450       0.155244
# 1901        0.000180      0.885893      0.015930       0.012294
# 1902        0.000331      0.320689      0.005674       0.316383
# 1903        0.000050      0.603238      0.006346       0.068265
# 1904        0.000020      0.799285      0.057266       0.015107
# 1905        0.000202      0.872739      0.010353       0.016139
# 1906        0.000215      0.508225      0.010400       0.241609
# 1907        0.000051      0.759480      0.018594       0.039966
# 1908        0.000112      0.664756      0.086285       0.058265
# 1909        0.000128      0.806007      0.014618       0.036923
# 1910        0.000106      0.539043      0.009405       0.095169
# 1911        0.000069      0.703340      0.011843       0.077281
# 1912        0.000065      0.467889      0.012182       0.087210
# 1913        0.000174      0.514979      0.005159       0.118284
# 1914        0.000358      0.347897      0.006433       0.306420
# 1915        0.000083      0.388324      0.011261       0.182344
# 1916        0.000061      0.381809      0.017401       0.059193
# 1917        0.000064      0.499700      0.018698       0.237719
# 1918        0.000062      0.576786      0.039052       0.152147
# 1919        0.000039      0.345161      0.014405       0.226761
# 1920        0.000229      0.675806      0.026689       0.046840
# 1921        0.000032      0.920497      0.016684       0.000312
# 1922        0.000149      0.410580      0.001116       0.114487
# 1923        0.000660      0.530536      0.020712       0.130230
# 1924        0.000292      0.837137      0.021004       0.014894
# 1925        0.000095      0.431821      0.006043       0.066348
# 1926        0.000069      0.697408      0.005402       0.025462
# 1927        0.000032      0.839474      0.005878       0.008865
# 1928        0.000188      0.501325      0.004709       0.136501
# 1929        0.000352      0.617488      0.007171       0.090632
#
#                                                     url
# 0     https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1     https://s3.amazonaws.com/100daysofspice/1_31_1...
# 2     https://s3.amazonaws.com/100daysofspice/1_31_1...
# 3     https://s3.amazonaws.com/100daysofspice/1_31_1...
# 4     https://s3.amazonaws.com/100daysofspice/1_31_1...
# 5     https://s3.amazonaws.com/100daysofspice/1_31_1...
# 6     https://s3.amazonaws.com/100daysofspice/1_31_1...
# 7     https://s3.amazonaws.com/100daysofspice/1_31_1...
# 8     https://s3.amazonaws.com/100daysofspice/1_31_1...
# 9     https://s3.amazonaws.com/100daysofspice/1_31_1...
# 10    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 11    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 12    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 13    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 14    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 15    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 16    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 17    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 18    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 19    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 20    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 21    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 22    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 23    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 24    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 25    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 26    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 27    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 28    https://s3.amazonaws.com/100daysofspice/1_31_1...
# 29    https://s3.amazonaws.com/100daysofspice/1_31_1...
# ...                                                 ...
# 1900  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1901  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1902  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1903  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1904  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1905  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1906  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1907  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1908  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1909  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1910  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1911  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1912  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1913  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1914  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1915  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1916  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1917  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1918  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1919  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1920  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1921  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1922  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1923  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1924  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1925  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1926  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1927  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1928  https://s3.amazonaws.com/100daysofspice/1_31_1...
# 1929  https://s3.amazonaws.com/100daysofspice/1_31_1...
#
# [1930 rows x 10 columns]
# time: 63.1 ms

# %%
df.to_csv('csv/1_31_17-EMOTIONS.csv', sep=',', index=False)
# Out:
# time: 49.5 ms
