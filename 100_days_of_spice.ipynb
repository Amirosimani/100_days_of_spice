# %%
# install youtubedl library
# sudo -H pip install --upgrade youtube-dl

# %%
import os

# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime

# %% [markdown]
# ## download youtube video

# %%
# downloading all the videos from the playlist - mp4 & highest quality
# latest: 39 videos from 1/23/17 to 4/3/17
# https://www.youtube.com/playlist?list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI

# os.system("youtube-dl -f 'bestvideo[ext=mp4]/best[ext=mp4]/best' -citk https://www.youtube.com/playlist?list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI")


# os.system("youtube-dl -f bestvideo+bestaudio https://www.youtube.com/watch?v=hTpoxrEbKFk&list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI&index=39")

# %%
## files to delet

#President Trump Holds a Press Conference-Ct0H_ndjavM.mp4
#President Trump and Prime Minister Trudeau-vqkb-sJ31S4.mp4
#President Trump and PM May Joint Press Conference-8TYCHq9cAS8.mp4
#Joint Statment by President Trump and Prime Minister Shinzō Abe-ntlqA33SL-k.mp4
#Joint Press Conference-IbpsmS2BTLo.mp4"

# %% [markdown]
# ## Extracting stills from videos

# %%
import cv2
import math
import numpy as np


cv2.__version__ # this will print the version of your opencv2

# %%
# def extract_stills(videoFile, extraction_rate, output_address, output_name):
#     """This function takes the location of a video and extract stills based on the user desired rate.
#     It requires importing cv2 and math libraries.
    
#     parameters
#     video: locaiton of the video - string
#     extraction_rate: rate of extracting stills in seconds - int"""
    
#     # setting up the file
#     vidcap = cv2.VideoCapture(videoFile)
    
#     # setting up parameters
#     seconds = 1000
#     fps = int(round(vidcap.get(cv2.CAP_PROP_FPS))) # Gets the frames per second
#     total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
#     duration = (round(total_frames/fps) -1)*1000
    
#     location = output_address + output_name + '%d.jpg'
#     #extracting every 'extraction_rate' of the video
#     for i in range(0, duration, extraction_rate * 1000):
#         vidcap.set(cv2.CAP_PROP_POS_MSEC,i)
#         success,image = vidcap.read()
#         j = i/1000
# #         return cv2.imwrite(location % j, image)     # save frame as JPEG file


# # import cv2
# # import os

# # def video_to_frames(video, path_output_dir):
# #     # extract frames from a video and save to directory as 'x.png' where 
# #     # x is the frame index
# #     vidcap = cv2.VideoCapture(video)
# #     count = 0
# #     while vidcap.isOpened():
# #         success, image = vidcap.read()
# #         if success:
# #             cv2.imwrite(os.path.join(path_output_dir, '%d.png') % count, image)
# #             count += 1
# #         else:
# #             break
# #     cv2.destroyAllWindows()
# #     vidcap.release()

# # video_to_frames('../somepath/myvid.mp4', '../somepath/out')

# %%
# # fourcc = cv2.VideoWriter_fourcc(*'H264')

# # setting up the file
# videoFile = '/Users/Amiros/GitHub/100_days_of_spice/3_31_17 - White House Press Briefing-Nr8Mu0-vPsQ.mp4'
# vidcap = cv2.VideoCapture(videoFile)
# success,image = vidcap.read()

# # setting up parameters
# seconds = 1000
# fps = int(round(vidcap.get(cv2.CAP_PROP_FPS))) # Gets the frames per second
# total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
# duration = (round(total_frames/fps) -1)*1000

# #extracting every 'second' of the video
# for i in range(0, duration, seconds):
#     vidcap.set(cv2.CAP_PROP_POS_MSEC,i)
#     success,image = vidcap.read()
#     j = i/1000
#     cv2.imwrite("/Users/Amiros/GitHub/100_days_of_spice/images/4_3_17/4_3_17__%d.jpg" % j, image)     # save frame as JPEG file

# %% [markdown]
# ## Detecting Sean's face

# %%
# from cognitive_face import face as CF
# from urllib3 import util

# %%
# KEY = 'e3b77a2e317244f2a7198e9387190a64'
# CF.Key.set(KEY)

# %%
# img_url = 'http://i2.cdn.cnn.com/cnnnext/dam/assets/170121181022-sean-spicer-donald-trump-inauguration-crowd-bts-00002515-large-169.jpg'
# result = CF.detect(img_url)

# %%
# CF.detect('https://upload.wikimedia.org/wikipedia/commons/3/3f/Press_secretary_Sean_Spicer.jpg')
# # CF.detect('https://img.washingtonpost.com/wp-apps/imrs.php?src=https://img.washingtonpost.com/rf/image_960w/2010-2019/WashingtonPost/2017/01/25/Production/Daily/A-Section/Images/AFP_KO6YL.jpg&w=480')

# %%
# face_ids = ['e13dd2b8-c9a4-4035-86a8-6b37ac6ce77b', '2850cf17-4ea9-4285-86bb-d29c703338f1', '92f34cee-7038-476a-827c-b6f1e31de989']

# CF.group(face_ids)

# %%
# CF.find_similars(help)

# %% [markdown]
# # Detecting emotions

# %%
import http.client, urllib, base64, requests
import cognitive_face as CF 
from cognitive_face import util
import time
import os

# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime
# Out:
# ERROR:root:Line magic function `%install_ext` not found.

# %%
#Emotion Analysis parameters
_url = 'https://api.projectoxford.ai/emotion/v1.0/recognize'
_key = '167a95eae08446f0a00b4568c045b97b'  ######### Here you have to paste your primary key for EMOTION API
_maxNumRetries = 5

#Face detection parametrs
CF.Key.set('bee19ea2a47e4a6eb64e23e969a6df6e') ######### set the key for FACE API
# Out:
# time: 2.55 ms

# %%
# Image path
urlImage= ''

# Emtional Anlaysis function
def processRequest( json, data, headers, params ):

    retries = 0
    result = None

    while True:

        response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )

        if response.status_code == 429: 

            print( "Message: %s" % ( response.json()['error']['message'] ) )

            if retries <= _maxNumRetries: 
                time.sleep(1) 
                retries += 1
                continue
            else: 
                print( 'Error: failed after retrying!' )
                break

        elif response.status_code == 200 or response.status_code == 201:

            if 'content-length' in response.headers and int(response.headers['content-length']) == 0: 
                result = None 
            elif 'content-type' in response.headers and isinstance(response.headers['content-type'], str): 
                if 'application/json' in response.headers['content-type'].lower(): 
                    result = response.json() if response.content else None 
                elif 'image' in response.headers['content-type'].lower(): 
                    result = response.content
        else:
            print( "Error code: %d" % ( response.status_code ) )
            print( "Message: %s" % ( response.json()['error']['message'] ) )

        break
        
    return result


headers = dict()
headers['Ocp-Apim-Subscription-Key'] = _key
headers['Content-Type'] = 'application/json' 

json = { 'url': urlImage } 
data = None
params = None
# Out:
# time: 37.2 ms

# %%
# Face detect function
def detect(image, face_id=True, landmarks=False, faceRectangle= False, attributes='gender'):
    
    url = 'detect'
    headers, data, json = util.parse_image(image)
    params = {
        'returnFaceId': face_id and 'true',
        'returnFaceLandmarks': landmarks and 'false',
        'returnFaceAttributes': attributes,
    }

    return util.request('POST', url, headers=headers, params=params, json=json,
                        data=data)
# Out:
# time: 5.49 ms

# %%
# generate a fake url list to replicate S3 condition

#### ATTNTION ----- change '4641' to match the number of last image+1 -----#######
#### ATTNTION ----- change '1_23_17/1_23_17___%d.jpg' to match the path and names on your S3 bucket -----#######

url_list = []
for i in range(0,2340,1):
    url = "https://s3.amazonaws.com/100daysofspice/3_24_17/3_24_17___%d.jpg" % i
    url_list.append(url)
# Out:
# time: 8.41 ms

# %%
# Face Detection & Emotion Analysis - UPDATED
processed = {}
face_detection = {}
count = 0

for single_image in url_list:
 
    try:
        face_detection[count] = detect(single_image)

        json = { 'url': single_image } 
        processed[count] = processRequest(json, data, headers, params)  
    except:
        pass

    try:
        if face_detection[count][0]['faceRectangle'] == processed[count][0]['faceRectangle']:
            face_detection[count][0].update(processed[count][0])
            face_detection[count][1].update(processed[count][1])
        if  face_detection[count][0]['faceRectangle'] == processed[count][1]['faceRectangle']:
            face_detection[count][0].update(processed[count][1])
            face_detection[count][1].update(processed[count][0])
    except:
        pass
    
    count += 1
    
    time.sleep(3)
# Out:
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# ...
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# time: 3h 22min 47s

# %%
face_detection

# %%
# Save the result as Json
#### ATTNTION ----- update '1_23_17.json' to the name of your current folder #######

import json
with open('/Users/Amiros/GitHub/100_days_of_spice/json/3_24_17.json', 'w') as fp:
    json.dump(face_detection, fp, sort_keys=True)
# Out:
# time: 278 ms

# %% [markdown]
# ## json to csv

# %%
import json
import csv
# Out:
# time: 1.25 ms

# %%
"""
This can probably be improved but serves the purpose of our analysis.
I used Chris's schema so it will be useful for Quarz analysis.

"""

EMOTIONS = [
    'contempt',
    'fear',
    'sadness',
    'disgust',
    'anger',
    'neutral',
    'happiness',
    'surprise',
]


CSV_COLUMNS = [
    'url',
    'frame_time',
    'sean_happiness',
    'sean_neutral',
    'sean_anger',
    'sean_contempt',
    'sean_suprise',
    'sean_sadness',
    'sean_fear'
]
# Out:
# time: 8.1 ms

# %%
with open('/Users/Amiros/GitHub/100_days_of_spice/json/3_24_17.json') as data_file:    
    json_data = json.load(data_file)
    
json_data = {int(k):v for k,v in json_data.items()} #converting keys to integer   
frame_keys = sorted(json_data.keys())
# Out:
# time: 76.8 ms

# %%
csv_data = []
   
for key in frame_keys:
    url = 'https://s3.amazonaws.com/100daysofspice/3_24_17/3_24_17___%d.jpg' % key
    frame = json_data[key]
        
    row = {
        #'frame': frame,
        'url': url,
        'frame_time': key,
    }
    
    if len(frame) > 1:
        for face in frame:
            if face['faceAttributes']['gender'] == 'male':
                prefix = 'sean_'
                try:
                    for emotion in EMOTIONS:
                        row[prefix + emotion] = face['scores'][emotion]
                except:
                    pass
                
            row.pop("frame", None)        
      
    elif len(frame) == 1:
        for face in frame:
            if face['faceAttributes']['gender'] == 'male':
                prefix = 'sean_'
                try:
                    for emotion in EMOTIONS:
                    #print(face['scores'][emotion])
                        row[prefix + emotion] = face['scores'][emotion]
                except:
                    pass
                ### assign emotions vale to each candidate and change the name to the respective one 
          
        row.pop("frame", None)        

    csv_data.append(row)
# Out:
# time: 90.1 ms

# %%
import pandas as pd
df = pd.DataFrame(csv_data)
# Out:
# time: 63.8 ms

# %%
####### change the date here
df['data'] = '3_24_17'
df
# Out:
#       frame_time  sean_anger  sean_contempt  sean_disgust     sean_fear  \
# 0              0         NaN            NaN           NaN           NaN
# 1              1         NaN            NaN           NaN           NaN
# 2              2         NaN            NaN           NaN           NaN
# 3              3    0.013924       0.001532      0.002741  3.466777e-04
# 4              4    0.000765       0.000067      0.000042  1.219669e-06
# 5              5    0.053351       0.002071      0.015220  1.999661e-03
# 6              6    0.006518       0.001020      0.000712  1.484620e-06
# 7              7    0.005387       0.000920      0.001495  8.988951e-06
# 8              8    0.035684       0.002829      0.015005  7.560816e-05
# 9              9    0.002132       0.000060      0.000096  2.469470e-07
# 10            10    0.030767       0.002683      0.014579  1.297466e-04
# 11            11    0.007038       0.000746      0.002200  5.094723e-05
# 12            12    0.006785       0.000135      0.000135  2.377402e-07
# 13            13    0.003043       0.000213      0.000355  7.908001e-07
# 14            14    0.004407       0.000075      0.000177  2.846635e-07
# 15            15    0.052011       0.002296      0.007434  1.143132e-04
# 16            16    0.261202       0.007017      0.077759  4.402208e-04
# 17            17    0.026968       0.001286      0.018464  1.648451e-04
# 18            18    0.068294       0.001734      0.034528  1.231887e-03
# 19            19    0.006911       0.000092      0.002470  7.186265e-06
# 20            20    0.001569       0.000043      0.000158  1.613259e-07
# 21            21    0.005099       0.000142      0.000896  6.580711e-07
# 22            22    0.045648       0.000375      0.009804  6.248859e-05
# 23            23    0.005195       0.000078      0.000743  1.834567e-06
# 24            24    0.002493       0.000039      0.000204  7.250990e-08
# 25            25    0.009134       0.000081      0.000424  1.972466e-07
# 26            26    0.117698       0.013086      0.013196  1.924045e-03
# 27            27    0.003926       0.000049      0.000260  1.517467e-06
# 28            28    0.031984       0.001644      0.010272  1.502340e-04
# 29            29    0.017822       0.000294      0.001240  2.848855e-06
# ...          ...         ...            ...           ...           ...
# 1906        2292    0.307929       0.005813      0.022708  3.608282e-03
# 1907        2293    0.311460       0.001988      0.032789  3.588403e-04
# 1908        2294    0.410956       0.002853      0.038794  4.664997e-04
# 1909        2295    0.174051       0.003730      0.034111  6.746878e-03
# 1910        2296    0.284596       0.002548      0.043829  2.043121e-03
# 1911        2297    0.189650       0.004185      0.042699  2.005284e-03
# 1912        2298    0.138636       0.005691      0.009702  4.176004e-04
# 1913        2299    0.191931       0.006334      0.031672  3.210831e-03
# 1914        2300    0.113113       0.002484      0.008356  6.283087e-04
# 1915        2301    0.255299       0.002006      0.002593  3.435285e-04
# 1916        2302    0.395536       0.003335      0.036939  3.421809e-03
# 1917        2303    0.208053       0.002508      0.033310  7.900908e-04
# 1918        2304    0.510517       0.008218      0.046516  2.568421e-04
# 1919        2305    0.341692       0.003566      0.045830  1.478440e-03
# 1920        2306    0.395026       0.001680      0.029531  2.195044e-03
# 1921        2307    0.203915       0.003595      0.027895  2.511606e-03
# 1922        2308    0.049638       0.001065      0.003365  1.126958e-04
# 1923        2309    0.086529       0.001972      0.010319  1.540393e-03
# 1924        2310    0.267043       0.006862      0.013641  3.324806e-03
# 1925        2311    0.304327       0.008958      0.018462  7.799827e-03
# 1926        2312    0.253135       0.004800      0.017234  4.303965e-03
# 1927        2313    0.259493       0.007313      0.040961  4.218054e-03
# 1928        2314    0.020237       0.001246      0.004717  6.778350e-04
# 1929        2315    0.225589       0.003842      0.016033  1.767558e-03
# 1930        2316    0.438614       0.001913      0.043318  8.574471e-04
# 1931        2317    0.216238       0.001273      0.005500  8.988590e-04
# 1932        2318    0.234111       0.004863      0.028902  1.152556e-02
# 1933        2337    0.173482       0.001767      0.023432  2.087111e-03
# 1934        2338    0.364443       0.000651      0.002105  8.474552e-05
# 1935        2339    0.275655       0.001240      0.034314  3.554878e-03
#
#       sean_happiness  sean_neutral  sean_sadness  sean_surprise  \
# 0                NaN           NaN           NaN            NaN
# 1                NaN           NaN           NaN            NaN
# 2                NaN           NaN           NaN            NaN
# 3       1.480447e-03      0.933704      0.043793   2.478034e-03
# 4       5.931676e-04      0.944811      0.053705   1.534868e-05
# 5       6.700318e-04      0.809690      0.107334   9.663943e-03
# 6       1.559304e-04      0.785280      0.206303   8.549542e-06
# 7       4.910476e-05      0.826709      0.165330   1.014584e-04
# 8       6.807351e-04      0.903582      0.002369   3.977352e-02
# 9       7.228986e-06      0.898114      0.099582   8.519891e-06
# 10      3.163549e-04      0.890139      0.002313   5.907195e-02
# 11      4.654887e-04      0.940101      0.048338   1.059356e-03
# 12      5.232531e-07      0.847654      0.145287   2.399227e-06
# 13      1.049090e-05      0.864715      0.131654   8.607552e-06
# 14      8.432860e-07      0.675213      0.320125   1.548924e-06
# 15      4.975777e-05      0.919154      0.005108   1.383261e-02
# 16      9.540935e-04      0.605419      0.027816   1.939405e-02
# 17      3.323844e-05      0.449335      0.503326   4.219983e-04
# 18      1.761346e-04      0.657871      0.232926   3.238933e-03
# 19      6.608451e-06      0.891518      0.098827   1.676095e-04
# 20      3.312519e-06      0.790759      0.207466   1.905924e-06
# 21      2.517195e-05      0.743280      0.250555   2.997629e-06
# 22      1.266379e-05      0.671853      0.272011   2.347363e-04
# 23      1.114821e-05      0.768885      0.225071   1.546677e-05
# 24      8.203001e-07      0.449604      0.547659   1.725109e-07
# 25      2.747037e-06      0.744427      0.245930   1.112474e-06
# 26      1.396110e-04      0.801968      0.014220   3.776783e-02
# 27      4.973659e-05      0.894712      0.100987   1.549985e-05
# 28      2.095646e-04      0.836229      0.115865   3.645033e-03
# 29      3.497161e-06      0.621405      0.359225   7.648430e-06
# ...              ...           ...           ...            ...
# 1906    5.115675e-06      0.608897      0.023184   2.785459e-02
# 1907    1.138436e-04      0.547623      0.003798   1.018699e-01
# 1908    7.951029e-05      0.501302      0.004418   4.113090e-02
# 1909    9.447131e-06      0.652246      0.059271   6.983452e-02
# 1910    8.396608e-06      0.582460      0.045865   3.865065e-02
# 1911    4.214899e-05      0.680010      0.033601   4.780738e-02
# 1912    3.895953e-05      0.770442      0.072162   2.910117e-03
# 1913    4.368692e-05      0.678367      0.036022   5.241993e-02
# 1914    5.326407e-05      0.848809      0.012094   1.446194e-02
# 1915    1.577404e-06      0.703773      0.032680   3.303879e-03
# 1916    1.075001e-05      0.482332      0.021523   5.690193e-02
# 1917    3.990294e-05      0.674858      0.018323   6.211835e-02
# 1918    1.787177e-02      0.382411      0.001160   3.304964e-02
# 1919    4.421387e-04      0.532528      0.016226   5.823604e-02
# 1920    1.894438e-05      0.351681      0.007773   2.120951e-01
# 1921    3.931479e-05      0.661659      0.022842   7.754259e-02
# 1922    3.680852e-05      0.817885      0.126932   9.650264e-04
# 1923    1.194399e-04      0.814967      0.063378   2.117527e-02
# 1924    2.405994e-05      0.636190      0.031806   4.110754e-02
# 1925    5.930656e-05      0.559688      0.051269   4.943720e-02
# 1926    1.309634e-05      0.639665      0.043103   3.774564e-02
# 1927    1.183228e-05      0.576356      0.057644   5.400370e-02
# 1928    9.640439e-04      0.904812      0.032653   3.469307e-02
# 1929    9.695221e-06      0.686250      0.023515   4.299374e-02
# 1930    1.686370e-04      0.449580      0.012636   5.291256e-02
# 1931    4.262109e-06      0.728018      0.036550   1.151860e-02
# 1932    6.010313e-06      0.596244      0.040637   8.371156e-02
# 1933    1.044982e-04      0.676784      0.013501   1.088422e-01
# 1934    2.703362e-07      0.615653      0.015603   1.460376e-03
# 1935    2.819770e-06      0.511810      0.018513   1.549099e-01
#
#                                                     url     data
# 0     https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1     https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 2     https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 3     https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 4     https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 5     https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 6     https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 7     https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 8     https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 9     https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 10    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 11    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 12    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 13    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 14    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 15    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 16    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 17    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 18    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 19    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 20    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 21    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 22    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 23    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 24    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 25    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 26    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 27    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 28    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 29    https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# ...                                                 ...      ...
# 1906  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1907  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1908  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1909  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1910  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1911  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1912  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1913  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1914  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1915  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1916  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1917  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1918  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1919  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1920  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1921  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1922  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1923  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1924  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1925  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1926  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1927  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1928  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1929  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1930  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1931  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1932  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1933  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1934  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
# 1935  https://s3.amazonaws.com/100daysofspice/3_24_1...  3_24_17
#
# [1936 rows x 11 columns]
# time: 86.5 ms

# %%
#### change the name here
df.to_csv('csv/3_24_17-EMOTIONS.csv', sep=',', index=False)
# Out:
# time: 60 ms
