# %%
# install youtubedl library
# sudo -H pip install --upgrade youtube-dl

# %%
import os

# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime

# %% [markdown]
# ## download youtube video

# %%
# downloading all the videos from the playlist - mp4 & highest quality
# latest: 39 videos from 1/23/17 to 4/3/17
# https://www.youtube.com/playlist?list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI

# os.system("youtube-dl -f 'bestvideo[ext=mp4]/best[ext=mp4]/best' -citk https://www.youtube.com/playlist?list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI")


# os.system("youtube-dl -f bestvideo+bestaudio https://www.youtube.com/watch?v=hTpoxrEbKFk&list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI&index=39")

# %%
## files to delet

#President Trump Holds a Press Conference-Ct0H_ndjavM.mp4
#President Trump and Prime Minister Trudeau-vqkb-sJ31S4.mp4
#President Trump and PM May Joint Press Conference-8TYCHq9cAS8.mp4
#Joint Statment by President Trump and Prime Minister Shinzō Abe-ntlqA33SL-k.mp4
#Joint Press Conference-IbpsmS2BTLo.mp4"

# %% [markdown]
# ## Extracting stills from videos

# %%
import cv2
import math
import numpy as np


cv2.__version__ # this will print the version of your opencv2

# %%
# def extract_stills(videoFile, extraction_rate, output_address, output_name):
#     """This function takes the location of a video and extract stills based on the user desired rate.
#     It requires importing cv2 and math libraries.
    
#     parameters
#     video: locaiton of the video - string
#     extraction_rate: rate of extracting stills in seconds - int"""
    
#     # setting up the file
#     vidcap = cv2.VideoCapture(videoFile)
    
#     # setting up parameters
#     seconds = 1000
#     fps = int(round(vidcap.get(cv2.CAP_PROP_FPS))) # Gets the frames per second
#     total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
#     duration = (round(total_frames/fps) -1)*1000
    
#     location = output_address + output_name + '%d.jpg'
#     #extracting every 'extraction_rate' of the video
#     for i in range(0, duration, extraction_rate * 1000):
#         vidcap.set(cv2.CAP_PROP_POS_MSEC,i)
#         success,image = vidcap.read()
#         j = i/1000
# #         return cv2.imwrite(location % j, image)     # save frame as JPEG file


# # import cv2
# # import os

# # def video_to_frames(video, path_output_dir):
# #     # extract frames from a video and save to directory as 'x.png' where 
# #     # x is the frame index
# #     vidcap = cv2.VideoCapture(video)
# #     count = 0
# #     while vidcap.isOpened():
# #         success, image = vidcap.read()
# #         if success:
# #             cv2.imwrite(os.path.join(path_output_dir, '%d.png') % count, image)
# #             count += 1
# #         else:
# #             break
# #     cv2.destroyAllWindows()
# #     vidcap.release()

# # video_to_frames('../somepath/myvid.mp4', '../somepath/out')

# %%
# # fourcc = cv2.VideoWriter_fourcc(*'H264')

# # setting up the file
# videoFile = '/Users/Amiros/GitHub/100_days_of_spice/3_31_17 - White House Press Briefing-Nr8Mu0-vPsQ.mp4'
# vidcap = cv2.VideoCapture(videoFile)
# success,image = vidcap.read()

# # setting up parameters
# seconds = 1000
# fps = int(round(vidcap.get(cv2.CAP_PROP_FPS))) # Gets the frames per second
# total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
# duration = (round(total_frames/fps) -1)*1000

# #extracting every 'second' of the video
# for i in range(0, duration, seconds):
#     vidcap.set(cv2.CAP_PROP_POS_MSEC,i)
#     success,image = vidcap.read()
#     j = i/1000
#     cv2.imwrite("/Users/Amiros/GitHub/100_days_of_spice/images/4_3_17/4_3_17__%d.jpg" % j, image)     # save frame as JPEG file

# %% [markdown]
# ## Detecting Sean's face

# %%
# from cognitive_face import face as CF
# from urllib3 import util

# %%
# KEY = 'e3b77a2e317244f2a7198e9387190a64'
# CF.Key.set(KEY)

# %%
# img_url = 'http://i2.cdn.cnn.com/cnnnext/dam/assets/170121181022-sean-spicer-donald-trump-inauguration-crowd-bts-00002515-large-169.jpg'
# result = CF.detect(img_url)

# %%
# CF.detect('https://upload.wikimedia.org/wikipedia/commons/3/3f/Press_secretary_Sean_Spicer.jpg')
# # CF.detect('https://img.washingtonpost.com/wp-apps/imrs.php?src=https://img.washingtonpost.com/rf/image_960w/2010-2019/WashingtonPost/2017/01/25/Production/Daily/A-Section/Images/AFP_KO6YL.jpg&w=480')

# %%
# face_ids = ['e13dd2b8-c9a4-4035-86a8-6b37ac6ce77b', '2850cf17-4ea9-4285-86bb-d29c703338f1', '92f34cee-7038-476a-827c-b6f1e31de989']

# CF.group(face_ids)

# %%
# CF.find_similars(help)

# %% [markdown]
# # Detecting emotions

# %%
import http.client, urllib, base64, requests
import cognitive_face as CF 
from cognitive_face import util
import time
import os

# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime
# Out:
# ERROR:root:Line magic function `%install_ext` not found.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 6.15 ms

# %%
#Emotion Analysis parameters
_url = 'https://api.projectoxford.ai/emotion/v1.0/recognize'
_key = '33d85b37f8474e40b649999562336739'  ######### Here you have to paste your primary key for EMOTION API
_maxNumRetries = 5

#Face detection parametrs
CF.Key.set('6a96532956704d31a587e859fad4df30') ######### set the key for FACE API
# Out:
# time: 2.78 ms

# %%
# Image path
urlImage= ''

# Emtional Anlaysis function
def processRequest( json, data, headers, params ):

    retries = 0
    result = None

    while True:

        response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )

        if response.status_code == 429: 

            print( "Message: %s" % ( response.json()['error']['message'] ) )

            if retries <= _maxNumRetries: 
                time.sleep(1) 
                retries += 1
                continue
            else: 
                print( 'Error: failed after retrying!' )
                break

        elif response.status_code == 200 or response.status_code == 201:

            if 'content-length' in response.headers and int(response.headers['content-length']) == 0: 
                result = None 
            elif 'content-type' in response.headers and isinstance(response.headers['content-type'], str): 
                if 'application/json' in response.headers['content-type'].lower(): 
                    result = response.json() if response.content else None 
                elif 'image' in response.headers['content-type'].lower(): 
                    result = response.content
        else:
            print( "Error code: %d" % ( response.status_code ) )
            print( "Message: %s" % ( response.json()['error']['message'] ) )

        break
        
    return result


headers = dict()
headers['Ocp-Apim-Subscription-Key'] = _key
headers['Content-Type'] = 'application/json' 

json = { 'url': urlImage } 
data = None
params = None
# Out:
# time: 39 ms

# %%
# Face detect function
def detect(image, face_id=True, landmarks=False, faceRectangle= False, attributes='gender'):
    
    url = 'detect'
    headers, data, json = util.parse_image(image)
    params = {
        'returnFaceId': face_id and 'true',
        'returnFaceLandmarks': landmarks and 'false',
        'returnFaceAttributes': attributes,
    }

    return util.request('POST', url, headers=headers, params=params, json=json,
                        data=data)
# Out:
# time: 6.96 ms

# %%
# generate a fake url list to replicate S3 condition

#### ATTNTION ----- change '4641' to match the number of last image+1 -----#######
#### ATTNTION ----- change '1_23_17/1_23_17___%d.jpg' to match the path and names on your S3 bucket -----#######

url_list = []
for i in range(0,2593,1):
    url = "https://s3.amazonaws.com/100daysofspice/4_24/4_4_%d.jpg" % i
    url_list.append(url)
# Out:
# time: 6.36 ms

# %%
# Face Detection & Emotion Analysis - UPDATED
processed = {}
face_detection = {}
count = 0

for single_image in url_list:
 
    try:
        face_detection[count] = detect(single_image)

        json = { 'url': single_image } 
        processed[count] = processRequest(json, data, headers, params)  
    except:
        pass

    try:
        if face_detection[count][0]['faceRectangle'] == processed[count][0]['faceRectangle']:
            face_detection[count][0].update(processed[count][0])
            face_detection[count][1].update(processed[count][1])
        if  face_detection[count][0]['faceRectangle'] == processed[count][1]['faceRectangle']:
            face_detection[count][0].update(processed[count][1])
            face_detection[count][1].update(processed[count][0])
    except:
        pass
    
    count += 1
    
#     time.sleep(3)
# Out:
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# ...
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# time: 1h 12min 32s

# %%
# face_detection
# Out:
# time: 905 µs

# %%
# Save the result as Json
#### ATTNTION ----- update '1_23_17.json' to the name of your current folder #######

import json
with open('/Users/Amiros/GitHub/100_days_of_spice/json/4_24_17.json', 'w') as fp:
    json.dump(face_detection, fp, sort_keys=True)
# Out:
# time: 174 ms

# %% [markdown]
# ## json to csv

# %%
import json
import csv
# Out:
# time: 5.94 ms

# %%
"""
This can probably be improved but serves the purpose of our analysis.
I used Chris's schema so it will be useful for Quarz analysis.

"""

EMOTIONS = [
    'contempt',
    'fear',
    'sadness',
    'disgust',
    'anger',
    'neutral',
    'happiness',
    'surprise',
]


CSV_COLUMNS = [
    'url',
    'frame_time',
    'sean_happiness',
    'sean_neutral',
    'sean_anger',
    'sean_contempt',
    'sean_suprise',
    'sean_sadness',
    'sean_fear'
]
# Out:
# time: 6.71 ms

# %%
with open('/Users/Amiros/GitHub/100_days_of_spice/json/4_24_17.json') as data_file:    
    json_data = json.load(data_file)
    
json_data = {int(k):v for k,v in json_data.items()} #converting keys to integer   
frame_keys = sorted(json_data.keys())
# Out:
# time: 25.6 ms

# %%
csv_data = []
   
for key in frame_keys:
    url = 'https://s3.amazonaws.com/100daysofspice/4_24/4_4_%d.jpg' % key
    frame = json_data[key]
        
    row = {
        #'frame': frame,
        'url': url,
        'frame_time': key,
    }
    
    if len(frame) > 1:
        for face in frame:
            if face['faceAttributes']['gender'] == 'male':
                prefix = 'sean_'
                try:
                    for emotion in EMOTIONS:
                        row[prefix + emotion] = face['scores'][emotion]
                except:
                    pass
                
            row.pop("frame", None)        
      
    elif len(frame) == 1:
        for face in frame:
            if face['faceAttributes']['gender'] == 'male':
                prefix = 'sean_'
                try:
                    for emotion in EMOTIONS:
                    #print(face['scores'][emotion])
                        row[prefix + emotion] = face['scores'][emotion]
                except:
                    pass
                ### assign emotions vale to each candidate and change the name to the respective one 
          
        row.pop("frame", None)        

    csv_data.append(row)
# Out:
# time: 38.4 ms

# %%
import pandas as pd
df = pd.DataFrame(csv_data)
# Out:
# time: 1.47 s

# %%
####### change the date here
df['data'] = '4_24_17'
df
# Out:
#       frame_time    sean_anger  sean_contempt  sean_disgust     sean_fear  \
# 0              3           NaN            NaN           NaN           NaN
# 1              4           NaN            NaN           NaN           NaN
# 2              5           NaN            NaN           NaN           NaN
# 3              6  2.697824e-02   8.187205e-03  9.487718e-03  5.371953e-05
# 4              7  2.144543e-02   1.895230e-03  7.264805e-03  2.229136e-04
# 5              8  4.752573e-02   1.464157e-02  1.305149e-02  1.307460e-04
# 6              9  2.843928e-01   8.196142e-03  3.044142e-02  2.664312e-04
# 7             10  1.418056e-01   2.438064e-03  3.358665e-02  1.707126e-03
# 8             11  1.720790e-01   1.078341e-02  6.683076e-02  7.076215e-03
# 9             12  2.309364e-01   8.821717e-03  4.411573e-02  5.864969e-03
# 10            13  2.449867e-02   8.715514e-03  1.370133e-03  8.010128e-06
# 11            14  3.831156e-02   5.653413e-03  1.990232e-03  1.109244e-05
# 12            15  1.756496e-01   4.359566e-03  2.782357e-02  9.872969e-04
# 13            16  1.616820e-01   3.044589e-02  2.401265e-02  2.016417e-04
# 14            17  1.083014e-01   7.226190e-03  4.808477e-03  5.782161e-06
# 15            18  3.876724e-01   3.216063e-03  3.722239e-02  7.374195e-04
# 16            19  1.973423e-01   8.317402e-03  5.793233e-02  1.944676e-03
# 17            20  2.490199e-01   6.770676e-03  4.489294e-02  1.432339e-03
# 18            21  1.840361e-01   4.811486e-03  3.530071e-02  2.221216e-03
# 19            22  1.324640e-01   6.348082e-03  1.218291e-03  1.718097e-05
# 20            23  2.152421e-01   1.109905e-02  6.330887e-02  2.624147e-03
# 21            24  1.856233e-01   5.944264e-03  2.946145e-03  3.820394e-05
# 22            25  2.341152e-01   5.285360e-03  2.520072e-02  5.212035e-03
# 23            26  1.825785e-01   1.511357e-02  2.480040e-02  7.985224e-04
# 24            27  2.540971e-01   5.994096e-03  2.200111e-02  3.420832e-05
# 25            28  9.050235e-02   1.531235e-02  3.493748e-02  7.451833e-03
# 26            29  5.199695e-02   1.564649e-02  8.208797e-03  4.106577e-05
# 27            30  3.719513e-02   9.082130e-03  4.671900e-02  2.920962e-03
# 28           634  2.316381e-02   3.563071e-03  8.784782e-03  2.895548e-04
# 29           635  1.876913e-02   1.521540e-03  7.665125e-03  5.230674e-04
# ...          ...           ...            ...           ...           ...
# 1485        2559  1.835524e-02   8.576092e-03  9.514576e-03  3.449323e-04
# 1486        2560  4.880378e-02   3.589472e-02  3.349155e-02  4.889028e-04
# 1487        2561  7.699572e-03   9.954717e-03  4.708024e-03  1.889291e-04
# 1488        2562  1.767295e-02   2.656128e-02  3.198238e-03  9.470337e-05
# 1489        2567  3.464422e-06   6.264253e-03  8.643234e-05  1.757268e-10
# 1490        2568  2.779774e-07   8.438731e-07  9.928213e-06  1.109460e-10
# 1491        2569  1.324738e-09   8.453640e-08  7.861674e-08  1.079206e-13
# 1492        2570  3.449295e-07   1.385902e-06  1.207663e-05  1.176130e-10
# 1493        2571  6.232628e-03   2.110873e-01  1.123700e-02  6.431095e-05
# 1494        2572  1.048493e-02   1.131674e-02  9.496775e-03  8.172277e-05
# 1495        2573  1.499593e-02   3.953309e-02  5.760663e-03  3.543001e-05
# 1496        2574  2.006663e-02   1.422954e-01  1.040960e-02  1.683409e-05
# 1497        2575  1.880031e-02   7.093670e-03  6.158528e-03  5.038930e-04
# 1498        2576  2.131346e-01   6.691861e-03  3.129933e-02  8.682739e-04
# 1499        2577  4.335920e-02   7.286248e-03  9.327344e-03  1.354412e-05
# 1500        2578  4.082322e-02   1.192383e-02  1.830290e-02  2.992063e-05
# 1501        2579  5.697710e-02   1.850785e-02  3.680953e-02  1.149466e-03
# 1502        2580  8.067907e-02   8.663955e-03  2.488988e-02  7.092040e-05
# 1503        2581  3.637969e-02   2.654258e-03  6.500771e-03  7.298001e-05
# 1504        2582  1.037555e-02   5.967935e-03  3.950686e-03  7.957721e-05
# 1505        2583  7.026881e-02   4.620167e-03  2.027729e-02  2.330590e-04
# 1506        2584  4.332079e-02   1.145695e-03  1.576667e-03  5.015921e-05
# 1507        2585  7.443113e-02   5.230298e-03  1.781075e-02  4.349673e-04
# 1508        2586  2.345443e-02   2.132781e-03  1.551215e-03  4.739415e-06
# 1509        2587  3.918670e-02   8.432137e-03  2.339731e-02  9.134960e-04
# 1510        2588  6.265263e-02   1.006213e-02  2.457969e-02  2.077825e-04
# 1511        2589  5.332346e-02   4.917377e-03  2.183505e-03  1.964281e-04
# 1512        2590  3.179541e-02   1.961278e-03  1.572875e-02  6.164762e-05
# 1513        2591  3.507222e-02   8.209566e-03  2.399737e-02  7.218526e-04
# 1514        2592  2.200360e-02   1.570829e-03  7.625351e-03  1.580351e-04
#
#       sean_happiness  sean_neutral  sean_sadness  sean_surprise  \
# 0                NaN           NaN           NaN            NaN
# 1                NaN           NaN           NaN            NaN
# 2                NaN           NaN           NaN            NaN
# 3           0.001350  9.491013e-01  1.504938e-03   3.336403e-03
# 4           0.002021  9.248473e-01  3.561560e-03   3.874224e-02
# 5           0.000806  8.992565e-01  2.100010e-02   3.587610e-03
# 6           0.000121  6.506080e-01  3.542159e-03   2.243242e-02
# 7           0.000049  6.346064e-01  9.626106e-03   1.761810e-01
# 8           0.000162  5.836228e-01  4.277128e-02   1.166746e-01
# 9           0.000103  5.328203e-01  1.718564e-02   1.601526e-01
# 10          0.000007  9.402784e-01  2.496447e-02   1.581326e-04
# 11          0.000011  9.364963e-01  1.722781e-02   2.986112e-04
# 12          0.000182  7.028362e-01  8.050436e-03   8.011135e-02
# 13          0.000073  7.560297e-01  1.105704e-02   1.649764e-02
# 14          0.000006  8.579684e-01  2.127824e-02   4.055116e-04
# 15          0.000050  5.013678e-01  4.556615e-03   6.517766e-02
# 16          0.000159  6.349453e-01  1.695917e-02   8.239940e-02
# 17          0.000226  5.831858e-01  1.166706e-02   1.028052e-01
# 18          0.000129  6.042074e-01  1.983188e-02   1.494620e-01
# 19          0.000003  8.016322e-01  5.820760e-02   1.099086e-04
# 20          0.000417  5.679798e-01  1.795946e-02   1.213693e-01
# 21          0.000007  7.959995e-01  8.692330e-03   7.493925e-04
# 22          0.000039  6.343873e-01  3.046990e-02   6.529092e-02
# 23          0.000402  7.508821e-01  1.962459e-02   5.799750e-03
# 24          0.000003  7.025186e-01  9.302662e-03   6.049249e-03
# 25          0.001304  7.365354e-01  4.181517e-02   7.214101e-02
# 26          0.000076  8.901545e-01  3.286514e-02   1.010685e-03
# 27          0.001686  5.294014e-01  3.562828e-01   1.671210e-02
# 28          0.000176  8.882810e-01  7.347927e-02   2.262054e-03
# 29          0.000122  8.774485e-01  7.507981e-02   1.887099e-02
# ...              ...           ...           ...            ...
# 1485        0.024019  9.184984e-01  1.060755e-02   1.008464e-02
# 1486        0.006886  8.476774e-01  1.609609e-02   1.066177e-02
# 1487        0.001974  9.377885e-01  3.433718e-02   3.349421e-03
# 1488        0.005296  9.362139e-01  9.324198e-03   1.638693e-03
# 1489        0.990047  3.593973e-03  4.649192e-06   4.091517e-07
# 1490        0.999947  3.906574e-05  3.144148e-06   5.181170e-08
# 1491        1.000000  2.170843e-07  1.091410e-08   2.073604e-10
# 1492        0.999911  7.342892e-05  1.086372e-06   3.554812e-07
# 1493        0.442580  3.215876e-01  2.143089e-03   5.067926e-03
# 1494        0.078974  8.807718e-01  4.395288e-03   4.479132e-03
# 1495        0.035588  8.983576e-01  2.345120e-03   3.384175e-03
# 1496        0.001057  8.176285e-01  8.001374e-03   5.250255e-04
# 1497        0.009810  9.348094e-01  8.747401e-03   1.407658e-02
# 1498        0.000993  7.039810e-01  1.026113e-02   3.277121e-02
# 1499        0.015931  9.198400e-01  3.433500e-04   3.899623e-03
# 1500        0.002008  9.220011e-01  3.390400e-03   1.520827e-03
# 1501        0.000926  7.658656e-01  1.140138e-01   5.751076e-03
# 1502        0.004378  8.666525e-01  3.819522e-03   1.084624e-02
# 1503        0.000010  9.372679e-01  4.198262e-03   1.291630e-02
# 1504        0.000322  9.215532e-01  5.702663e-02   7.240341e-04
# 1505        0.000365  8.661741e-01  2.670226e-02   1.135968e-02
# 1506        0.000002  9.236265e-01  2.977343e-02   5.050735e-04
# 1507        0.000267  8.129798e-01  4.286583e-03   8.455954e-02
# 1508        0.000015  9.603818e-01  1.237226e-02   8.809000e-05
# 1509        0.003841  8.495395e-01  6.735158e-02   7.338323e-03
# 1510        0.003948  8.648393e-01  2.931678e-03   3.077872e-02
# 1511        0.000405  9.316657e-01  3.319942e-03   3.988176e-03
# 1512        0.000385  9.208063e-01  1.110812e-02   1.815386e-02
# 1513        0.000485  8.597564e-01  4.520755e-02   2.655013e-02
# 1514        0.000183  9.121739e-01  4.996377e-02   6.321626e-03
#
#                                                     url     data
# 0     https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1     https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 2     https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 3     https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 4     https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 5     https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 6     https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 7     https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 8     https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 9     https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 10    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 11    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 12    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 13    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 14    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 15    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 16    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 17    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 18    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 19    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 20    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 21    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 22    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 23    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 24    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 25    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 26    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 27    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 28    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 29    https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# ...                                                 ...      ...
# 1485  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1486  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1487  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1488  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1489  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1490  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1491  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1492  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1493  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1494  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1495  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1496  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1497  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1498  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1499  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1500  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1501  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1502  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1503  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1504  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1505  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1506  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1507  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1508  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1509  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1510  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1511  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1512  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1513  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
# 1514  https://s3.amazonaws.com/100daysofspice/4_24/4...  4_24_17
#
# [1515 rows x 11 columns]
# time: 72 ms

# %%
#### change the name here
df.to_csv('csv/4_24_17-EMOTIONS.csv', sep=',', index=False)
# Out:
# time: 35.5 ms
