# %%
# install youtubedl library
# sudo -H pip install --upgrade youtube-dl

# %%
import os

# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime
# Out:
# ERROR:root:Line magic function `%install_ext` not found.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 5.61 ms

# %% [markdown]
# ## download youtube video

# %%
# downloading all the videos from the playlist - mp4 & highest quality
# latest: 39 videos from 1/23/17 to 4/3/17
# https://www.youtube.com/playlist?list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI

# os.system("youtube-dl -f 'bestvideo[ext=mp4]/best[ext=mp4]/best' -citk https://www.youtube.com/playlist?list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI")


# os.system("youtube-dl -f bestvideo+bestaudio https://www.youtube.com/watch?v=hTpoxrEbKFk&list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI&index=39")

# %%
## files to delet

#President Trump Holds a Press Conference-Ct0H_ndjavM.mp4
#President Trump and Prime Minister Trudeau-vqkb-sJ31S4.mp4
#President Trump and PM May Joint Press Conference-8TYCHq9cAS8.mp4
#Joint Statment by President Trump and Prime Minister Shinzō Abe-ntlqA33SL-k.mp4
#Joint Press Conference-IbpsmS2BTLo.mp4"

# %% [markdown]
# ## Extracting stills from videos

# %%
import cv2
import math
import numpy as np


cv2.__version__ # this will print the version of your opencv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-339d3a0d7db2> in <module>()
# ----> 1 import cv2
#       2 import math
#       3 import numpy as np
#       4
#       5
#
# ImportError: dlopen(/Users/Amiros/anaconda/lib/python3.6/site-packages/cv2.cpython-36m-darwin.so, 2): Library not loaded: @rpath/libpng16.16.dylib
#   Referenced from: /Users/Amiros/anaconda/lib/libopencv_imgcodecs.3.1.0.dylib
#   Reason: Incompatible library version: libopencv_imgcodecs.3.1.dylib requires version 45.0.0 or later, but libpng16.16.dylib provides version 44.0.0
# time: 135 ms

# %%
# def extract_stills(videoFile, extraction_rate, output_address, output_name):
#     """This function takes the location of a video and extract stills based on the user desired rate.
#     It requires importing cv2 and math libraries.
    
#     parameters
#     video: locaiton of the video - string
#     extraction_rate: rate of extracting stills in seconds - int"""
    
#     # setting up the file
#     vidcap = cv2.VideoCapture(videoFile)
    
#     # setting up parameters
#     seconds = 1000
#     fps = int(round(vidcap.get(cv2.CAP_PROP_FPS))) # Gets the frames per second
#     total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
#     duration = (round(total_frames/fps) -1)*1000
    
#     location = output_address + output_name + '%d.jpg'
#     #extracting every 'extraction_rate' of the video
#     for i in range(0, duration, extraction_rate * 1000):
#         vidcap.set(cv2.CAP_PROP_POS_MSEC,i)
#         success,image = vidcap.read()
#         j = i/1000
# #         return cv2.imwrite(location % j, image)     # save frame as JPEG file


# # import cv2
# # import os

# # def video_to_frames(video, path_output_dir):
# #     # extract frames from a video and save to directory as 'x.png' where 
# #     # x is the frame index
# #     vidcap = cv2.VideoCapture(video)
# #     count = 0
# #     while vidcap.isOpened():
# #         success, image = vidcap.read()
# #         if success:
# #             cv2.imwrite(os.path.join(path_output_dir, '%d.png') % count, image)
# #             count += 1
# #         else:
# #             break
# #     cv2.destroyAllWindows()
# #     vidcap.release()

# # video_to_frames('../somepath/myvid.mp4', '../somepath/out')

# %%
# # fourcc = cv2.VideoWriter_fourcc(*'H264')

# # setting up the file
# videoFile = '/Users/Amiros/GitHub/100_days_of_spice/3_31_17 - White House Press Briefing-Nr8Mu0-vPsQ.mp4'
# vidcap = cv2.VideoCapture(videoFile)
# success,image = vidcap.read()

# # setting up parameters
# seconds = 1000
# fps = int(round(vidcap.get(cv2.CAP_PROP_FPS))) # Gets the frames per second
# total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
# duration = (round(total_frames/fps) -1)*1000

# #extracting every 'second' of the video
# for i in range(0, duration, seconds):
#     vidcap.set(cv2.CAP_PROP_POS_MSEC,i)
#     success,image = vidcap.read()
#     j = i/1000
#     cv2.imwrite("/Users/Amiros/GitHub/100_days_of_spice/images/4_3_17/4_3_17__%d.jpg" % j, image)     # save frame as JPEG file

# %% [markdown]
# ## Detecting Sean's face

# %%
# from cognitive_face import face as CF
# from urllib3 import util

# %%
# KEY = 'e3b77a2e317244f2a7198e9387190a64'
# CF.Key.set(KEY)

# %%
# img_url = 'http://i2.cdn.cnn.com/cnnnext/dam/assets/170121181022-sean-spicer-donald-trump-inauguration-crowd-bts-00002515-large-169.jpg'
# result = CF.detect(img_url)

# %%
# CF.detect('https://upload.wikimedia.org/wikipedia/commons/3/3f/Press_secretary_Sean_Spicer.jpg')
# # CF.detect('https://img.washingtonpost.com/wp-apps/imrs.php?src=https://img.washingtonpost.com/rf/image_960w/2010-2019/WashingtonPost/2017/01/25/Production/Daily/A-Section/Images/AFP_KO6YL.jpg&w=480')

# %%
# face_ids = ['e13dd2b8-c9a4-4035-86a8-6b37ac6ce77b', '2850cf17-4ea9-4285-86bb-d29c703338f1', '92f34cee-7038-476a-827c-b6f1e31de989']

# CF.group(face_ids)

# %%
# CF.find_similars(help)

# %% [markdown]
# # Detecting emotions

# %%
import http.client, urllib, base64, requests
import cognitive_face as CF 
from cognitive_face import util
import time
import os

# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime
# Out:
# ERROR:root:Line magic function `%install_ext` not found.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 6.02 ms

# %%
#Emotion Analysis parameters
_url = 'https://api.projectoxford.ai/emotion/v1.0/recognize'
_key = '167a95eae08446f0a00b4568c045b97b'  ######### Here you have to paste your primary key for EMOTION API
_maxNumRetries = 5

#Face detection parametrs
CF.Key.set('bee19ea2a47e4a6eb64e23e969a6df6e') ######### set the key for FACE API
# Out:
# time: 2.41 ms

# %%
# Image path
urlImage= ''

# Emtional Anlaysis function
def processRequest( json, data, headers, params ):

    retries = 0
    result = None

    while True:

        response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )

        if response.status_code == 429: 

            print( "Message: %s" % ( response.json()['error']['message'] ) )

            if retries <= _maxNumRetries: 
                time.sleep(1) 
                retries += 1
                continue
            else: 
                print( 'Error: failed after retrying!' )
                break

        elif response.status_code == 200 or response.status_code == 201:

            if 'content-length' in response.headers and int(response.headers['content-length']) == 0: 
                result = None 
            elif 'content-type' in response.headers and isinstance(response.headers['content-type'], str): 
                if 'application/json' in response.headers['content-type'].lower(): 
                    result = response.json() if response.content else None 
                elif 'image' in response.headers['content-type'].lower(): 
                    result = response.content
        else:
            print( "Error code: %d" % ( response.status_code ) )
            print( "Message: %s" % ( response.json()['error']['message'] ) )

        break
        
    return result


headers = dict()
headers['Ocp-Apim-Subscription-Key'] = _key
headers['Content-Type'] = 'application/json' 

json = { 'url': urlImage } 
data = None
params = None
# Out:
# time: 36 ms

# %%
# Face detect function
def detect(image, face_id=True, landmarks=False, faceRectangle= False, attributes='gender'):
    
    url = 'detect'
    headers, data, json = util.parse_image(image)
    params = {
        'returnFaceId': face_id and 'true',
        'returnFaceLandmarks': landmarks and 'false',
        'returnFaceAttributes': attributes,
    }

    return util.request('POST', url, headers=headers, params=params, json=json,
                        data=data)
# Out:
# time: 6.47 ms

# %%
# generate a fake url list to replicate S3 condition

#### ATTNTION ----- change '4641' to match the number of last image+1 -----#######
#### ATTNTION ----- change '1_23_17/1_23_17___%d.jpg' to match the path and names on your S3 bucket -----#######

url_list = []
for i in range(0,4185,1):
    url = "https://s3.amazonaws.com/100daysofspice/3_16_17/3_16_17___%d.jpg" % i
    url_list.append(url)
# Out:
# time: 6.06 ms

# %%
# Face Detection & Emotion Analysis - UPDATED
processed = {}
face_detection = {}
count = 0

for single_image in url_list:
 
    try:
        face_detection[count] = detect(single_image)

        json = { 'url': single_image } 
        processed[count] = processRequest(json, data, headers, params)  
    except:
        pass

    try:
        if face_detection[count][0]['faceRectangle'] == processed[count][0]['faceRectangle']:
            face_detection[count][0].update(processed[count][0])
            face_detection[count][1].update(processed[count][1])
        if  face_detection[count][0]['faceRectangle'] == processed[count][1]['faceRectangle']:
            face_detection[count][0].update(processed[count][1])
            face_detection[count][1].update(processed[count][0])
    except:
        pass
    
    count += 1
    
    time.sleep(3)

# %%
face_detection
# Out:
# {0: [],
#  1: [],
#  2: [],
#  3: [],
#  4: [],
#  5: [],
#  6: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '148cdbd2-bf43-436f-9525-843e28f0e15e',
#    'faceRectangle': {'height': 48, 'left': 358, 'top': 108, 'width': 48},
#    'scores': {'anger': 0.00134895591,
#     'contempt': 0.009784123,
#     'disgust': 0.00127266836,
#     'fear': 5.38163949e-05,
#     'happiness': 0.813742638,
#     'neutral': 0.1649807,
#     'sadness': 0.004352403,
#     'surprise': 0.00446470268}}],
#  7: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6e635149-61af-4fe7-8715-057168d6e2f3',
#    'faceRectangle': {'height': 67, 'left': 319, 'top': 122, 'width': 67},
#    'scores': {'anger': 0.0069143055,
#     'contempt': 0.0105235586,
#     'disgust': 0.00682614371,
#     'fear': 0.000546144845,
#     'happiness': 0.5313963,
#     'neutral': 0.406139016,
#     'sadness': 0.03095454,
#     'surprise': 0.0066999644}}],
#  8: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '495398aa-2388-40b5-a6ae-2afc5de607d2',
#    'faceRectangle': {'height': 70, 'left': 237, 'top': 118, 'width': 70},
#    'scores': {'anger': 0.04642361,
#     'contempt': 0.0204480328,
#     'disgust': 0.026499778,
#     'fear': 0.00291013,
#     'happiness': 0.16226466,
#     'neutral': 0.6930869,
#     'sadness': 0.03770162,
#     'surprise': 0.0106652686}}],
#  9: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '674eeade-7ead-475e-b615-c35fd0e70f97',
#    'faceRectangle': {'height': 75, 'left': 228, 'top': 99, 'width': 75},
#    'scores': {'anger': 0.00372418179,
#     'contempt': 0.0063731866,
#     'disgust': 0.00110084924,
#     'fear': 9.610599e-06,
#     'happiness': 0.000493885833,
#     'neutral': 0.9821818,
#     'sadness': 0.00589337945,
#     'surprise': 0.000223138064}}],
#  10: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'f01fe92f-7500-43f6-be5a-ea699fbabe4b',
#    'faceRectangle': {'height': 73, 'left': 225, 'top': 117, 'width': 73}}],
#  11: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6ce7e588-3ec8-4de5-9bde-ce0779cc5503',
#    'faceRectangle': {'height': 71, 'left': 258, 'top': 121, 'width': 71},
#    'scores': {'anger': 0.00884419,
#     'contempt': 0.00038292128,
#     'disgust': 0.000425765815,
#     'fear': 1.65137317e-06,
#     'happiness': 3.54728036e-06,
#     'neutral': 0.8074806,
#     'sadness': 0.1828466,
#     'surprise': 1.47427481e-05}}],
#  12: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'dae872db-250b-4521-9776-c9bf862583a0',
#    'faceRectangle': {'height': 72, 'left': 265, 'top': 122, 'width': 72},
#    'scores': {'anger': 0.00162017671,
#     'contempt': 0.000349081,
#     'disgust': 0.0003460818,
#     'fear': 1.46787954e-06,
#     'happiness': 4.61997661e-05,
#     'neutral': 0.901064038,
#     'sadness': 0.0965555757,
#     'surprise': 1.73565313e-05}}],
#  13: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'f209974c-70cc-48c0-a7c9-d634cad29113',
#    'faceRectangle': {'height': 80, 'left': 285, 'top': 93, 'width': 80},
#    'scores': {'anger': 0.102544427,
#     'contempt': 0.006512674,
#     'disgust': 0.0139377108,
#     'fear': 5.45930379e-05,
#     'happiness': 0.002917218,
#     'neutral': 0.839277565,
#     'sadness': 0.000584012538,
#     'surprise': 0.0341718122}}],
#  14: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e8006bde-af54-4cb7-9ea6-2f328be586e2',
#    'faceRectangle': {'height': 72, 'left': 273, 'top': 123, 'width': 72},
#    'scores': {'anger': 0.00415689731,
#     'contempt': 0.000375432457,
#     'disgust': 0.00100974273,
#     'fear': 1.61176322e-05,
#     'happiness': 0.00047376717,
#     'neutral': 0.964642942,
#     'sadness': 0.0283635184,
#     'surprise': 0.000961597543}}],
#  15: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '139185b7-eb3a-4e6e-b0ae-c643e07f6ee8',
#    'faceRectangle': {'height': 74, 'left': 276, 'top': 115, 'width': 74},
#    'scores': {'anger': 0.00321585941,
#     'contempt': 0.00041342,
#     'disgust': 0.000453468849,
#     'fear': 1.00516982e-05,
#     'happiness': 0.000225147145,
#     'neutral': 0.955657065,
#     'sadness': 0.039620854,
#     'surprise': 0.000404145976}}],
#  16: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6ec7a42f-a93b-4ab1-bcb1-f51f014e3f60',
#    'faceRectangle': {'height': 79, 'left': 281, 'top': 88, 'width': 79},
#    'scores': {'anger': 0.308558464,
#     'contempt': 0.0105765611,
#     'disgust': 0.06856851,
#     'fear': 0.0009576597,
#     'happiness': 0.000270754244,
#     'neutral': 0.5707875,
#     'sadness': 0.00591688836,
#     'surprise': 0.0343636833}}],
#  17: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '2ef6dd95-9c1b-4cc5-b8ab-5874ab8f8e33',
#    'faceRectangle': {'height': 76, 'left': 279, 'top': 84, 'width': 76},
#    'scores': {'anger': 0.007978322,
#     'contempt': 0.00469408,
#     'disgust': 0.010464618,
#     'fear': 0.00039089346,
#     'happiness': 0.00231883023,
#     'neutral': 0.916068,
#     'sadness': 0.01499535,
#     'surprise': 0.0430899076}}],
#  18: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e510d032-6521-4737-b1ae-c8ae62f10082',
#    'faceRectangle': {'height': 76, 'left': 298, 'top': 86, 'width': 76},
#    'scores': {'anger': 0.0118251387,
#     'contempt': 0.00589272939,
#     'disgust': 0.00330297532,
#     'fear': 0.00013012925,
#     'happiness': 0.0010439147,
#     'neutral': 0.964203238,
#     'sadness': 0.00288081565,
#     'surprise': 0.01072107}}],
#  19: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'aa323de2-40dd-44f3-aa7a-932c116cc9a9',
#    'faceRectangle': {'height': 77, 'left': 294, 'top': 85, 'width': 77},
#    'scores': {'anger': 0.120455869,
#     'contempt': 0.0005669884,
#     'disgust': 0.0271234754,
#     'fear': 4.27790874e-05,
#     'happiness': 0.000225978089,
#     'neutral': 0.6653344,
#     'sadness': 0.00151340885,
#     'surprise': 0.184737131}}],
#  20: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '863e86cd-6b75-4e54-9b5f-3e98a29cd6d2',
#    'faceRectangle': {'height': 77, 'left': 294, 'top': 88, 'width': 77},
#    'scores': {'anger': 0.033499524,
#     'contempt': 0.00141524384,
#     'disgust': 0.0112876613,
#     'fear': 0.003972099,
#     'happiness': 5.721732e-05,
#     'neutral': 0.802210152,
#     'sadness': 0.0179983843,
#     'surprise': 0.1295597}}],
#  21: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9a6d76f6-8319-415e-a46d-b1481ca44bed',
#    'faceRectangle': {'height': 80, 'left': 280, 'top': 88, 'width': 80},
#    'scores': {'anger': 0.01254012,
#     'contempt': 0.0009204357,
#     'disgust': 0.00190830964,
#     'fear': 0.0004115509,
#     'happiness': 9.857154e-06,
#     'neutral': 0.952159643,
#     'sadness': 0.008471744,
#     'surprise': 0.0235783383}}],
#  22: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '34ea450f-828c-41e7-898e-435e34809475',
#    'faceRectangle': {'height': 81, 'left': 265, 'top': 89, 'width': 81},
#    'scores': {'anger': 0.100183815,
#     'contempt': 0.006340906,
#     'disgust': 0.0500315838,
#     'fear': 0.000272781,
#     'happiness': 0.0007593273,
#     'neutral': 0.7841572,
#     'sadness': 0.00740389433,
#     'surprise': 0.050850492}}],
#  23: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '39fcb002-7f25-4595-8ffb-256009125c74',
#    'faceRectangle': {'height': 79, 'left': 230, 'top': 89, 'width': 79},
#    'scores': {'anger': 0.105983563,
#     'contempt': 0.0109670395,
#     'disgust': 0.03184687,
#     'fear': 6.421258e-05,
#     'happiness': 0.000756794238,
#     'neutral': 0.7899383,
#     'sadness': 0.00604751846,
#     'surprise': 0.0543957}}],
#  24: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'cca8f172-b963-489d-9ca7-36072458f3d7',
#    'faceRectangle': {'height': 74, 'left': 253, 'top': 94, 'width': 74},
#    'scores': {'anger': 0.0310972333,
#     'contempt': 0.002063449,
#     'disgust': 0.01421464,
#     'fear': 0.00264953868,
#     'happiness': 0.000376658165,
#     'neutral': 0.8549261,
#     'sadness': 0.0389689021,
#     'surprise': 0.0557034872}}],
#  25: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '88f61e8e-9ec6-455b-9d22-994d527e5fb5',
#    'faceRectangle': {'height': 77, 'left': 242, 'top': 91, 'width': 77},
#    'scores': {'anger': 0.00611958932,
#     'contempt': 0.0151568353,
#     'disgust': 0.007243224,
#     'fear': 3.165453e-05,
#     'happiness': 0.02236577,
#     'neutral': 0.9433801,
#     'sadness': 0.00289077475,
#     'surprise': 0.00281202048}}],
#  26: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8e951e59-ddd8-4d76-a867-3c9bd482183b',
#    'faceRectangle': {'height': 77, 'left': 232, 'top': 89, 'width': 77},
#    'scores': {'anger': 0.000394317234,
#     'contempt': 0.0664639547,
#     'disgust': 0.00135331182,
#     'fear': 2.9550547e-06,
#     'happiness': 0.5104244,
#     'neutral': 0.415377527,
#     'sadness': 0.000171839478,
#     'surprise': 0.005811683}}],
#  27: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c0df26c0-2022-4797-8abb-d7e10b044c94',
#    'faceRectangle': {'height': 71, 'left': 256, 'top': 91, 'width': 71},
#    'scores': {'anger': 0.0116008474,
#     'contempt': 0.0164690185,
#     'disgust': 0.0168014336,
#     'fear': 0.0003813622,
#     'happiness': 0.0197309777,
#     'neutral': 0.895414054,
#     'sadness': 0.0277951956,
#     'surprise': 0.0118071232}}],
#  28: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1dac1761-68c6-4119-908a-3f3d1f1ccb37',
#    'faceRectangle': {'height': 55, 'left': 240, 'top': 121, 'width': 55},
#    'scores': {'anger': 0.0455702767,
#     'contempt': 0.001884138,
#     'disgust': 0.0403792672,
#     'fear': 0.007757175,
#     'happiness': 0.0111801466,
#     'neutral': 0.6120233,
#     'sadness': 0.208194688,
#     'surprise': 0.07301104}}],
#  29: [],
#  30: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6d754e00-b530-4c9d-8a67-05d3d32b136d',
#    'faceRectangle': {'height': 53, 'left': 187, 'top': 109, 'width': 53},
#    'scores': {'anger': 0.0103195012,
#     'contempt': 0.00241470034,
#     'disgust': 0.00165814534,
#     'fear': 0.000353173527,
#     'happiness': 0.0708432049,
#     'neutral': 0.890813231,
#     'sadness': 0.0188048,
#     'surprise': 0.00479322346}}],
#  31: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b1691734-7e9f-48de-b2b4-3d09289dbee3',
#    'faceRectangle': {'height': 53, 'left': 284, 'top': 120, 'width': 53},
#    'scores': {'anger': 0.0019350081,
#     'contempt': 0.000675983145,
#     'disgust': 0.0009685782,
#     'fear': 4.83434e-05,
#     'happiness': 0.0131316921,
#     'neutral': 0.9313727,
#     'sadness': 0.0507401675,
#     'surprise': 0.00112750544}}],
#  32: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'a616134d-1d7b-4451-b630-f95e53a39b85',
#    'faceRectangle': {'height': 61, 'left': 233, 'top': 108, 'width': 61},
#    'scores': {'anger': 0.00220772345,
#     'contempt': 0.0193989836,
#     'disgust': 0.0013807097,
#     'fear': 0.000238164139,
#     'happiness': 0.6241695,
#     'neutral': 0.3424686,
#     'sadness': 0.00377275213,
#     'surprise': 0.00636354228}}],
#  33: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e7e6b74c-ec45-43f2-81c3-1aa2baa033dd',
#    'faceRectangle': {'height': 66, 'left': 215, 'top': 101, 'width': 66},
#    'scores': {'anger': 0.0237457566,
#     'contempt': 0.0284145847,
#     'disgust': 0.00276826718,
#     'fear': 0.00157420035,
#     'happiness': 0.00544444565,
#     'neutral': 0.8308767,
#     'sadness': 0.001845316,
#     'surprise': 0.105330721}}],
#  34: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '5586b222-70fd-4399-969f-7e4c7686138a',
#    'faceRectangle': {'height': 63, 'left': 256, 'top': 107, 'width': 63},
#    'scores': {'anger': 0.008461392,
#     'contempt': 0.0263134446,
#     'disgust': 0.003054511,
#     'fear': 0.0006878712,
#     'happiness': 0.0690186843,
#     'neutral': 0.867791951,
#     'sadness': 0.00275148987,
#     'surprise': 0.0219206363}}],
#  35: [],
#  36: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ccafdfab-ad06-4c4b-9a31-dcb302d46f6b',
#    'faceRectangle': {'height': 60, 'left': 274, 'top': 105, 'width': 60},
#    'scores': {'anger': 0.00357294525,
#     'contempt': 0.0001554228,
#     'disgust': 0.000138291012,
#     'fear': 1.20297382e-05,
#     'happiness': 5.05759454e-05,
#     'neutral': 0.9910378,
#     'sadness': 0.0008236172,
#     'surprise': 0.004209348}}],
#  37: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '0cb2c499-b418-49e5-b709-3d11c9db363f',
#    'faceRectangle': {'height': 57, 'left': 251, 'top': 114, 'width': 57},
#    'scores': {'anger': 0.00429854775,
#     'contempt': 0.00214942056,
#     'disgust': 0.0008266453,
#     'fear': 1.10823994e-05,
#     'happiness': 0.0004244109,
#     'neutral': 0.976146042,
#     'sadness': 0.0156655554,
#     'surprise': 0.000478317}}],
#  38: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'd38b8724-40db-4f37-9f31-338c6b48b147',
#    'faceRectangle': {'height': 62, 'left': 225, 'top': 98, 'width': 62},
#    'scores': {'anger': 0.004233518,
#     'contempt': 0.0130088162,
#     'disgust': 0.00376587175,
#     'fear': 0.00125147216,
#     'happiness': 0.005945422,
#     'neutral': 0.9333681,
#     'sadness': 0.00368879875,
#     'surprise': 0.03473801}}],
#  39: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'af74700e-5c4e-430f-a15e-c1f8ecba74ca',
#    'faceRectangle': {'height': 61, 'left': 225, 'top': 92, 'width': 61},
#    'scores': {'anger': 3.71320966e-05,
#     'contempt': 9.564728e-06,
#     'disgust': 3.03729976e-05,
#     'fear': 1.38141388e-06,
#     'happiness': 0.997959256,
#     'neutral': 0.00120004162,
#     'sadness': 3.26498434e-06,
#     'surprise': 0.0007589673}}],
#  40: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '85113e35-6225-43af-b5b2-5ec57d374530',
#    'faceRectangle': {'height': 67, 'left': 232, 'top': 93, 'width': 67},
#    'scores': {'anger': 0.0170348231,
#     'contempt': 0.010717622,
#     'disgust': 0.005869211,
#     'fear': 0.00145729131,
#     'happiness': 0.2333269,
#     'neutral': 0.636317849,
#     'sadness': 0.00289718877,
#     'surprise': 0.09237912}}],
#  41: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1ba237e1-811e-4d6f-acf5-1d8458eaf076',
#    'faceRectangle': {'height': 60, 'left': 255, 'top': 104, 'width': 60},
#    'scores': {'anger': 0.00725358,
#     'contempt': 0.008037906,
#     'disgust': 0.00521599,
#     'fear': 7.850652e-05,
#     'happiness': 0.0289722644,
#     'neutral': 0.936814845,
#     'sadness': 0.0109548038,
#     'surprise': 0.00267210742}}],
#  42: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '281743e5-bd23-4d9e-9c02-c71dce5e6d2b',
#    'faceRectangle': {'height': 71, 'left': 276, 'top': 88, 'width': 71},
#    'scores': {'anger': 0.0258,
#     'contempt': 0.000719561533,
#     'disgust': 0.0021396142,
#     'fear': 0.0003916892,
#     'happiness': 0.00122089684,
#     'neutral': 0.698365748,
#     'sadness': 0.0020904867,
#     'surprise': 0.26927197}}],
#  43: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '324368d4-fbbf-4722-b048-c86223b08d3f',
#    'faceRectangle': {'height': 71, 'left': 253, 'top': 88, 'width': 71},
#    'scores': {'anger': 0.0151165584,
#     'contempt': 0.00227029133,
#     'disgust': 0.00249471143,
#     'fear': 0.000761999341,
#     'happiness': 0.00390617386,
#     'neutral': 0.816613436,
#     'sadness': 0.002385511,
#     'surprise': 0.156451315}}],
#  44: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'edadffc9-9b39-4c33-adf3-d86e712ba5d6',
#    'faceRectangle': {'height': 65, 'left': 235, 'top': 100, 'width': 65},
#    'scores': {'anger': 0.0075737657,
#     'contempt': 0.00744536,
#     'disgust': 0.009210274,
#     'fear': 3.13411547e-05,
#     'happiness': 0.0146961361,
#     'neutral': 0.9431324,
#     'sadness': 0.0173977874,
#     'surprise': 0.0005129245}}],
#  45: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'cf33827d-ea9d-4fd6-a24c-869d133864a9',
#    'faceRectangle': {'height': 71, 'left': 228, 'top': 83, 'width': 71},
#    'scores': {'anger': 0.004119766,
#     'contempt': 0.00748957926,
#     'disgust': 0.002675057,
#     'fear': 0.000669941364,
#     'happiness': 0.0112807164,
#     'neutral': 0.95343405,
#     'sadness': 0.00321136345,
#     'surprise': 0.0171195231}}],
#  46: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '63095c9c-5be4-4f5c-9b54-5727dc821df1',
#    'faceRectangle': {'height': 70, 'left': 228, 'top': 84, 'width': 70},
#    'scores': {'anger': 0.007008573,
#     'contempt': 0.0143841151,
#     'disgust': 0.00929464,
#     'fear': 0.000266513758,
#     'happiness': 0.4022947,
#     'neutral': 0.5601899,
#     'sadness': 0.004846204,
#     'surprise': 0.00171538524}}],
#  47: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ce851064-72ac-4631-a088-dda757bc16f3',
#    'faceRectangle': {'height': 67, 'left': 227, 'top': 94, 'width': 67},
#    'scores': {'anger': 0.00248259283,
#     'contempt': 0.00366251776,
#     'disgust': 0.00111584645,
#     'fear': 3.236951e-05,
#     'happiness': 0.00134880748,
#     'neutral': 0.973287,
#     'sadness': 0.016788207,
#     'surprise': 0.00128269359}}],
#  48: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '0896032d-28ab-4ce4-b887-88125d0c2c36',
#    'faceRectangle': {'height': 70, 'left': 265, 'top': 88, 'width': 70},
#    'scores': {'anger': 0.0111126071,
#     'contempt': 0.00364101748,
#     'disgust': 0.00466217147,
#     'fear': 0.000396273972,
#     'happiness': 0.00678145327,
#     'neutral': 0.888262868,
#     'sadness': 0.002284498,
#     'surprise': 0.08285914}}],
#  49: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ea1f19f2-e04f-436e-975f-51dd78469495',
#    'faceRectangle': {'height': 63, 'left': 268, 'top': 93, 'width': 63},
#    'scores': {'anger': 0.0106284516,
#     'contempt': 0.006229254,
#     'disgust': 0.0103913564,
#     'fear': 0.000762268668,
#     'happiness': 0.0048067593,
#     'neutral': 0.8516834,
#     'sadness': 0.0056572957,
#     'surprise': 0.10984125}}],
#  50: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'aedd5f4f-d355-47f4-a744-c28e805ea0b4',
#    'faceRectangle': {'height': 73, 'left': 227, 'top': 80, 'width': 73},
#    'scores': {'anger': 0.00330403284,
#     'contempt': 0.00520735048,
#     'disgust': 0.00189330475,
#     'fear': 7.666963e-05,
#     'happiness': 0.00148675242,
#     'neutral': 0.9839996,
#     'sadness': 0.00184139656,
#     'surprise': 0.002190904}}],
#  51: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '2fc44fa4-c9bc-4378-9a1f-359e516f6a4e',
#    'faceRectangle': {'height': 62, 'left': 265, 'top': 100, 'width': 62},
#    'scores': {'anger': 0.0221003033,
#     'contempt': 0.0274077561,
#     'disgust': 0.0263720378,
#     'fear': 0.0008767964,
#     'happiness': 0.399383932,
#     'neutral': 0.480291128,
#     'sadness': 0.04099567,
#     'surprise': 0.00257236045}}],
#  52: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'feed4352-e074-4fac-8d68-1c6766d3069b',
#    'faceRectangle': {'height': 66, 'left': 243, 'top': 104, 'width': 66},
#    'scores': {'anger': 0.00174044422,
#     'contempt': 0.0149885584,
#     'disgust': 0.001442956,
#     'fear': 9.870001e-06,
#     'happiness': 0.00794715,
#     'neutral': 0.96699053,
#     'sadness': 0.005640115,
#     'surprise': 0.00124035683}}],
#  53: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b10ae33b-e8de-49f4-b884-0a084fe8f9e1',
#    'faceRectangle': {'height': 70, 'left': 264, 'top': 96, 'width': 70},
#    'scores': {'anger': 0.0103450678,
#     'contempt': 0.005754675,
#     'disgust': 0.00107294589,
#     'fear': 0.000376882672,
#     'happiness': 0.001502232,
#     'neutral': 0.941289842,
#     'sadness': 0.00351612875,
#     'surprise': 0.0361422524}}],
#  54: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1127d924-3f6b-4a0c-9270-6e4f923513a9',
#    'faceRectangle': {'height': 67, 'left': 236, 'top': 107, 'width': 67},
#    'scores': {'anger': 0.00131518766,
#     'contempt': 0.00693625538,
#     'disgust': 0.0009214665,
#     'fear': 1.33775814e-06,
#     'happiness': 0.00126246817,
#     'neutral': 0.9851283,
#     'sadness': 0.00412796251,
#     'surprise': 0.000307019742}}],
#  55: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1bd2593f-1b03-4d9d-8c2d-5a8c1fb68bad',
#    'faceRectangle': {'height': 68, 'left': 224, 'top': 113, 'width': 68},
#    'scores': {'anger': 0.0266202036,
#     'contempt': 0.0143966554,
#     'disgust': 0.0199773721,
#     'fear': 0.000947805354,
#     'happiness': 0.0537471175,
#     'neutral': 0.8541308,
#     'sadness': 0.0173106026,
#     'surprise': 0.0128694614}}],
#  56: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '01026695-c329-4499-a6dc-b73a4a8d5a11',
#    'faceRectangle': {'height': 69, 'left': 226, 'top': 112, 'width': 69},
#    'scores': {'anger': 0.004401736,
#     'contempt': 0.00259793829,
#     'disgust': 0.00198239321,
#     'fear': 9.050503e-05,
#     'happiness': 0.0019299041,
#     'neutral': 0.962956369,
#     'sadness': 0.02439375,
#     'surprise': 0.00164742244}}],
#  57: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6e26d8b7-0d44-42a9-96b5-53f295932f69',
#    'faceRectangle': {'height': 73, 'left': 270, 'top': 104, 'width': 73},
#    'scores': {'anger': 0.00305237272,
#     'contempt': 0.00119795452,
#     'disgust': 0.0007268609,
#     'fear': 0.000200392751,
#     'happiness': 0.0005436735,
#     'neutral': 0.959902644,
#     'sadness': 0.00351245888,
#     'surprise': 0.0308636148}}],
#  58: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '81a29b1c-b155-4b76-bd24-022563fb430b',
#    'faceRectangle': {'height': 69, 'left': 228, 'top': 114, 'width': 69},
#    'scores': {'anger': 0.00275103562,
#     'contempt': 0.0114037152,
#     'disgust': 0.004263521,
#     'fear': 0.000138398245,
#     'happiness': 0.16625151,
#     'neutral': 0.804030657,
#     'sadness': 0.00780474255,
#     'surprise': 0.00335644186}}],
#  59: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '52204d7c-7f97-41f6-97e9-91447c3fcaa3',
#    'faceRectangle': {'height': 72, 'left': 205, 'top': 110, 'width': 72},
#    'scores': {'anger': 0.03323251,
#     'contempt': 0.02277909,
#     'disgust': 0.019552974,
#     'fear': 0.0007854863,
#     'happiness': 0.0421713553,
#     'neutral': 0.8623726,
#     'sadness': 0.00521865534,
#     'surprise': 0.01388734}}],
#  60: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '232a5db6-4172-42e1-8e2f-5a72c888ffe5',
#    'faceRectangle': {'height': 75, 'left': 258, 'top': 94, 'width': 75},
#    'scores': {'anger': 0.0187870134,
#     'contempt': 0.00955992751,
#     'disgust': 0.005965273,
#     'fear': 0.00244601467,
#     'happiness': 0.00376848434,
#     'neutral': 0.9343274,
#     'sadness': 0.002477932,
#     'surprise': 0.0226679482}}],
#  61: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8128c686-4dd0-4716-94a2-4ad31a83b210',
#    'faceRectangle': {'height': 78, 'left': 313, 'top': 95, 'width': 78},
#    'scores': {'anger': 0.00696025463,
#     'contempt': 0.00149629521,
#     'disgust': 0.0014704474,
#     'fear': 0.00335435476,
#     'happiness': 0.002499963,
#     'neutral': 0.777836263,
#     'sadness': 0.00381972874,
#     'surprise': 0.20256269}}],
#  62: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e958265c-844f-438d-9291-f8517a71dc14',
#    'faceRectangle': {'height': 74, 'left': 256, 'top': 100, 'width': 74},
#    'scores': {'anger': 0.0400580131,
#     'contempt': 0.00716858031,
#     'disgust': 0.019603502,
#     'fear': 0.00183251128,
#     'happiness': 0.00280259922,
#     'neutral': 0.8897177,
#     'sadness': 0.00286405836,
#     'surprise': 0.0359530374}}],
#  63: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'a838f856-1342-44a4-9069-fcb5557bce78',
#    'faceRectangle': {'height': 68, 'left': 235, 'top': 119, 'width': 68},
#    'scores': {'anger': 0.00624536024,
#     'contempt': 0.00405956,
#     'disgust': 0.003681159,
#     'fear': 0.0001566183,
#     'happiness': 0.0186618716,
#     'neutral': 0.945731342,
#     'sadness': 0.0188793484,
#     'surprise': 0.00258474587}}],
#  64: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '2f0e3a4f-16f9-4a53-8185-7efbbc76403e',
#    'faceRectangle': {'height': 70, 'left': 238, 'top': 116, 'width': 70},
#    'scores': {'anger': 0.00272776978,
#     'contempt': 0.00463719945,
#     'disgust': 0.002515589,
#     'fear': 0.0002184301,
#     'happiness': 0.0111067425,
#     'neutral': 0.954584539,
#     'sadness': 0.006003392,
#     'surprise': 0.0182063114}}],
#  65: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '563fff2c-036e-4c7d-acd4-6bbf0de49141',
#    'faceRectangle': {'height': 71, 'left': 220, 'top': 111, 'width': 71},
#    'scores': {'anger': 1.0529463e-05,
#     'contempt': 7.99079953e-06,
#     'disgust': 2.42161718e-06,
#     'fear': 8.480914e-08,
#     'happiness': 0.9999476,
#     'neutral': 2.79582728e-05,
#     'sadness': 6.874531e-07,
#     'surprise': 2.70218925e-06}}],
#  66: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '382f5b7f-c070-4d5a-96f7-1ffa632d9ce5',
#    'faceRectangle': {'height': 69, 'left': 243, 'top': 109, 'width': 69},
#    'scores': {'anger': 0.00300994632,
#     'contempt': 0.012688648,
#     'disgust': 0.00563785,
#     'fear': 3.9354858e-05,
#     'happiness': 0.022511499,
#     'neutral': 0.94083035,
#     'sadness': 0.0146114966,
#     'surprise': 0.0006708602}}],
#  67: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8c9c7deb-5b77-4099-822d-399e553fb5cb',
#    'faceRectangle': {'height': 78, 'left': 274, 'top': 86, 'width': 78},
#    'scores': {'anger': 0.002406024,
#     'contempt': 0.002875657,
#     'disgust': 0.000817776658,
#     'fear': 0.000171852,
#     'happiness': 0.004701476,
#     'neutral': 0.923229754,
#     'sadness': 0.0008201588,
#     'surprise': 0.0649773}}],
#  68: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9b68a0a7-e42e-4113-9e0a-b9054b5b608a',
#    'faceRectangle': {'height': 70, 'left': 230, 'top': 100, 'width': 70},
#    'scores': {'anger': 0.00608837139,
#     'contempt': 0.008300116,
#     'disgust': 0.006539486,
#     'fear': 0.000142967416,
#     'happiness': 0.0336797461,
#     'neutral': 0.93452704,
#     'sadness': 0.008115742,
#     'surprise': 0.00260651461}}],
#  69: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '69ca3d12-aeb5-48e9-b7e3-53cba29cd6fc',
#    'faceRectangle': {'height': 75, 'left': 209, 'top': 90, 'width': 75},
#    'scores': {'anger': 0.00277077057,
#     'contempt': 0.0243295562,
#     'disgust': 0.004042732,
#     'fear': 0.0005185837,
#     'happiness': 0.03175403,
#     'neutral': 0.924556136,
#     'sadness': 0.005641321,
#     'surprise': 0.00638687843}}],
#  70: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '2094eb03-91a5-49db-b550-75d114e7c74d',
#    'faceRectangle': {'height': 68, 'left': 222, 'top': 100, 'width': 68},
#    'scores': {'anger': 0.00449350337,
#     'contempt': 0.007027778,
#     'disgust': 0.003233834,
#     'fear': 0.0002997931,
#     'happiness': 0.028716201,
#     'neutral': 0.9326601,
#     'sadness': 0.0188631546,
#     'surprise': 0.004705636}}],
#  71: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '42facb2c-faa6-4368-848d-43fa5df989c9',
#    'faceRectangle': {'height': 71, 'left': 226, 'top': 98, 'width': 71},
#    'scores': {'anger': 0.001574394,
#     'contempt': 0.00726621132,
#     'disgust': 0.00264262012,
#     'fear': 4.902027e-05,
#     'happiness': 0.0981159359,
#     'neutral': 0.863042831,
#     'sadness': 0.0265395883,
#     'surprise': 0.000769421866}}],
#  72: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8066578e-f07a-4d11-82a4-e82d99f1c251',
#    'faceRectangle': {'height': 72, 'left': 258, 'top': 93, 'width': 72},
#    'scores': {'anger': 0.0074461163,
#     'contempt': 0.00645397836,
#     'disgust': 0.002704722,
#     'fear': 0.0006773791,
#     'happiness': 0.6115856,
#     'neutral': 0.283656627,
#     'sadness': 0.00166588451,
#     'surprise': 0.0858096555}}],
#  73: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'fcaefa46-fb99-4321-a15c-b1f5c10614ea',
#    'faceRectangle': {'height': 67, 'left': 240, 'top': 107, 'width': 67},
#    'scores': {'anger': 0.005410655,
#     'contempt': 0.008695536,
#     'disgust': 0.00327118253,
#     'fear': 0.000107028187,
#     'happiness': 0.161642432,
#     'neutral': 0.8087793,
#     'sadness': 0.008886596,
#     'surprise': 0.00320726051}}],
#  74: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e3e4f3cf-36fd-4878-abe4-7943d6775703',
#    'faceRectangle': {'height': 65, 'left': 235, 'top': 104, 'width': 65},
#    'scores': {'anger': 0.00150786014,
#     'contempt': 0.0139261894,
#     'disgust': 0.00162056368,
#     'fear': 4.16095354e-05,
#     'happiness': 0.171732187,
#     'neutral': 0.7974527,
#     'sadness': 0.0133497752,
#     'surprise': 0.00036914894}}],
#  75: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e94e2c76-708c-41f2-8a9f-71ec31c1c17c',
#    'faceRectangle': {'height': 66, 'left': 264, 'top': 96, 'width': 66},
#    'scores': {'anger': 0.0006360862,
#     'contempt': 0.00447939849,
#     'disgust': 0.00225526327,
#     'fear': 1.68521219e-05,
#     'happiness': 0.8469115,
#     'neutral': 0.139135808,
#     'sadness': 0.00650622137,
#     'surprise': 5.88569455e-05}}],
#  76: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'fab869cb-5e5f-492c-b7ad-ad381f208b1a',
#    'faceRectangle': {'height': 71, 'left': 210, 'top': 97, 'width': 71},
#    'scores': {'anger': 0.00417183153,
#     'contempt': 0.0270533133,
#     'disgust': 0.00572014228,
#     'fear': 0.00112750521,
#     'happiness': 0.0634871051,
#     'neutral': 0.8380622,
#     'sadness': 0.0572395958,
#     'surprise': 0.0031382856}}],
#  77: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'a386e985-a021-460e-8ad4-7ba2fdb8d4fd',
#    'faceRectangle': {'height': 68, 'left': 203, 'top': 101, 'width': 68},
#    'scores': {'anger': 0.00132410671,
#     'contempt': 0.005391199,
#     'disgust': 0.0012464053,
#     'fear': 0.000234456078,
#     'happiness': 0.017535083,
#     'neutral': 0.937357247,
#     'sadness': 0.0351502076,
#     'surprise': 0.0017613091}}],
#  78: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8eec1f5c-56ff-4425-a7f8-832850b3795a',
#    'faceRectangle': {'height': 67, 'left': 236, 'top': 107, 'width': 67},
#    'scores': {'anger': 0.001993389,
#     'contempt': 0.00309612579,
#     'disgust': 0.00116110477,
#     'fear': 7.12238252e-05,
#     'happiness': 0.09841171,
#     'neutral': 0.852412462,
#     'sadness': 0.0418246537,
#     'surprise': 0.00102932553}}],
#  79: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e8d67c8a-372a-42b4-9bf1-06e0c83c78dd',
#    'faceRectangle': {'height': 67, 'left': 246, 'top': 108, 'width': 67},
#    'scores': {'anger': 0.0102286655,
#     'contempt': 0.00729678059,
#     'disgust': 0.0112818331,
#     'fear': 0.00013111165,
#     'happiness': 0.0189665221,
#     'neutral': 0.917609036,
#     'sadness': 0.0336651132,
#     'surprise': 0.000820928544}}],
#  80: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '09d44a8a-0cbd-4795-8d56-d7550e3e7753',
#    'faceRectangle': {'height': 67, 'left': 232, 'top': 97, 'width': 67},
#    'scores': {'anger': 0.008486029,
#     'contempt': 0.0110133793,
#     'disgust': 0.0101032071,
#     'fear': 0.00012806739,
#     'happiness': 0.00470720464,
#     'neutral': 0.95023334,
#     'sadness': 0.009303881,
#     'surprise': 0.006024868}}],
#  81: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '3995db46-855d-4c7d-a243-0ed9350e50d4',
#    'faceRectangle': {'height': 73, 'left': 245, 'top': 89, 'width': 73},
#    'scores': {'anger': 0.00596776046,
#     'contempt': 0.00515465764,
#     'disgust': 0.0123204393,
#     'fear': 0.0004904526,
#     'happiness': 0.0141263558,
#     'neutral': 0.945923746,
#     'sadness': 0.0115704834,
#     'surprise': 0.00444612326}}],
#  82: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '86835433-9fae-4688-9201-21c6b664e68a',
#    'faceRectangle': {'height': 69, 'left': 226, 'top': 106, 'width': 69},
#    'scores': {'anger': 0.00304251024,
#     'contempt': 0.00245304452,
#     'disgust': 0.0008685952,
#     'fear': 3.92647526e-05,
#     'happiness': 0.0014875005,
#     'neutral': 0.9816765,
#     'sadness': 0.00925666,
#     'surprise': 0.001175911}}],
#  83: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'de0cfee5-bd8b-4449-8a1f-686147a5aa55',
#    'faceRectangle': {'height': 68, 'left': 229, 'top': 105, 'width': 68},
#    'scores': {'anger': 0.00380068668,
#     'contempt': 0.00360743725,
#     'disgust': 0.0021226434,
#     'fear': 2.31401027e-05,
#     'happiness': 0.005815414,
#     'neutral': 0.9744727,
#     'sadness': 0.00960283,
#     'surprise': 0.0005551279}}],
#  84: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '87b3b0f1-ea15-4b5d-be32-e304442725a2',
#    'faceRectangle': {'height': 70, 'left': 226, 'top': 98, 'width': 70},
#    'scores': {'anger': 0.0008663031,
#     'contempt': 0.004831966,
#     'disgust': 0.00122228917,
#     'fear': 2.37695167e-05,
#     'happiness': 0.0383136868,
#     'neutral': 0.9443269,
#     'sadness': 0.009346799,
#     'surprise': 0.00106830813}}],
#  85: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c7497fa9-2270-43e8-b226-8e8763711230',
#    'faceRectangle': {'height': 71, 'left': 194, 'top': 89, 'width': 71},
#    'scores': {'anger': 0.00220103632,
#     'contempt': 0.0212870128,
#     'disgust': 0.00299564819,
#     'fear': 0.00113012921,
#     'happiness': 0.0569806956,
#     'neutral': 0.851674259,
#     'sadness': 0.05676997,
#     'surprise': 0.00696123252}}],
#  86: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b9839d27-4e4d-462d-b6c4-5235c00d2e55',
#    'faceRectangle': {'height': 67, 'left': 222, 'top': 104, 'width': 67},
#    'scores': {'anger': 0.00716132531,
#     'contempt': 0.005001752,
#     'disgust': 0.00541947,
#     'fear': 0.000256615924,
#     'happiness': 0.01969976,
#     'neutral': 0.9228761,
#     'sadness': 0.037761312,
#     'surprise': 0.00182367256}}],
#  87: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '893263f1-0721-41d5-8e88-87e68bfe4ddb',
#    'faceRectangle': {'height': 70, 'left': 231, 'top': 98, 'width': 70},
#    'scores': {'anger': 0.00625734357,
#     'contempt': 0.00346454629,
#     'disgust': 0.007723333,
#     'fear': 9.260631e-05,
#     'happiness': 0.0006193424,
#     'neutral': 0.964559,
#     'sadness': 0.0122518567,
#     'surprise': 0.00503196567}}],
#  88: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '476312ff-f520-4afa-80a0-03030d744d25',
#    'faceRectangle': {'height': 69, 'left': 238, 'top': 102, 'width': 69},
#    'scores': {'anger': 0.00194016937,
#     'contempt': 0.00642583147,
#     'disgust': 0.00167578761,
#     'fear': 7.694396e-05,
#     'happiness': 0.00103853352,
#     'neutral': 0.9770743,
#     'sadness': 0.00782251451,
#     'surprise': 0.0039459113}}],
#  89: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'd4da1408-ab4e-419c-9bf8-fd9a0817a224',
#    'faceRectangle': {'height': 70, 'left': 228, 'top': 97, 'width': 70},
#    'scores': {'anger': 0.0103355888,
#     'contempt': 0.0134187751,
#     'disgust': 0.00635523768,
#     'fear': 0.000608724542,
#     'happiness': 0.0493010022,
#     'neutral': 0.9046572,
#     'sadness': 0.008638714,
#     'surprise': 0.006684763}}],
#  90: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '82130275-0692-4c9c-b3fd-b9ed4254a21d',
#    'faceRectangle': {'height': 74, 'left': 279, 'top': 91, 'width': 74},
#    'scores': {'anger': 0.004325706,
#     'contempt': 0.00148571981,
#     'disgust': 0.0007919668,
#     'fear': 0.001974674,
#     'happiness': 0.00105240033,
#     'neutral': 0.8583632,
#     'sadness': 0.0072006355,
#     'surprise': 0.124805681}}],
#  91: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '4034a653-5d56-4f9b-92d2-8299bdc49c48',
#    'faceRectangle': {'height': 67, 'left': 247, 'top': 101, 'width': 67},
#    'scores': {'anger': 0.00268662418,
#     'contempt': 0.0425518081,
#     'disgust': 0.00219662045,
#     'fear': 0.00025824437,
#     'happiness': 0.0674869642,
#     'neutral': 0.8711614,
#     'sadness': 0.00449425727,
#     'surprise': 0.009164071}}],
#  92: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '3f6f6fbf-6615-429d-a82e-16273abb1a25',
#    'faceRectangle': {'height': 79, 'left': 210, 'top': 90, 'width': 79},
#    'scores': {'anger': 0.0227785017,
#     'contempt': 0.0121119544,
#     'disgust': 0.00742909033,
#     'fear': 0.0006071568,
#     'happiness': 0.00857762,
#     'neutral': 0.8884871,
#     'sadness': 0.00141733,
#     'surprise': 0.0585912354}}],
#  93: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '18ef0725-7330-4987-bf27-b1da13a3be65',
#    'faceRectangle': {'height': 69, 'left': 220, 'top': 107, 'width': 69},
#    'scores': {'anger': 0.0008545234,
#     'contempt': 0.00242526876,
#     'disgust': 0.000270260556,
#     'fear': 8.481346e-06,
#     'happiness': 0.00122262258,
#     'neutral': 0.989523351,
#     'sadness': 0.0043982,
#     'surprise': 0.00129727414}}],
#  94: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1134789f-73ba-44b7-8ea8-916968015c0f',
#    'faceRectangle': {'height': 68, 'left': 226, 'top': 101, 'width': 68},
#    'scores': {'anger': 0.0112635922,
#     'contempt': 0.0117147174,
#     'disgust': 0.00592504442,
#     'fear': 0.0005831135,
#     'happiness': 0.3263505,
#     'neutral': 0.6255708,
#     'sadness': 0.014001146,
#     'surprise': 0.004591121}}],
#  95: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b4cbee86-b30f-4894-b9b7-a367d9f41c13',
#    'faceRectangle': {'height': 78, 'left': 265, 'top': 84, 'width': 78},
#    'scores': {'anger': 0.00385020417,
#     'contempt': 0.0009857514,
#     'disgust': 0.0006560323,
#     'fear': 0.00120281486,
#     'happiness': 0.00179196836,
#     'neutral': 0.8696385,
#     'sadness': 0.00473632,
#     'surprise': 0.117138386}}],
#  96: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'eb97c55b-ec51-4fde-9a7e-186be220a6d7',
#    'faceRectangle': {'height': 78, 'left': 258, 'top': 83, 'width': 78},
#    'scores': {'anger': 0.0003207054,
#     'contempt': 0.00113985268,
#     'disgust': 6.51525261e-05,
#     'fear': 2.13016883e-05,
#     'happiness': 0.00164406677,
#     'neutral': 0.9835985,
#     'sadness': 0.0007983191,
#     'surprise': 0.0124121327}}],
#  97: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '68b1c280-5a75-40cd-ba6a-b052ce6c5e7e',
#    'faceRectangle': {'height': 63, 'left': 230, 'top': 109, 'width': 63},
#    'scores': {'anger': 0.000119788681,
#     'contempt': 0.00355332438,
#     'disgust': 0.000132883622,
#     'fear': 2.04148819e-06,
#     'happiness': 0.676359653,
#     'neutral': 0.3188453,
#     'sadness': 0.0008986182,
#     'surprise': 8.84299661e-05}}],
#  98: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e0b0432d-494f-4a42-aa7e-1f041ac00ede',
#    'faceRectangle': {'height': 66, 'left': 229, 'top': 106, 'width': 66},
#    'scores': {'anger': 0.008042396,
#     'contempt': 0.0102644013,
#     'disgust': 0.00652472442,
#     'fear': 0.000161442891,
#     'happiness': 0.09861144,
#     'neutral': 0.857929647,
#     'sadness': 0.0162923075,
#     'surprise': 0.00217362354}}],
#  99: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'cd71f584-32af-4c58-8a87-1c78e75d6188',
#    'faceRectangle': {'height': 67, 'left': 245, 'top': 102, 'width': 67},
#    'scores': {'anger': 0.00680891424,
#     'contempt': 0.00896958,
#     'disgust': 0.00556504866,
#     'fear': 4.386445e-05,
#     'happiness': 0.0312404,
#     'neutral': 0.9279988,
#     'sadness': 0.0186628588,
#     'surprise': 0.0007105425}}],
#  100: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9b75be08-8ffe-4608-bf4e-90b5f2cc6b4a',
#    'faceRectangle': {'height': 74, 'left': 302, 'top': 92, 'width': 74},
#    'scores': {'anger': 0.002452299,
#     'contempt': 0.007726483,
#     'disgust': 0.000767041754,
#     'fear': 1.22586125e-05,
#     'happiness': 0.08961557,
#     'neutral': 0.897048,
#     'sadness': 0.0002585175,
#     'surprise': 0.00211985037}}],
#  101: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8e9d6c3d-a4d9-4366-8101-4525fad7de07',
#    'faceRectangle': {'height': 64, 'left': 244, 'top': 114, 'width': 64},
#    'scores': {'anger': 0.00151582574,
#     'contempt': 0.001358109,
#     'disgust': 0.00142708072,
#     'fear': 2.963241e-05,
#     'happiness': 0.0280472059,
#     'neutral': 0.9548026,
#     'sadness': 0.0121645574,
#     'surprise': 0.000655028445}}],
#  102: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1ae12c87-cd96-4d17-b24f-4db139cb37ad',
#    'faceRectangle': {'height': 67, 'left': 240, 'top': 107, 'width': 67},
#    'scores': {'anger': 0.008202545,
#     'contempt': 0.007700311,
#     'disgust': 0.009028137,
#     'fear': 0.000359071128,
#     'happiness': 0.09553358,
#     'neutral': 0.8567517,
#     'sadness': 0.0193489827,
#     'surprise': 0.00307571981}}],
#  103: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '14ecb9a2-ea2c-45d3-a17b-2072359f9559',
#    'faceRectangle': {'height': 75, 'left': 223, 'top': 90, 'width': 75},
#    'scores': {'anger': 0.00425861264,
#     'contempt': 0.024651628,
#     'disgust': 0.00130140851,
#     'fear': 0.000478081172,
#     'happiness': 0.008640942,
#     'neutral': 0.9355043,
#     'sadness': 0.00118456292,
#     'surprise': 0.0239804238}}],
#  104: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '689b8ba4-c029-4962-846d-d48b391f5d29',
#    'faceRectangle': {'height': 68, 'left': 235, 'top': 106, 'width': 68},
#    'scores': {'anger': 0.00244307541,
#     'contempt': 0.0061947573,
#     'disgust': 0.00315101515,
#     'fear': 3.936748e-05,
#     'happiness': 0.0441870019,
#     'neutral': 0.9290993,
#     'sadness': 0.0142406533,
#     'surprise': 0.0006447929}}],
#  105: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '116f4132-019b-4556-be19-6ea80a4acdca',
#    'faceRectangle': {'height': 67, 'left': 238, 'top': 106, 'width': 67},
#    'scores': {'anger': 0.006468968,
#     'contempt': 0.005296678,
#     'disgust': 0.00546891,
#     'fear': 5.77878272e-05,
#     'happiness': 0.00391181372,
#     'neutral': 0.966704249,
#     'sadness': 0.0100791743,
#     'surprise': 0.00201241183}}],
#  106: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e494c657-c025-43a7-b119-c8f356599a6f',
#    'faceRectangle': {'height': 67, 'left': 247, 'top': 102, 'width': 67},
#    'scores': {'anger': 0.00215745065,
#     'contempt': 0.00212946651,
#     'disgust': 0.002185119,
#     'fear': 1.0535101e-05,
#     'happiness': 0.00091294205,
#     'neutral': 0.985033,
#     'sadness': 0.006792376,
#     'surprise': 0.0007791267}}],
#  107: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '463902dd-82b1-4778-b4c7-71914f161f8c',
#    'faceRectangle': {'height': 69, 'left': 250, 'top': 100, 'width': 69},
#    'scores': {'anger': 0.003039798,
#     'contempt': 0.009283808,
#     'disgust': 0.00316975266,
#     'fear': 6.908219e-05,
#     'happiness': 0.4304972,
#     'neutral': 0.546310663,
#     'sadness': 0.00718751,
#     'surprise': 0.000442205521}}],
#  108: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '314f6bdc-dace-4d5f-97da-7a59f501939e',
#    'faceRectangle': {'height': 77, 'left': 285, 'top': 83, 'width': 77},
#    'scores': {'anger': 0.0016412898,
#     'contempt': 0.00126661512,
#     'disgust': 0.001359813,
#     'fear': 0.000392299,
#     'happiness': 0.00113587163,
#     'neutral': 0.9020004,
#     'sadness': 0.00307778246,
#     'surprise': 0.0891259238}}],
#  109: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c3728aa1-17f6-4293-8cf0-0eb7f861ff1d',
#    'faceRectangle': {'height': 75, 'left': 272, 'top': 88, 'width': 75},
#    'scores': {'anger': 0.0007452347,
#     'contempt': 0.00078620197,
#     'disgust': 0.0002577315,
#     'fear': 0.000455868372,
#     'happiness': 0.001149102,
#     'neutral': 0.760726869,
#     'sadness': 0.00153279293,
#     'surprise': 0.234346181}}],
#  110: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'bb2c089b-d8ad-490e-90fb-b68f3c7995ae',
#    'faceRectangle': {'height': 72, 'left': 274, 'top': 89, 'width': 72},
#    'scores': {'anger': 0.00542085944,
#     'contempt': 0.0016317853,
#     'disgust': 0.00217875256,
#     'fear': 0.0007324388,
#     'happiness': 0.0109656425,
#     'neutral': 0.594523549,
#     'sadness': 0.0024760298,
#     'surprise': 0.382070959}}],
#  111: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '210a4fda-235f-4f2c-9768-d27442c9f94d',
#    'faceRectangle': {'height': 67, 'left': 226, 'top': 110, 'width': 67},
#    'scores': {'anger': 0.00156663288,
#     'contempt': 0.00172740326,
#     'disgust': 0.0007449391,
#     'fear': 4.262999e-05,
#     'happiness': 0.009416962,
#     'neutral': 0.971391559,
#     'sadness': 0.0142917586,
#     'surprise': 0.00081809}}],
#  112: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b4f53038-82bb-459e-b4c1-464fa85225c3',
#    'faceRectangle': {'height': 67, 'left': 229, 'top': 108, 'width': 67},
#    'scores': {'anger': 0.001654723,
#     'contempt': 0.00142841786,
#     'disgust': 0.00140852318,
#     'fear': 7.338032e-05,
#     'happiness': 0.0298883747,
#     'neutral': 0.931824,
#     'sadness': 0.0326005556,
#     'surprise': 0.00112198992}}],
#  113: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '7d181905-2950-413c-bb50-26f6288d2629',
#    'faceRectangle': {'height': 72, 'left': 221, 'top': 96, 'width': 72},
#    'scores': {'anger': 0.006021869,
#     'contempt': 0.0256508663,
#     'disgust': 0.005857551,
#     'fear': 0.00148011011,
#     'happiness': 0.10395965,
#     'neutral': 0.8245411,
#     'sadness': 0.003936799,
#     'surprise': 0.0285520665}}],
#  114: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b06e8150-8dcc-406d-8180-138790bf770f',
#    'faceRectangle': {'height': 70, 'left': 231, 'top': 103, 'width': 70},
#    'scores': {'anger': 0.00144599634,
#     'contempt': 0.00934222247,
#     'disgust': 0.00127932848,
#     'fear': 3.37059755e-05,
#     'happiness': 0.003736477,
#     'neutral': 0.968818247,
#     'sadness': 0.0144771086,
#     'surprise': 0.0008669109}}],
#  115: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '059c23b8-f6bb-49a1-9048-f6e18791544c',
#    'faceRectangle': {'height': 68, 'left': 256, 'top': 105, 'width': 68},
#    'scores': {'anger': 0.000340722327,
#     'contempt': 0.0492729172,
#     'disgust': 0.00025216327,
#     'fear': 1.66117673e-06,
#     'happiness': 0.000488485035,
#     'neutral': 0.9477955,
#     'sadness': 0.0008832626,
#     'surprise': 0.0009652699}}],
#  116: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8cbba64a-93b5-4db9-a451-5610bdde39c4',
#    'faceRectangle': {'height': 72, 'left': 220, 'top': 90, 'width': 72},
#    'scores': {'anger': 0.0154542774,
#     'contempt': 0.0293742586,
#     'disgust': 0.0161000174,
#     'fear': 0.00149690814,
#     'happiness': 0.05811463,
#     'neutral': 0.8450679,
#     'sadness': 0.005434697,
#     'surprise': 0.0289573241}}],
#  117: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'dc0c65e8-5725-48de-9c6c-d0881591ea86',
#    'faceRectangle': {'height': 67, 'left': 227, 'top': 103, 'width': 67},
#    'scores': {'anger': 0.001390305,
#     'contempt': 0.0118980752,
#     'disgust': 0.00186905521,
#     'fear': 5.769836e-05,
#     'happiness': 0.0381252542,
#     'neutral': 0.9222125,
#     'sadness': 0.0238011554,
#     'surprise': 0.0006459793}}],
#  118: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '79cf1816-a455-42d2-a791-46708ac4d941',
#    'faceRectangle': {'height': 70, 'left': 227, 'top': 96, 'width': 70},
#    'scores': {'anger': 0.00150438724,
#     'contempt': 0.009317932,
#     'disgust': 0.00371427229,
#     'fear': 0.000142811652,
#     'happiness': 0.0281798244,
#     'neutral': 0.940929234,
#     'sadness': 0.014729891,
#     'surprise': 0.00148164306}}],
#  119: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6b48f926-6945-4f99-bdf3-7f182b699ae4',
#    'faceRectangle': {'height': 76, 'left': 215, 'top': 89, 'width': 76},
#    'scores': {'anger': 0.00128468964,
#     'contempt': 0.0414206274,
#     'disgust': 0.000889226969,
#     'fear': 0.0005098751,
#     'happiness': 0.0183710568,
#     'neutral': 0.9291532,
#     'sadness': 0.006429479,
#     'surprise': 0.00194185763}}],
#  120: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c94b4c48-93e4-491b-9304-57e64443aeec',
#    'faceRectangle': {'height': 76, 'left': 257, 'top': 87, 'width': 76},
#    'scores': {'anger': 0.0487795174,
#     'contempt': 0.009944745,
#     'disgust': 0.0175801143,
#     'fear': 0.0019250511,
#     'happiness': 0.00499678031,
#     'neutral': 0.8556077,
#     'sadness': 0.00503982836,
#     'surprise': 0.05612625}}],
#  121: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '85a8fdd4-f341-4486-b1b3-85339b826666',
#    'faceRectangle': {'height': 64, 'left': 247, 'top': 109, 'width': 64},
#    'scores': {'anger': 0.000410016568,
#     'contempt': 0.005798846,
#     'disgust': 0.000523950264,
#     'fear': 5.423446e-06,
#     'happiness': 0.221180081,
#     'neutral': 0.768769,
#     'sadness': 0.00308356434,
#     'surprise': 0.000229061567}}],
#  122: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '0922656b-b7a6-4aee-86d7-7cae9f9c8e95',
#    'faceRectangle': {'height': 69, 'left': 240, 'top': 105, 'width': 69},
#    'scores': {'anger': 0.000439183175,
#     'contempt': 0.00344629586,
#     'disgust': 0.000580895052,
#     'fear': 1.44383657e-05,
#     'happiness': 0.184146151,
#     'neutral': 0.796043038,
#     'sadness': 0.0149042141,
#     'surprise': 0.000425800041}}],
#  123: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8553536e-a6f5-4795-9a5b-b75a08a01a19',
#    'faceRectangle': {'height': 65, 'left': 262, 'top': 106, 'width': 65},
#    'scores': {'anger': 0.0025952626,
#     'contempt': 0.00660382863,
#     'disgust': 0.004546868,
#     'fear': 0.000213456544,
#     'happiness': 0.07131217,
#     'neutral': 0.8952841,
#     'sadness': 0.0134567861,
#     'surprise': 0.005987545}}],
#  124: [{'faceAttributes': {'gender': 'male'},
# ...
#     'neutral': 0.716845334,
#     'sadness': 0.215595722,
#     'surprise': 0.0250881463}}],
#  531: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '3aa7c873-1869-4482-9ec9-867676f7366b',
#    'faceRectangle': {'height': 74, 'left': 228, 'top': 112, 'width': 74},
#    'scores': {'anger': 0.0024956814,
#     'contempt': 0.000725149643,
#     'disgust': 0.00260959147,
#     'fear': 0.000157469025,
#     'happiness': 0.000131380963,
#     'neutral': 0.8741792,
#     'sadness': 0.115914732,
#     'surprise': 0.00378678273}}],
#  532: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '45cace63-136f-432a-99ec-ff420314d18f',
#    'faceRectangle': {'height': 73, 'left': 223, 'top': 112, 'width': 73},
#    'scores': {'anger': 0.00467100646,
#     'contempt': 0.0002991798,
#     'disgust': 0.004298654,
#     'fear': 7.594781e-05,
#     'happiness': 0.000131254841,
#     'neutral': 0.952026,
#     'sadness': 0.02739199,
#     'surprise': 0.0111059351}}],
#  533: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '511df845-a8ed-4a3d-ad24-bea399cd3816',
#    'faceRectangle': {'height': 77, 'left': 244, 'top': 98, 'width': 77},
#    'scores': {'anger': 0.052940432,
#     'contempt': 0.00302319252,
#     'disgust': 0.0002936096,
#     'fear': 9.223179e-06,
#     'happiness': 1.06898085e-06,
#     'neutral': 0.9393685,
#     'sadness': 0.00422159024,
#     'surprise': 0.000142392}}],
#  534: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6af1e7b9-7c7f-4aef-8012-be5830fb3181',
#    'faceRectangle': {'height': 70, 'left': 227, 'top': 122, 'width': 70},
#    'scores': {'anger': 0.0152674969,
#     'contempt': 0.00065385265,
#     'disgust': 0.003621838,
#     'fear': 0.000163086486,
#     'happiness': 1.26222831e-05,
#     'neutral': 0.8504874,
#     'sadness': 0.128474459,
#     'surprise': 0.00131922239}}],
#  535: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '7993ddda-9be2-455d-9405-0fed2a385309',
#    'faceRectangle': {'height': 73, 'left': 223, 'top': 115, 'width': 73},
#    'scores': {'anger': 0.00106146093,
#     'contempt': 0.000410346576,
#     'disgust': 0.0008271619,
#     'fear': 3.71674978e-05,
#     'happiness': 8.56582046e-05,
#     'neutral': 0.8435756,
#     'sadness': 0.153099567,
#     'surprise': 0.0009030488}}],
#  536: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ecacd166-d9da-41eb-85ab-89a5376a1280',
#    'faceRectangle': {'height': 71, 'left': 221, 'top': 121, 'width': 71},
#    'scores': {'anger': 0.005531621,
#     'contempt': 0.000155686081,
#     'disgust': 0.000927457237,
#     'fear': 4.90997172e-06,
#     'happiness': 6.47866636e-06,
#     'neutral': 0.877361059,
#     'sadness': 0.115901768,
#     'surprise': 0.000110999077}}],
#  537: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'dde89a0e-9bdb-48b6-a288-d14d1e2ba299',
#    'faceRectangle': {'height': 73, 'left': 224, 'top': 119, 'width': 73},
#    'scores': {'anger': 0.00375680579,
#     'contempt': 0.000278797757,
#     'disgust': 0.00188343541,
#     'fear': 3.602312e-05,
#     'happiness': 1.88553258e-05,
#     'neutral': 0.8401131,
#     'sadness': 0.1530609,
#     'surprise': 0.0008520958}}],
#  538: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'fd42155c-22fd-4417-95e0-458d3bbb781a',
#    'faceRectangle': {'height': 72, 'left': 227, 'top': 119, 'width': 72},
#    'scores': {'anger': 0.000347994559,
#     'contempt': 6.47600755e-05,
#     'disgust': 8.32024452e-05,
#     'fear': 3.02062915e-07,
#     'happiness': 5.07904224e-06,
#     'neutral': 0.8872783,
#     'sadness': 0.112210795,
#     'surprise': 9.546666e-06}}],
#  539: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1cf49216-6783-4d8b-89f5-0c9b533a5356',
#    'faceRectangle': {'height': 73, 'left': 225, 'top': 117, 'width': 73},
#    'scores': {'anger': 0.000638580765,
#     'contempt': 0.000178321585,
#     'disgust': 0.000155184011,
#     'fear': 1.52917e-06,
#     'happiness': 2.47590469e-05,
#     'neutral': 0.8870202,
#     'sadness': 0.111936525,
#     'surprise': 4.491047e-05}}],
#  540: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ecf058ec-117d-4292-8fa8-889122242e27',
#    'faceRectangle': {'height': 78, 'left': 242, 'top': 97, 'width': 78},
#    'scores': {'anger': 0.175898239,
#     'contempt': 0.004915694,
#     'disgust': 0.02180075,
#     'fear': 0.0008853427,
#     'happiness': 6.117639e-05,
#     'neutral': 0.729926,
#     'sadness': 0.00590780657,
#     'surprise': 0.06060502}}],
#  541: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8516345e-132d-421d-8241-ea2d21087a10',
#    'faceRectangle': {'height': 73, 'left': 260, 'top': 119, 'width': 73},
#    'scores': {'anger': 0.000473373337,
#     'contempt': 2.69628817e-05,
#     'disgust': 0.000191520754,
#     'fear': 1.84292375e-07,
#     'happiness': 2.05017358e-07,
#     'neutral': 0.610671341,
#     'sadness': 0.3886345,
#     'surprise': 1.91924642e-06}}],
#  542: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '7ac4befd-79e7-44ad-98ff-abfb2009432d',
#    'faceRectangle': {'height': 69, 'left': 272, 'top': 120, 'width': 69},
#    'scores': {'anger': 0.008621558,
#     'contempt': 0.0003006402,
#     'disgust': 0.003902132,
#     'fear': 0.000142726276,
#     'happiness': 6.04396446e-05,
#     'neutral': 0.8913978,
#     'sadness': 0.0919752046,
#     'surprise': 0.003599526}}],
#  543: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '48c7c4ca-f72f-4efc-9639-84c917fbcf85',
#    'faceRectangle': {'height': 70, 'left': 258, 'top': 120, 'width': 70},
#    'scores': {'anger': 0.000783967262,
#     'contempt': 4.25845319e-05,
#     'disgust': 0.000203810312,
#     'fear': 2.78286876e-07,
#     'happiness': 2.40055524e-05,
#     'neutral': 0.839291751,
#     'sadness': 0.1596503,
#     'surprise': 3.295569e-06}}],
#  544: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '03c48ba0-1400-4fdd-a5f1-5133e355982e',
#    'faceRectangle': {'height': 73, 'left': 255, 'top': 114, 'width': 73},
#    'scores': {'anger': 0.005326834,
#     'contempt': 8.88671e-05,
#     'disgust': 0.0008020197,
#     'fear': 9.308245e-07,
#     'happiness': 1.89666662e-06,
#     'neutral': 0.6680353,
#     'sadness': 0.325737476,
#     'surprise': 6.630012e-06}}],
#  545: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c3b2b586-14dd-4891-b5c7-989b1c17780d',
#    'faceRectangle': {'height': 72, 'left': 253, 'top': 117, 'width': 72},
#    'scores': {'anger': 0.0007400924,
#     'contempt': 9.664115e-05,
#     'disgust': 0.0001045546,
#     'fear': 5.61086e-07,
#     'happiness': 5.80814049e-05,
#     'neutral': 0.957448065,
#     'sadness': 0.04152267,
#     'surprise': 2.93116973e-05}}],
#  546: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ab29fc38-5d0c-4c11-b72b-dbba18d6a617',
#    'faceRectangle': {'height': 71, 'left': 261, 'top': 115, 'width': 71},
#    'scores': {'anger': 0.0001742595,
#     'contempt': 1.71973188e-05,
#     'disgust': 2.12156538e-05,
#     'fear': 1.815583e-07,
#     'happiness': 2.87101429e-05,
#     'neutral': 0.8878857,
#     'sadness': 0.111868612,
#     'surprise': 4.11061455e-06}}],
#  547: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9c97790a-d885-4014-8871-7d72e7857aba',
#    'faceRectangle': {'height': 72, 'left': 279, 'top': 120, 'width': 72},
#    'scores': {'anger': 0.0112639014,
#     'contempt': 0.000187496844,
#     'disgust': 0.002142328,
#     'fear': 4.03955e-05,
#     'happiness': 1.54792033e-05,
#     'neutral': 0.821459234,
#     'sadness': 0.164378509,
#     'surprise': 0.000512629165}}],
#  548: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'd8ab1587-e2cc-4e50-9e59-81d945c0461c',
#    'faceRectangle': {'height': 71, 'left': 238, 'top': 121, 'width': 71},
#    'scores': {'anger': 0.0009787134,
#     'contempt': 9.835504e-05,
#     'disgust': 0.000142787831,
#     'fear': 2.79982555e-06,
#     'happiness': 2.74677332e-05,
#     'neutral': 0.9082512,
#     'sadness': 0.0904219,
#     'surprise': 7.677363e-05}}],
#  549: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '38ca1c4a-037f-4bb9-9509-eb2ea3b7b183',
#    'faceRectangle': {'height': 72, 'left': 231, 'top': 116, 'width': 72},
#    'scores': {'anger': 0.009604549,
#     'contempt': 0.0004208948,
#     'disgust': 0.004046272,
#     'fear': 0.00024656445,
#     'happiness': 7.046453e-05,
#     'neutral': 0.9304815,
#     'sadness': 0.0384540819,
#     'surprise': 0.0166756548}}],
#  550: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'aece682a-ee12-48b7-90c9-d0664f0dfd24',
#    'faceRectangle': {'height': 76, 'left': 235, 'top': 100, 'width': 76},
#    'scores': {'anger': 0.0288502537,
#     'contempt': 0.004143506,
#     'disgust': 0.00442014169,
#     'fear': 8.11920763e-05,
#     'happiness': 0.000205882621,
#     'neutral': 0.9285843,
#     'sadness': 0.03278097,
#     'surprise': 0.000933799252}}],
#  551: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '674fe5e1-96d1-4a8e-bc7b-a7111d6bf38a',
#    'faceRectangle': {'height': 72, 'left': 234, 'top': 116, 'width': 72},
#    'scores': {'anger': 0.00168130861,
#     'contempt': 0.000163346922,
#     'disgust': 0.000556259649,
#     'fear': 6.178391e-06,
#     'happiness': 1.51623353e-05,
#     'neutral': 0.8430975,
#     'sadness': 0.154386371,
#     'surprise': 9.386148e-05}}],
#  552: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '58dcd3c3-d6f4-4dad-b2c2-8b6ac1ea0307',
#    'faceRectangle': {'height': 80, 'left': 242, 'top': 87, 'width': 80},
#    'scores': {'anger': 0.10924156,
#     'contempt': 0.004270703,
#     'disgust': 0.0125950063,
#     'fear': 0.000145475613,
#     'happiness': 0.000484239863,
#     'neutral': 0.8077842,
#     'sadness': 0.00102993159,
#     'surprise': 0.06444889}}],
#  553: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'cef06b91-4353-41d9-a36e-6301094b7970',
#    'faceRectangle': {'height': 73, 'left': 237, 'top': 118, 'width': 73},
#    'scores': {'anger': 0.00552721927,
#     'contempt': 0.000318736624,
#     'disgust': 0.00134997431,
#     'fear': 3.321714e-05,
#     'happiness': 2.025452e-05,
#     'neutral': 0.9212951,
#     'sadness': 0.06960209,
#     'surprise': 0.0018533899}}],
#  554: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9d22e8e6-011d-4b61-87e0-27ad7e27233e',
#    'faceRectangle': {'height': 70, 'left': 238, 'top': 119, 'width': 70},
#    'scores': {'anger': 0.00321707525,
#     'contempt': 0.000281182642,
#     'disgust': 0.0005153425,
#     'fear': 3.02203671e-06,
#     'happiness': 5.95294841e-06,
#     'neutral': 0.844187856,
#     'sadness': 0.1517565,
#     'surprise': 3.30943221e-05}}],
#  555: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'fa6ac600-1799-4676-948e-14714a70166e',
#    'faceRectangle': {'height': 70, 'left': 233, 'top': 119, 'width': 70},
#    'scores': {'anger': 0.000441051525,
#     'contempt': 4.9123777e-05,
#     'disgust': 5.198024e-05,
#     'fear': 1.8777169e-07,
#     'happiness': 2.56155272e-06,
#     'neutral': 0.83940804,
#     'sadness': 0.1600435,
#     'surprise': 3.56142755e-06}}],
#  556: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '2d08b1d5-5756-40d1-af25-8f6d078f8ab6',
#    'faceRectangle': {'height': 71, 'left': 235, 'top': 119, 'width': 71},
#    'scores': {'anger': 0.00349930255,
#     'contempt': 0.000153500441,
#     'disgust': 0.002405446,
#     'fear': 1.18946882e-05,
#     'happiness': 0.000122345984,
#     'neutral': 0.882412553,
#     'sadness': 0.111153476,
#     'surprise': 0.000241455549}}],
#  557: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'cf51c6c5-c629-447f-b245-47894aa0b54c',
#    'faceRectangle': {'height': 71, 'left': 235, 'top': 119, 'width': 71},
#    'scores': {'anger': 0.000279144559,
#     'contempt': 9.116449e-05,
#     'disgust': 7.767741e-05,
#     'fear': 3.915267e-07,
#     'happiness': 1.32336691e-05,
#     'neutral': 0.877878368,
#     'sadness': 0.12165042,
#     'surprise': 9.619339e-06}}],
#  558: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e64663d9-36a2-4e2b-85d4-76f3644d22d8',
#    'faceRectangle': {'height': 72, 'left': 244, 'top': 119, 'width': 72},
#    'scores': {'anger': 0.0008413876,
#     'contempt': 2.80157765e-05,
#     'disgust': 0.000116704359,
#     'fear': 1.23514354e-07,
#     'happiness': 1.1721203e-05,
#     'neutral': 0.909584761,
#     'sadness': 0.08941257,
#     'surprise': 4.6954724e-06}}],
#  559: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'dfba5f15-748e-4825-8ea0-5b0798f18693',
#    'faceRectangle': {'height': 70, 'left': 286, 'top': 124, 'width': 70},
#    'scores': {'anger': 0.000933752162,
#     'contempt': 6.838943e-05,
#     'disgust': 0.000161944874,
#     'fear': 1.25549514e-06,
#     'happiness': 0.00011877215,
#     'neutral': 0.9622702,
#     'sadness': 0.03635967,
#     'surprise': 8.604109e-05}}],
#  560: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '20729d70-e33d-4ef5-a323-9cbcf00505bc',
#    'faceRectangle': {'height': 77, 'left': 287, 'top': 92, 'width': 77},
#    'scores': {'anger': 0.01720564,
#     'contempt': 0.00371137634,
#     'disgust': 0.0125971381,
#     'fear': 5.865072e-05,
#     'happiness': 0.0005059001,
#     'neutral': 0.944626451,
#     'sadness': 0.00353268,
#     'surprise': 0.017762186}}],
#  561: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1f1010e9-1d6f-4f4a-9623-a13706500c8c',
#    'faceRectangle': {'height': 71, 'left': 257, 'top': 113, 'width': 71},
#    'scores': {'anger': 0.00103344978,
#     'contempt': 0.000235429077,
#     'disgust': 0.000668305,
#     'fear': 1.70152964e-06,
#     'happiness': 8.175973e-05,
#     'neutral': 0.932429969,
#     'sadness': 0.06543415,
#     'surprise': 0.000115239462}}],
#  562: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '985d09e5-a3fa-472a-a17a-83abf6821934',
#    'faceRectangle': {'height': 77, 'left': 257, 'top': 105, 'width': 77},
#    'scores': {'anger': 0.0372168273,
#     'contempt': 0.00392353768,
#     'disgust': 0.029514784,
#     'fear': 0.000922771171,
#     'happiness': 0.000814250263,
#     'neutral': 0.8643732,
#     'sadness': 0.0487460457,
#     'surprise': 0.0144885918}}],
#  563: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9324003e-9896-43df-abe6-9ccb576957cb',
#    'faceRectangle': {'height': 79, 'left': 289, 'top': 79, 'width': 79},
#    'scores': {'anger': 0.0529701561,
#     'contempt': 0.001305254,
#     'disgust': 0.01565417,
#     'fear': 8.565344e-05,
#     'happiness': 0.0014700985,
#     'neutral': 0.6091385,
#     'sadness': 0.0008217991,
#     'surprise': 0.318554372}}],
#  564: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '3b118fd7-9191-49ef-ac48-8474f3e98cda',
#    'faceRectangle': {'height': 79, 'left': 270, 'top': 81, 'width': 79},
#    'scores': {'anger': 0.00435057469,
#     'contempt': 0.00314060226,
#     'disgust': 0.001755851,
#     'fear': 2.75808979e-05,
#     'happiness': 7.590026e-05,
#     'neutral': 0.970300734,
#     'sadness': 0.0195481181,
#     'surprise': 0.000800652255}}],
#  565: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '53e19601-81bb-4644-8a0c-34d775842cf6',
#    'faceRectangle': {'height': 79, 'left': 253, 'top': 91, 'width': 79},
#    'scores': {'anger': 0.0698223,
#     'contempt': 0.002261164,
#     'disgust': 0.0322004035,
#     'fear': 1.28257734e-05,
#     'happiness': 0.000789663,
#     'neutral': 0.756993949,
#     'sadness': 0.00106046756,
#     'surprise': 0.136859223}}],
#  566: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '471f995a-3c3c-4b93-8894-76e2f5ae89f4',
#    'faceRectangle': {'height': 74, 'left': 252, 'top': 113, 'width': 74},
#    'scores': {'anger': 0.03193837,
#     'contempt': 0.00109864143,
#     'disgust': 0.0187795926,
#     'fear': 0.000413302565,
#     'happiness': 4.057276e-05,
#     'neutral': 0.8035009,
#     'sadness': 0.133495122,
#     'surprise': 0.0107335057}}],
#  567: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b5c3d50b-0e4f-4189-9690-329a7fd264d7',
#    'faceRectangle': {'height': 74, 'left': 228, 'top': 112, 'width': 74},
#    'scores': {'anger': 0.00633082,
#     'contempt': 0.00117342384,
#     'disgust': 0.004718735,
#     'fear': 0.000100024779,
#     'happiness': 0.000281481538,
#     'neutral': 0.8151097,
#     'sadness': 0.171324566,
#     'surprise': 0.0009612288}}],
#  568: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e02495d6-c222-4714-af04-e66712093566',
#    'faceRectangle': {'height': 73, 'left': 231, 'top': 113, 'width': 73},
#    'scores': {'anger': 0.009114746,
#     'contempt': 0.00206119334,
#     'disgust': 0.00194491213,
#     'fear': 0.000111422589,
#     'happiness': 0.000276145671,
#     'neutral': 0.8724684,
#     'sadness': 0.11296498,
#     'surprise': 0.00105820515}}]}
# time: 294 ms

# %%
# Save the result as Json
#### ATTNTION ----- update '1_23_17.json' to the name of your current folder #######

import json
with open('/Users/Amiros/GitHub/100_days_of_spice/json/3_16_17.json', 'w') as fp:
    json.dump(face_detection, fp, sort_keys=True)

# %% [markdown]
# ## json to csv

# %%
import json
import csv

# %%
"""
This can probably be improved but serves the purpose of our analysis.
I used Chris's schema so it will be useful for Quarz analysis.

"""

EMOTIONS = [
    'contempt',
    'fear',
    'sadness',
    'disgust',
    'anger',
    'neutral',
    'happiness',
    'surprise',
]


CSV_COLUMNS = [
    'url',
    'frame_time',
    'sean_happiness',
    'sean_neutral',
    'sean_anger',
    'sean_contempt',
    'sean_suprise',
    'sean_sadness',
    'sean_fear'
]

# %%
with open('/Users/Amiros/GitHub/100_days_of_spice/json/3_16_17.json') as data_file:    
    json_data = json.load(data_file)
    
json_data = {int(k):v for k,v in json_data.items()} #converting keys to integer   
frame_keys = sorted(json_data.keys())

# %%
csv_data = []
   
for key in frame_keys:
    url = 'https://s3.amazonaws.com/100daysofspice/3_16_17/3_16_17___%d.jpg' % key
    frame = json_data[key]
        
    row = {
        #'frame': frame,
        'url': url,
        'frame_time': key,
    }
    
    if len(frame) > 1:
        for face in frame:
            if face['faceAttributes']['gender'] == 'male':
                prefix = 'sean_'
                try:
                    for emotion in EMOTIONS:
                        row[prefix + emotion] = face['scores'][emotion]
                except:
                    pass
                
            row.pop("frame", None)        
      
    elif len(frame) == 1:
        for face in frame:
            if face['faceAttributes']['gender'] == 'male':
                prefix = 'sean_'
                try:
                    for emotion in EMOTIONS:
                    #print(face['scores'][emotion])
                        row[prefix + emotion] = face['scores'][emotion]
                except:
                    pass
                ### assign emotions vale to each candidate and change the name to the respective one 
          
        row.pop("frame", None)        

    csv_data.append(row)

# %%
import pandas as pd
df = pd.DataFrame(csv_data)

# %%
####### change the date here
df['data'] = '3_16_17'
df

# %%
#### change the name here
df.to_csv('csv/3_16_17-EMOTIONS.csv', sep=',', index=False)
