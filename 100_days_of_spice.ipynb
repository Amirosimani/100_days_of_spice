# %%
# install youtubedl library
# sudo -H pip install --upgrade youtube-dl

# %%
import os

# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime

# %% [markdown]
# ## download youtube video

# %%
# downloading all the videos from the playlist - mp4 & highest quality
# latest: 39 videos from 1/23/17 to 4/3/17
# https://www.youtube.com/playlist?list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI

# os.system("youtube-dl -f 'bestvideo[ext=mp4]/best[ext=mp4]/best' -citk https://www.youtube.com/playlist?list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI")


# os.system("youtube-dl -f bestvideo+bestaudio https://www.youtube.com/watch?v=hTpoxrEbKFk&list=PLRJNAhZxtqH_3Nl-7n1vhgTUHyFSuQ0nI&index=39")

# %%
## files to delet

#President Trump Holds a Press Conference-Ct0H_ndjavM.mp4
#President Trump and Prime Minister Trudeau-vqkb-sJ31S4.mp4
#President Trump and PM May Joint Press Conference-8TYCHq9cAS8.mp4
#Joint Statment by President Trump and Prime Minister Shinzō Abe-ntlqA33SL-k.mp4
#Joint Press Conference-IbpsmS2BTLo.mp4"

# %% [markdown]
# ## Extracting stills from videos

# %%
import cv2
import math
import numpy as np


cv2.__version__ # this will print the version of your opencv2

# %%
# def extract_stills(videoFile, extraction_rate, output_address, output_name):
#     """This function takes the location of a video and extract stills based on the user desired rate.
#     It requires importing cv2 and math libraries.
    
#     parameters
#     video: locaiton of the video - string
#     extraction_rate: rate of extracting stills in seconds - int"""
    
#     # setting up the file
#     vidcap = cv2.VideoCapture(videoFile)
    
#     # setting up parameters
#     seconds = 1000
#     fps = int(round(vidcap.get(cv2.CAP_PROP_FPS))) # Gets the frames per second
#     total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
#     duration = (round(total_frames/fps) -1)*1000
    
#     location = output_address + output_name + '%d.jpg'
#     #extracting every 'extraction_rate' of the video
#     for i in range(0, duration, extraction_rate * 1000):
#         vidcap.set(cv2.CAP_PROP_POS_MSEC,i)
#         success,image = vidcap.read()
#         j = i/1000
# #         return cv2.imwrite(location % j, image)     # save frame as JPEG file


# # import cv2
# # import os

# # def video_to_frames(video, path_output_dir):
# #     # extract frames from a video and save to directory as 'x.png' where 
# #     # x is the frame index
# #     vidcap = cv2.VideoCapture(video)
# #     count = 0
# #     while vidcap.isOpened():
# #         success, image = vidcap.read()
# #         if success:
# #             cv2.imwrite(os.path.join(path_output_dir, '%d.png') % count, image)
# #             count += 1
# #         else:
# #             break
# #     cv2.destroyAllWindows()
# #     vidcap.release()

# # video_to_frames('../somepath/myvid.mp4', '../somepath/out')

# %%
# # fourcc = cv2.VideoWriter_fourcc(*'H264')

# # setting up the file
# videoFile = '/Users/Amiros/GitHub/100_days_of_spice/3_31_17 - White House Press Briefing-Nr8Mu0-vPsQ.mp4'
# vidcap = cv2.VideoCapture(videoFile)
# success,image = vidcap.read()

# # setting up parameters
# seconds = 1000
# fps = int(round(vidcap.get(cv2.CAP_PROP_FPS))) # Gets the frames per second
# total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
# duration = (round(total_frames/fps) -1)*1000

# #extracting every 'second' of the video
# for i in range(0, duration, seconds):
#     vidcap.set(cv2.CAP_PROP_POS_MSEC,i)
#     success,image = vidcap.read()
#     j = i/1000
#     cv2.imwrite("/Users/Amiros/GitHub/100_days_of_spice/images/4_3_17/4_3_17__%d.jpg" % j, image)     # save frame as JPEG file

# %% [markdown]
# ## Detecting Sean's face

# %%
# from cognitive_face import face as CF
# from urllib3 import util

# %%
# KEY = 'e3b77a2e317244f2a7198e9387190a64'
# CF.Key.set(KEY)

# %%
# img_url = 'http://i2.cdn.cnn.com/cnnnext/dam/assets/170121181022-sean-spicer-donald-trump-inauguration-crowd-bts-00002515-large-169.jpg'
# result = CF.detect(img_url)

# %%
# CF.detect('https://upload.wikimedia.org/wikipedia/commons/3/3f/Press_secretary_Sean_Spicer.jpg')
# # CF.detect('https://img.washingtonpost.com/wp-apps/imrs.php?src=https://img.washingtonpost.com/rf/image_960w/2010-2019/WashingtonPost/2017/01/25/Production/Daily/A-Section/Images/AFP_KO6YL.jpg&w=480')

# %%
# face_ids = ['e13dd2b8-c9a4-4035-86a8-6b37ac6ce77b', '2850cf17-4ea9-4285-86bb-d29c703338f1', '92f34cee-7038-476a-827c-b6f1e31de989']

# CF.group(face_ids)

# %%
# CF.find_similars(help)

# %% [markdown]
# # Detecting emotions

# %%
import http.client, urllib, base64, requests
import cognitive_face as CF 
from cognitive_face import util
import time
import os

# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime
# Out:
# ERROR:root:Line magic function `%install_ext` not found.

# %%
#Emotion Analysis parameters
_url = 'https://api.projectoxford.ai/emotion/v1.0/recognize'
_key = '167a95eae08446f0a00b4568c045b97b'  ######### Here you have to paste your primary key for EMOTION API
_maxNumRetries = 5

#Face detection parametrs
CF.Key.set('bee19ea2a47e4a6eb64e23e969a6df6e') ######### set the key for FACE API
# Out:
# time: 2.66 ms

# %%
# Image path
urlImage= ''

# Emtional Anlaysis function
def processRequest( json, data, headers, params ):

    retries = 0
    result = None

    while True:

        response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )

        if response.status_code == 429: 

            print( "Message: %s" % ( response.json()['error']['message'] ) )

            if retries <= _maxNumRetries: 
                time.sleep(1) 
                retries += 1
                continue
            else: 
                print( 'Error: failed after retrying!' )
                break

        elif response.status_code == 200 or response.status_code == 201:

            if 'content-length' in response.headers and int(response.headers['content-length']) == 0: 
                result = None 
            elif 'content-type' in response.headers and isinstance(response.headers['content-type'], str): 
                if 'application/json' in response.headers['content-type'].lower(): 
                    result = response.json() if response.content else None 
                elif 'image' in response.headers['content-type'].lower(): 
                    result = response.content
        else:
            print( "Error code: %d" % ( response.status_code ) )
            print( "Message: %s" % ( response.json()['error']['message'] ) )

        break
        
    return result


headers = dict()
headers['Ocp-Apim-Subscription-Key'] = _key
headers['Content-Type'] = 'application/json' 

json = { 'url': urlImage } 
data = None
params = None
# Out:
# time: 36.5 ms

# %%
# Face detect function
def detect(image, face_id=True, landmarks=False, faceRectangle= False, attributes='gender'):
    
    url = 'detect'
    headers, data, json = util.parse_image(image)
    params = {
        'returnFaceId': face_id and 'true',
        'returnFaceLandmarks': landmarks and 'false',
        'returnFaceAttributes': attributes,
    }

    return util.request('POST', url, headers=headers, params=params, json=json,
                        data=data)
# Out:
# time: 5.34 ms

# %%
# generate a fake url list to replicate S3 condition

#### ATTNTION ----- change '4641' to match the number of last image+1 -----#######
#### ATTNTION ----- change '1_23_17/1_23_17___%d.jpg' to match the path and names on your S3 bucket -----#######

url_list = []
for i in range(0,3544,1):
    url = "https://s3.amazonaws.com/100daysofspice/3_22_17/3_22_17___%d.jpg" % i
    url_list.append(url)
# Out:
# time: 18.2 ms

# %%
# Face Detection & Emotion Analysis - UPDATED
processed = {}
face_detection = {}
count = 0

for single_image in url_list:
 
    try:
        face_detection[count] = detect(single_image)

        json = { 'url': single_image } 
        processed[count] = processRequest(json, data, headers, params)  
    except:
        pass

    try:
        if face_detection[count][0]['faceRectangle'] == processed[count][0]['faceRectangle']:
            face_detection[count][0].update(processed[count][0])
            face_detection[count][1].update(processed[count][1])
        if  face_detection[count][0]['faceRectangle'] == processed[count][1]['faceRectangle']:
            face_detection[count][0].update(processed[count][1])
            face_detection[count][1].update(processed[count][0])
    except:
        pass
    
    count += 1
    
    time.sleep(3)
# Out:
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 500
# response: { "statusCode": 500, "message": "Internal server error", "activityId": "b34ae94d-4f8e-4eab-b0a4-bc9a7dc6df7d" }
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# ...
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# status_code: 400
# response: {"error":{"code":"InvalidURL","message":"Invalid image URL or error downloading from target server. Remote server error returned: \"Response status code does not indicate success: 404 (Not Found).\""}}
# time: 5h 34s

# %%
face_detection
# Out:
# {0: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '4bd9db44-5faf-4489-883e-f82d03296709',
#    'faceRectangle': {'height': 72, 'left': 269, 'top': 122, 'width': 72},
#    'scores': {'anger': 0.001971113,
#     'contempt': 2.04690041e-05,
#     'disgust': 7.22741461e-05,
#     'fear': 4.60088557e-07,
#     'happiness': 8.646268e-06,
#     'neutral': 0.8584766,
#     'sadness': 0.139444128,
#     'surprise': 6.35093875e-06}}],
#  1: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b44b70a5-2f19-451b-af8d-ba1335e4aaec',
#    'faceRectangle': {'height': 71, 'left': 261, 'top': 121, 'width': 71},
#    'scores': {'anger': 0.002132149,
#     'contempt': 4.886615e-05,
#     'disgust': 5.26530057e-05,
#     'fear': 1.10610408e-07,
#     'happiness': 4.38886127e-06,
#     'neutral': 0.7668614,
#     'sadness': 0.230899155,
#     'surprise': 1.29880823e-06}}],
#  2: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '2d8a65fe-eab3-46d2-8ea9-3b49a79a7b34',
#    'faceRectangle': {'height': 72, 'left': 277, 'top': 114, 'width': 72},
#    'scores': {'anger': 0.006027643,
#     'contempt': 0.000346827524,
#     'disgust': 0.000145603422,
#     'fear': 1.949877e-07,
#     'happiness': 4.9072687e-06,
#     'neutral': 0.6591162,
#     'sadness': 0.334357858,
#     'surprise': 7.42389034e-07}}],
#  3: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'd220716b-ba14-49ea-a42c-9626edb612fd',
#    'faceRectangle': {'height': 74, 'left': 322, 'top': 114, 'width': 74},
#    'scores': {'anger': 0.0123476628,
#     'contempt': 0.0003602751,
#     'disgust': 0.00163948617,
#     'fear': 4.25624e-05,
#     'happiness': 3.797583e-05,
#     'neutral': 0.771054,
#     'sadness': 0.214239389,
#     'surprise': 0.000278597145}}],
#  4: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ec57258b-7a08-4c7f-9b70-22043c4db176',
#    'faceRectangle': {'height': 73, 'left': 251, 'top': 105, 'width': 73},
#    'scores': {'anger': 0.008697362,
#     'contempt': 0.00109239842,
#     'disgust': 0.00185609981,
#     'fear': 6.6297066e-06,
#     'happiness': 8.013798e-05,
#     'neutral': 0.7318195,
#     'sadness': 0.2564133,
#     'surprise': 3.454451e-05}}],
#  5: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '0c123296-b5da-4471-881b-eabac4ee6d3a',
#    'faceRectangle': {'height': 78, 'left': 240, 'top': 93, 'width': 78},
#    'scores': {'anger': 0.0277917031,
#     'contempt': 0.001954942,
#     'disgust': 0.00192997477,
#     'fear': 4.937068e-06,
#     'happiness': 3.02027229e-06,
#     'neutral': 0.798141,
#     'sadness': 0.1701205,
#     'surprise': 5.39237044e-05}}],
#  6: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6933d8d9-1de2-47d1-bdae-bad41fb11fcb',
#    'faceRectangle': {'height': 77, 'left': 261, 'top': 85, 'width': 77},
#    'scores': {'anger': 0.269747645,
#     'contempt': 0.0009191277,
#     'disgust': 0.0320733525,
#     'fear': 0.000111619454,
#     'happiness': 2.5997073e-05,
#     'neutral': 0.556938,
#     'sadness': 0.002047151,
#     'surprise': 0.138137132}}],
#  7: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c757560e-e09b-49b2-86fd-6721d25fe1d5',
#    'faceRectangle': {'height': 71, 'left': 238, 'top': 111, 'width': 71},
#    'scores': {'anger': 0.00141674245,
#     'contempt': 3.63634972e-05,
#     'disgust': 0.000391693815,
#     'fear': 9.591283e-07,
#     'happiness': 4.831494e-06,
#     'neutral': 0.8196877,
#     'sadness': 0.178451136,
#     'surprise': 1.05574827e-05}}],
#  8: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'f2c3d19c-47e1-4721-8fb5-9ab00ee573fd',
#    'faceRectangle': {'height': 78, 'left': 238, 'top': 99, 'width': 78},
#    'scores': {'anger': 0.3982137,
#     'contempt': 0.02767659,
#     'disgust': 0.0316517279,
#     'fear': 0.00297507946,
#     'happiness': 0.000175571971,
#     'neutral': 0.493175715,
#     'sadness': 0.0106945736,
#     'surprise': 0.0354370326}}],
#  9: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '72a3c816-f586-443f-bcf5-f8c13a4880fe',
#    'faceRectangle': {'height': 72, 'left': 246, 'top': 112, 'width': 72},
#    'scores': {'anger': 0.0449398533,
#     'contempt': 0.0007592309,
#     'disgust': 0.007354765,
#     'fear': 0.000192693275,
#     'happiness': 7.36932952e-06,
#     'neutral': 0.691185832,
#     'sadness': 0.25425148,
#     'surprise': 0.00130878179}}],
#  10: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1dda3007-2ef7-4ab4-baf4-05cb9f66c67a',
#    'faceRectangle': {'height': 73, 'left': 244, 'top': 110, 'width': 73},
#    'scores': {'anger': 0.00183632481,
#     'contempt': 2.92806762e-05,
#     'disgust': 0.000131679451,
#     'fear': 2.157805e-07,
#     'happiness': 3.27694465e-07,
#     'neutral': 0.7697676,
#     'sadness': 0.228231356,
#     'surprise': 3.24150028e-06}}],
#  11: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'a5208087-3109-4fe9-8c39-88f54e869162',
#    'faceRectangle': {'height': 74, 'left': 273, 'top': 107, 'width': 74},
#    'scores': {'anger': 0.004206487,
#     'contempt': 0.000196921726,
#     'disgust': 0.000945692242,
#     'fear': 2.03060517e-06,
#     'happiness': 5.707348e-06,
#     'neutral': 0.776498139,
#     'sadness': 0.2181163,
#     'surprise': 2.87342937e-05}}],
#  12: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9b414222-f3ac-4fa7-a749-40559685a767',
#    'faceRectangle': {'height': 79, 'left': 328, 'top': 91, 'width': 79},
#    'scores': {'anger': 0.204429179,
#     'contempt': 0.00353821367,
#     'disgust': 0.0369288176,
#     'fear': 0.000709396147,
#     'happiness': 2.31592458e-05,
#     'neutral': 0.62333554,
#     'sadness': 0.00272940146,
#     'surprise': 0.1283063}}],
#  13: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'cdccb671-494d-484f-9cae-e53278e0cc27',
#    'faceRectangle': {'height': 77, 'left': 251, 'top': 89, 'width': 77},
#    'scores': {'anger': 0.08737102,
#     'contempt': 0.00318582635,
#     'disgust': 0.01501527,
#     'fear': 0.00047110836,
#     'happiness': 6.443339e-05,
#     'neutral': 0.8529724,
#     'sadness': 0.0105676148,
#     'surprise': 0.0303523671}}],
#  14: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '27e47a23-d982-4f7c-b1b8-417e7b0156a4',
#    'faceRectangle': {'height': 72, 'left': 236, 'top': 117, 'width': 72},
#    'scores': {'anger': 0.005139958,
#     'contempt': 0.000276721868,
#     'disgust': 6.35496544e-05,
#     'fear': 1.64231523e-07,
#     'happiness': 4.28151952e-06,
#     'neutral': 0.8367893,
#     'sadness': 0.157724544,
#     'surprise': 1.495728e-06}}],
#  15: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '00c100b3-5c0f-4851-a6a3-c375dc8a8926',
#    'faceRectangle': {'height': 72, 'left': 241, 'top': 114, 'width': 72},
#    'scores': {'anger': 0.0124530541,
#     'contempt': 0.0005092369,
#     'disgust': 0.0009865819,
#     'fear': 3.649977e-06,
#     'happiness': 1.7906965e-06,
#     'neutral': 0.449463218,
#     'sadness': 0.5365742,
#     'surprise': 8.298849e-06}}],
#  16: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'dc6ddebe-d73c-44bc-931c-05fd64294586',
#    'faceRectangle': {'height': 73, 'left': 245, 'top': 110, 'width': 73},
#    'scores': {'anger': 0.00608642,
#     'contempt': 0.000416210241,
#     'disgust': 0.00321796769,
#     'fear': 4.26922124e-05,
#     'happiness': 5.105585e-05,
#     'neutral': 0.6976565,
#     'sadness': 0.29219678,
#     'surprise': 0.000332381547}}],
#  17: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '51c7eabb-fb20-44b4-8d47-a2c544a39759',
#    'faceRectangle': {'height': 73, 'left': 243, 'top': 110, 'width': 73},
#    'scores': {'anger': 0.0185817629,
#     'contempt': 0.000385765132,
#     'disgust': 0.006343204,
#     'fear': 0.000109161359,
#     'happiness': 3.11490439e-05,
#     'neutral': 0.762573,
#     'sadness': 0.210718378,
#     'surprise': 0.00125757663}}],
#  18: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '2ad95f3a-f792-4ee5-9edd-a110ac69e625',
#    'faceRectangle': {'height': 71, 'left': 252, 'top': 111, 'width': 71},
#    'scores': {'anger': 0.0330567323,
#     'contempt': 0.0003259461,
#     'disgust': 0.00537515525,
#     'fear': 6.02123728e-05,
#     'happiness': 1.48225786e-06,
#     'neutral': 0.8530453,
#     'sadness': 0.103517622,
#     'surprise': 0.00461754575}}],
#  19: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '79b5e9f0-47e9-497f-a24b-2b09807cf38f',
#    'faceRectangle': {'height': 78, 'left': 319, 'top': 86, 'width': 78},
#    'scores': {'anger': 0.0928518549,
#     'contempt': 0.00556844426,
#     'disgust': 0.03406557,
#     'fear': 0.000207521385,
#     'happiness': 0.000208838872,
#     'neutral': 0.8190042,
#     'sadness': 0.00663517369,
#     'surprise': 0.04145841}}],
#  20: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'f6604564-46da-4379-96a3-8f17e43c0507',
#    'faceRectangle': {'height': 76, 'left': 299, 'top': 88, 'width': 76},
#    'scores': {'anger': 0.204444587,
#     'contempt': 0.00396970753,
#     'disgust': 0.0420080945,
#     'fear': 0.00110820017,
#     'happiness': 7.905924e-05,
#     'neutral': 0.6598042,
#     'sadness': 0.0114015574,
#     'surprise': 0.07718459}}],
#  21: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '31a73c24-5149-40e1-9616-f6b05358daf7',
#    'faceRectangle': {'height': 70, 'left': 261, 'top': 114, 'width': 70},
#    'scores': {'anger': 0.00170626654,
#     'contempt': 1.75235382e-05,
#     'disgust': 4.13010021e-05,
#     'fear': 1.27987549e-08,
#     'happiness': 3.764909e-07,
#     'neutral': 0.6872774,
#     'sadness': 0.310957,
#     'surprise': 1.415095e-07}}],
#  22: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '5dc10cf9-8315-48c1-8677-1a1e5ff5c2df',
#    'faceRectangle': {'height': 72, 'left': 262, 'top': 112, 'width': 72},
#    'scores': {'anger': 0.0226020478,
#     'contempt': 0.0002949215,
#     'disgust': 0.00121534127,
#     'fear': 2.01154962e-05,
#     'happiness': 2.11769247e-06,
#     'neutral': 0.6651407,
#     'sadness': 0.31065774,
#     'surprise': 6.704686e-05}}],
#  23: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6ceb7d7a-2cb0-4dab-8bd0-0e6ccdd749b7',
#    'faceRectangle': {'height': 72, 'left': 271, 'top': 110, 'width': 72},
#    'scores': {'anger': 0.0108578093,
#     'contempt': 8.769532e-05,
#     'disgust': 0.0006959938,
#     'fear': 3.75376828e-07,
#     'happiness': 2.04652892e-07,
#     'neutral': 0.449790776,
#     'sadness': 0.5385653,
#     'surprise': 1.86676266e-06}}],
#  24: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '3fe75b78-30aa-4084-ae05-b401af88b974',
#    'faceRectangle': {'height': 71, 'left': 289, 'top': 112, 'width': 71},
#    'scores': {'anger': 0.006477452,
#     'contempt': 5.93483928e-05,
#     'disgust': 0.000807709061,
#     'fear': 6.81282927e-06,
#     'happiness': 2.88412821e-06,
#     'neutral': 0.7717832,
#     'sadness': 0.220799282,
#     'surprise': 6.334061e-05}}],
#  25: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '630adcf2-2ac0-4864-ae4e-3f9f15f90d82',
#    'faceRectangle': {'height': 76, 'left': 267, 'top': 110, 'width': 76},
#    'scores': {'anger': 0.0203338824,
#     'contempt': 0.0002479411,
#     'disgust': 0.00150749821,
#     'fear': 7.795873e-06,
#     'happiness': 1.17390073e-05,
#     'neutral': 0.840218663,
#     'sadness': 0.137559235,
#     'surprise': 0.000113231559}}],
#  26: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '25b8bffc-dd0b-4f88-aba7-8268992d7829',
#    'faceRectangle': {'height': 78, 'left': 238, 'top': 80, 'width': 78},
#    'scores': {'anger': 0.11144089,
#     'contempt': 0.007869797,
#     'disgust': 0.006808637,
#     'fear': 1.73668159e-05,
#     'happiness': 4.0055962e-05,
#     'neutral': 0.8682432,
#     'sadness': 0.00399790658,
#     'surprise': 0.00158210692}}],
#  27: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '893077d8-406d-4a09-a94f-c3d124a7fa4d',
#    'faceRectangle': {'height': 79, 'left': 260, 'top': 86, 'width': 79},
#    'scores': {'anger': 0.234529272,
#     'contempt': 0.00255477778,
#     'disgust': 0.0488953181,
#     'fear': 0.00321181,
#     'happiness': 6.00533667e-06,
#     'neutral': 0.512172043,
#     'sadness': 0.0118017206,
#     'surprise': 0.186829031}}],
#  28: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '04275b1e-282e-411a-8a05-87de50c3ec7a',
#    'faceRectangle': {'height': 72, 'left': 247, 'top': 110, 'width': 72},
#    'scores': {'anger': 0.0030366946,
#     'contempt': 8.8980516e-05,
#     'disgust': 0.000597459,
#     'fear': 2.51557481e-06,
#     'happiness': 5.245329e-06,
#     'neutral': 0.6841927,
#     'sadness': 0.312054485,
#     'surprise': 2.19381054e-05}}],
#  29: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9a419b4a-e0ff-4d4c-b7ab-afff9c660dba',
#    'faceRectangle': {'height': 71, 'left': 245, 'top': 109, 'width': 71},
#    'scores': {'anger': 0.0063749305,
#     'contempt': 0.000120083059,
#     'disgust': 0.000365304964,
#     'fear': 6.748928e-07,
#     'happiness': 1.34942593e-06,
#     'neutral': 0.6599303,
#     'sadness': 0.3332018,
#     'surprise': 5.56632131e-06}}],
#  30: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '0af068f9-c020-4369-9c22-045a0bc98acd',
#    'faceRectangle': {'height': 70, 'left': 247, 'top': 109, 'width': 70},
#    'scores': {'anger': 0.0134578934,
#     'contempt': 0.000326316978,
#     'disgust': 0.004133825,
#     'fear': 6.16156e-05,
#     'happiness': 2.56936819e-05,
#     'neutral': 0.7871638,
#     'sadness': 0.194214314,
#     'surprise': 0.00061653374}}],
#  31: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '15b311f2-d775-4273-93c1-cde5de8e7bd8',
#    'faceRectangle': {'height': 73, 'left': 247, 'top': 104, 'width': 73},
#    'scores': {'anger': 0.0127359731,
#     'contempt': 0.000404971157,
#     'disgust': 0.00531452848,
#     'fear': 0.000174509783,
#     'happiness': 3.219019e-05,
#     'neutral': 0.89216274,
#     'sadness': 0.07288251,
#     'surprise': 0.0162926037}}],
#  32: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '900f68e3-d78b-4eb5-873e-6673e88e1351',
#    'faceRectangle': {'height': 75, 'left': 266, 'top': 99, 'width': 75},
#    'scores': {'anger': 0.0117608365,
#     'contempt': 0.00164925435,
#     'disgust': 0.00330596766,
#     'fear': 2.67585783e-05,
#     'happiness': 1.48658346e-05,
#     'neutral': 0.590552032,
#     'sadness': 0.3924856,
#     'surprise': 0.0002047083}}],
#  33: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'cb354dee-7387-40a4-a882-a3c95425ed6e',
#    'faceRectangle': {'height': 73, 'left': 249, 'top': 112, 'width': 73},
#    'scores': {'anger': 0.011492447,
#     'contempt': 0.00021778341,
#     'disgust': 0.0005912147,
#     'fear': 1.55663183e-05,
#     'happiness': 1.48510208e-05,
#     'neutral': 0.799575269,
#     'sadness': 0.1879027,
#     'surprise': 0.000190171573}}],
#  34: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '39a04670-f3a2-4165-a6c7-94d2aab68227',
#    'faceRectangle': {'height': 70, 'left': 250, 'top': 113, 'width': 70},
#    'scores': {'anger': 0.006675122,
#     'contempt': 4.94353226e-05,
#     'disgust': 0.000280951383,
#     'fear': 5.778841e-07,
#     'happiness': 6.60075159e-07,
#     'neutral': 0.7502272,
#     'sadness': 0.24276121,
#     'surprise': 4.83030271e-06}}],
#  35: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1ccd7285-9673-4ace-bfc3-86d7ccfbbfca',
#    'faceRectangle': {'height': 69, 'left': 258, 'top': 110, 'width': 69},
#    'scores': {'anger': 0.02355689,
#     'contempt': 0.000204790165,
#     'disgust': 0.00170083717,
#     'fear': 7.682645e-06,
#     'happiness': 5.99301575e-06,
#     'neutral': 0.712413251,
#     'sadness': 0.262058437,
#     'surprise': 5.21240945e-05}}],
#  36: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b5f482a3-1ec9-4092-ad4f-666c211f21e4',
#    'faceRectangle': {'height': 70, 'left': 287, 'top': 121, 'width': 70},
#    'scores': {'anger': 0.0492678657,
#     'contempt': 0.00192302628,
#     'disgust': 0.0109945312,
#     'fear': 0.0007218773,
#     'happiness': 8.462388e-05,
#     'neutral': 0.75039643,
#     'sadness': 0.18231903,
#     'surprise': 0.00429262174}}],
#  37: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ce5e74ae-f12d-4df5-89a8-016d57d67b76',
#    'faceRectangle': {'height': 71, 'left': 251, 'top': 111, 'width': 71},
#    'scores': {'anger': 0.00588843739,
#     'contempt': 0.00065731717,
#     'disgust': 0.00118952373,
#     'fear': 7.01764066e-06,
#     'happiness': 2.01668e-05,
#     'neutral': 0.7860559,
#     'sadness': 0.20608142,
#     'surprise': 0.000100200559}}],
#  38: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'd5f09b0d-66c9-4116-bdbd-3628866d3b53',
#    'faceRectangle': {'height': 71, 'left': 247, 'top': 114, 'width': 71},
#    'scores': {'anger': 0.000964010833,
#     'contempt': 1.06694561e-05,
#     'disgust': 0.000101181693,
#     'fear': 1.21931663e-07,
#     'happiness': 1.3160145e-06,
#     'neutral': 0.649330258,
#     'sadness': 0.349591255,
#     'surprise': 1.16793854e-06}}],
#  39: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8588426c-f212-4d93-8a6a-5afb6acadf26',
#    'faceRectangle': {'height': 70, 'left': 250, 'top': 112, 'width': 70},
#    'scores': {'anger': 0.105225362,
#     'contempt': 0.00243052584,
#     'disgust': 0.04844017,
#     'fear': 0.00251639425,
#     'happiness': 0.000214296757,
#     'neutral': 0.4189124,
#     'sadness': 0.4180057,
#     'surprise': 0.0042551253}}],
#  40: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '47f9ed27-6777-4f2d-8ad0-bf3c1b6e90d0',
#    'faceRectangle': {'height': 78, 'left': 279, 'top': 79, 'width': 78},
#    'scores': {'anger': 0.1618914,
#     'contempt': 0.005866509,
#     'disgust': 0.0567011423,
#     'fear': 0.0009858487,
#     'happiness': 6.1141e-05,
#     'neutral': 0.6898706,
#     'sadness': 0.008764186,
#     'surprise': 0.0758591741}}],
#  41: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '5fe5c991-593d-4752-b75c-9be3caf8fde8',
#    'faceRectangle': {'height': 75, 'left': 295, 'top': 83, 'width': 75},
#    'scores': {'anger': 0.172286659,
#     'contempt': 0.00610638,
#     'disgust': 0.0140530271,
#     'fear': 0.0003611972,
#     'happiness': 9.566644e-06,
#     'neutral': 0.7836845,
#     'sadness': 0.00852039,
#     'surprise': 0.0149782561}}],
#  42: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '006205f3-82a0-48c8-b92e-44945f796865',
#    'faceRectangle': {'height': 70, 'left': 287, 'top': 119, 'width': 70},
#    'scores': {'anger': 0.000691306137,
#     'contempt': 2.06951631e-06,
#     'disgust': 1.85639165e-05,
#     'fear': 1.75172932e-09,
#     'happiness': 4.32515037e-08,
#     'neutral': 0.358283758,
#     'sadness': 0.641004264,
#     'surprise': 6.863015e-09}}],
#  43: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'fa8acf37-37a4-4787-bed5-b7d4e36265fa',
#    'faceRectangle': {'height': 69, 'left': 239, 'top': 116, 'width': 69},
#    'scores': {'anger': 0.0354436636,
#     'contempt': 0.00219567283,
#     'disgust': 0.0128464708,
#     'fear': 0.000317235041,
#     'happiness': 0.0005498928,
#     'neutral': 0.773769259,
#     'sadness': 0.172013417,
#     'surprise': 0.00286438828}}],
#  44: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'a528c6f7-5edd-41b6-a073-8a9f9b98b4a9',
#    'faceRectangle': {'height': 78, 'left': 253, 'top': 92, 'width': 78},
#    'scores': {'anger': 0.131789252,
#     'contempt': 0.01879802,
#     'disgust': 0.027226612,
#     'fear': 0.000939709134,
#     'happiness': 0.00184746028,
#     'neutral': 0.7768873,
#     'sadness': 0.00714516453,
#     'surprise': 0.03536649}}],
#  45: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c790e35a-5968-4d74-98cb-b490ddb503d4',
#    'faceRectangle': {'height': 77, 'left': 262, 'top': 89, 'width': 77},
#    'scores': {'anger': 0.241192967,
#     'contempt': 0.00318616186,
#     'disgust': 0.02495802,
#     'fear': 0.000290347845,
#     'happiness': 3.44488144e-05,
#     'neutral': 0.6632329,
#     'sadness': 0.0015668,
#     'surprise': 0.06553832}}],
#  46: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '81195143-0e81-4121-bf4f-85abfa9a7d23',
#    'faceRectangle': {'height': 79, 'left': 230, 'top': 84, 'width': 79},
#    'scores': {'anger': 0.08846111,
#     'contempt': 0.005913449,
#     'disgust': 0.04494639,
#     'fear': 6.10323368e-05,
#     'happiness': 0.0008459553,
#     'neutral': 0.751781,
#     'sadness': 0.00456984248,
#     'surprise': 0.103421219}}],
#  47: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9f70a52c-bf4a-4561-a58f-5ea725360a77',
#    'faceRectangle': {'height': 77, 'left': 240, 'top': 85, 'width': 77},
#    'scores': {'anger': 0.146014079,
#     'contempt': 0.008522186,
#     'disgust': 0.0328185819,
#     'fear': 0.0001414354,
#     'happiness': 1.982803e-05,
#     'neutral': 0.7845243,
#     'sadness': 0.008791184,
#     'surprise': 0.0191683564}}],
#  48: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ea42254d-dd5b-44ec-8552-f9db42bbf277',
#    'faceRectangle': {'height': 69, 'left': 248, 'top': 121, 'width': 69},
#    'scores': {'anger': 0.00185445,
#     'contempt': 1.62305041e-05,
#     'disgust': 0.000144043617,
#     'fear': 2.482399e-07,
#     'happiness': 4.566808e-06,
#     'neutral': 0.596664846,
#     'sadness': 0.401314467,
#     'surprise': 1.13078261e-06}}],
#  49: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '39e755de-c3a0-44e9-8b79-c3ee20c72598',
#    'faceRectangle': {'height': 70, 'left': 248, 'top': 119, 'width': 70},
#    'scores': {'anger': 0.008460698,
#     'contempt': 1.294747e-05,
#     'disgust': 0.000168104671,
#     'fear': 3.05654424e-07,
#     'happiness': 1.43074388e-07,
#     'neutral': 0.5752635,
#     'sadness': 0.416093051,
#     'surprise': 1.270554e-06}}],
#  50: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'a96e4f6a-5209-4a12-a56b-acb9e1baeb40',
#    'faceRectangle': {'height': 70, 'left': 245, 'top': 117, 'width': 70},
#    'scores': {'anger': 0.002232738,
#     'contempt': 1.70854473e-05,
#     'disgust': 0.000102660415,
#     'fear': 1.010542e-07,
#     'happiness': 1.00604427e-06,
#     'neutral': 0.6681452,
#     'sadness': 0.3295003,
#     'surprise': 9.293126e-07}}],
#  51: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '7031161d-61dc-4074-9aec-ce01a16a432c',
#    'faceRectangle': {'height': 70, 'left': 255, 'top': 122, 'width': 70},
#    'scores': {'anger': 0.004956769,
#     'contempt': 0.000115573996,
#     'disgust': 0.0007312838,
#     'fear': 7.5493117e-06,
#     'happiness': 2.84546368e-05,
#     'neutral': 0.8440888,
#     'sadness': 0.149986178,
#     'surprise': 8.54102836e-05}}],
#  52: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8e361a39-9f3f-451f-a136-4832dae199f7',
#    'faceRectangle': {'height': 74, 'left': 283, 'top': 126, 'width': 74},
#    'scores': {'anger': 0.0570742376,
#     'contempt': 0.000411305169,
#     'disgust': 0.002018396,
#     'fear': 1.946851e-05,
#     'happiness': 2.08428482e-05,
#     'neutral': 0.774379253,
#     'sadness': 0.165960044,
#     'surprise': 0.000116453804}}],
#  53: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ac2e8411-906d-4689-974a-e287749e055b',
#    'faceRectangle': {'height': 71, 'left': 261, 'top': 122, 'width': 71},
#    'scores': {'anger': 0.000113978167,
#     'contempt': 3.34023935e-06,
#     'disgust': 2.77325739e-06,
#     'fear': 2.5638518e-09,
#     'happiness': 3.26354734e-06,
#     'neutral': 0.83011806,
#     'sadness': 0.169758573,
#     'surprise': 3.54261118e-08}}],
#  54: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'bf9a0661-8c00-462a-9ef1-262657cbc0f7',
#    'faceRectangle': {'height': 71, 'left': 262, 'top': 118, 'width': 71},
#    'scores': {'anger': 6.32653537e-05,
#     'contempt': 1.35603932e-06,
#     'disgust': 3.34975743e-06,
#     'fear': 7.68247e-10,
#     'happiness': 7.61482056e-07,
#     'neutral': 0.698628068,
#     'sadness': 0.301303178,
#     'surprise': 1.09787237e-08}}],
#  55: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '27dcd2ac-158f-4d3f-b3f0-5966b2b7c8ad',
#    'faceRectangle': {'height': 70, 'left': 265, 'top': 117, 'width': 70},
#    'scores': {'anger': 0.0180697553,
#     'contempt': 0.000283891626,
#     'disgust': 0.004942169,
#     'fear': 5.293533e-05,
#     'happiness': 5.75931954e-05,
#     'neutral': 0.653358161,
#     'sadness': 0.323019,
#     'surprise': 0.000216505}}],
#  56: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8dd16e13-461a-458e-b04e-0b4f3fc3b8ed',
#    'faceRectangle': {'height': 72, 'left': 264, 'top': 116, 'width': 72},
#    'scores': {'anger': 0.00237443461,
#     'contempt': 5.155092e-05,
#     'disgust': 0.000298725237,
#     'fear': 4.88656e-07,
#     'happiness': 1.65261633e-06,
#     'neutral': 0.7859723,
#     'sadness': 0.211293176,
#     'surprise': 7.658123e-06}}],
#  57: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '7ded180d-ff4a-482c-9a13-97ce7cbe0f97',
#    'faceRectangle': {'height': 74, 'left': 261, 'top': 102, 'width': 74},
#    'scores': {'anger': 0.008568931,
#     'contempt': 0.000285532442,
#     'disgust': 0.00152789685,
#     'fear': 5.382163e-05,
#     'happiness': 2.25847489e-05,
#     'neutral': 0.897240758,
#     'sadness': 0.09151558,
#     'surprise': 0.000784912845}}],
#  58: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '7425d9c9-86bf-4e0d-baf3-b8f5f27ea3f8',
#    'faceRectangle': {'height': 69, 'left': 279, 'top': 118, 'width': 69},
#    'scores': {'anger': 0.00277438667,
#     'contempt': 1.46670664e-05,
#     'disgust': 0.0001362093,
#     'fear': 8.49767758e-08,
#     'happiness': 2.12308669e-06,
#     'neutral': 0.6517867,
#     'sadness': 0.3452856,
#     'surprise': 2.31802915e-07}}],
#  59: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'bdaad22d-48a8-4acf-aa6d-08111063a326',
#    'faceRectangle': {'height': 69, 'left': 266, 'top': 119, 'width': 69},
#    'scores': {'anger': 0.000247846183,
#     'contempt': 2.82937754e-06,
#     'disgust': 9.294139e-06,
#     'fear': 5.1638116e-09,
#     'happiness': 1.188765e-06,
#     'neutral': 0.7162861,
#     'sadness': 0.2834527,
#     'surprise': 3.798505e-08}}],
#  60: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ca708049-12ba-42cc-b429-a8c2e8d7ca6e',
#    'faceRectangle': {'height': 72, 'left': 238, 'top': 116, 'width': 72},
#    'scores': {'anger': 0.00303139,
#     'contempt': 6.64726249e-05,
#     'disgust': 0.0005509684,
#     'fear': 7.631924e-07,
#     'happiness': 2.62204458e-06,
#     'neutral': 0.5407631,
#     'sadness': 0.4555797,
#     'surprise': 5.029534e-06}}],
#  61: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e9950356-5eec-4871-b344-cc306fb9e78c',
#    'faceRectangle': {'height': 68, 'left': 244, 'top': 120, 'width': 68},
#    'scores': {'anger': 0.0004128316,
#     'contempt': 1.08152278e-06,
#     'disgust': 1.382361e-05,
#     'fear': 4.929517e-09,
#     'happiness': 1.10719938e-07,
#     'neutral': 0.411579,
#     'sadness': 0.587993145,
#     'surprise': 2.309256e-08}}],
#  62: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1bacca90-3ac6-433c-91ef-d7fd715a2237',
#    'faceRectangle': {'height': 71, 'left': 242, 'top': 118, 'width': 71},
#    'scores': {'anger': 0.002048031,
#     'contempt': 4.337933e-06,
#     'disgust': 4.91484025e-05,
#     'fear': 5.01163555e-08,
#     'happiness': 3.38538285e-07,
#     'neutral': 0.6311226,
#     'sadness': 0.3667751,
#     'surprise': 3.74750584e-07}}],
#  63: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '4d889579-e94c-4b44-9d5e-58070c4d6e32',
#    'faceRectangle': {'height': 71, 'left': 240, 'top': 118, 'width': 71},
#    'scores': {'anger': 0.000280652574,
#     'contempt': 1.39772874e-06,
#     'disgust': 9.628861e-06,
#     'fear': 6.40304654e-09,
#     'happiness': 1.0350609e-06,
#     'neutral': 0.8326068,
#     'sadness': 0.167100415,
#     'surprise': 9.42379259e-08}}],
#  64: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '16151bb9-60df-4b57-932a-c4ba1e847b3e',
#    'faceRectangle': {'height': 71, 'left': 244, 'top': 113, 'width': 71},
#    'scores': {'anger': 0.00577399554,
#     'contempt': 7.571332e-05,
#     'disgust': 0.00125065912,
#     'fear': 4.6830487e-06,
#     'happiness': 5.3745207e-06,
#     'neutral': 0.810549736,
#     'sadness': 0.1822705,
#     'surprise': 6.936404e-05}}],
#  65: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c39f6f3c-d236-4eb5-b570-5afbfadfc259',
#    'faceRectangle': {'height': 77, 'left': 267, 'top': 85, 'width': 77},
#    'scores': {'anger': 0.07216657,
#     'contempt': 0.00297473278,
#     'disgust': 0.01936267,
#     'fear': 0.000402326463,
#     'happiness': 6.499459e-05,
#     'neutral': 0.817153752,
#     'sadness': 0.004482345,
#     'surprise': 0.08339261}}],
#  66: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '516a491f-a72e-498e-845a-33b82ea4b8db',
#    'faceRectangle': {'height': 79, 'left': 260, 'top': 82, 'width': 79},
#    'scores': {'anger': 0.307336479,
#     'contempt': 0.0102328509,
#     'disgust': 0.0188240558,
#     'fear': 0.000641129969,
#     'happiness': 6.45320542e-05,
#     'neutral': 0.6397335,
#     'sadness': 0.0053269905,
#     'surprise': 0.0178404525}}],
#  67: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c26cb419-c9c6-465d-ba78-50854c2e8179',
#    'faceRectangle': {'height': 68, 'left': 242, 'top': 123, 'width': 68},
#    'scores': {'anger': 0.000747219543,
#     'contempt': 2.34147774e-05,
#     'disgust': 5.117263e-05,
#     'fear': 5.83574575e-08,
#     'happiness': 6.720895e-06,
#     'neutral': 0.663219154,
#     'sadness': 0.335951865,
#     'surprise': 3.715149e-07}}],
#  68: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '2b98e839-73f4-43f1-a822-cd9625034bdb',
#    'faceRectangle': {'height': 69, 'left': 246, 'top': 121, 'width': 69},
#    'scores': {'anger': 0.042306602,
#     'contempt': 0.00119981985,
#     'disgust': 0.00993107,
#     'fear': 0.000252183265,
#     'happiness': 3.57048921e-05,
#     'neutral': 0.674683452,
#     'sadness': 0.2702163,
#     'surprise': 0.001374871}}],
#  69: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'a69e2316-e8fc-4b19-aedd-72a9760cd171',
#    'faceRectangle': {'height': 67, 'left': 246, 'top': 121, 'width': 67},
#    'scores': {'anger': 0.0003076076,
#     'contempt': 1.14304366e-05,
#     'disgust': 3.811494e-05,
#     'fear': 2.97787164e-08,
#     'happiness': 9.00947157e-07,
#     'neutral': 0.5760286,
#     'sadness': 0.4236131,
#     'surprise': 2.13306649e-07}}],
#  70: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '371116d4-0dea-4a62-bc5e-8a130c83097a',
#    'faceRectangle': {'height': 70, 'left': 250, 'top': 119, 'width': 70},
#    'scores': {'anger': 0.0003896233,
#     'contempt': 5.927367e-06,
#     'disgust': 1.02538079e-05,
#     'fear': 1.95164751e-09,
#     'happiness': 6.910599e-07,
#     'neutral': 0.8198304,
#     'sadness': 0.179763034,
#     'surprise': 6.30240251e-08}}],
#  71: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '5574d47a-3f96-407e-b1f7-3e515bb7d4ac',
#    'faceRectangle': {'height': 76, 'left': 275, 'top': 84, 'width': 76},
#    'scores': {'anger': 0.09578502,
#     'contempt': 0.001404881,
#     'disgust': 0.0255554263,
#     'fear': 0.000376965,
#     'happiness': 6.204155e-05,
#     'neutral': 0.7381205,
#     'sadness': 0.00533135841,
#     'surprise': 0.133363813}}],
#  72: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c93ef9fd-f673-4258-8e3d-89bd5a334bec',
#    'faceRectangle': {'height': 70, 'left': 313, 'top': 119, 'width': 70},
#    'scores': {'anger': 0.0236819759,
#     'contempt': 0.000378637953,
#     'disgust': 0.008285817,
#     'fear': 0.000338477927,
#     'happiness': 8.446778e-06,
#     'neutral': 0.667676449,
#     'sadness': 0.2964181,
#     'surprise': 0.00321212434}}],
#  73: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1a9c8562-81f6-4900-b288-a9f8ad348440',
#    'faceRectangle': {'height': 73, 'left': 282, 'top': 104, 'width': 73},
#    'scores': {'anger': 0.003311979,
#     'contempt': 0.0002692187,
#     'disgust': 0.005360708,
#     'fear': 7.996463e-05,
#     'happiness': 1.19074866e-05,
#     'neutral': 0.6113084,
#     'sadness': 0.377439231,
#     'surprise': 0.00221860083}}],
#  74: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '33233bd4-f18d-4497-a401-bf05ba2808a9',
#    'faceRectangle': {'height': 78, 'left': 275, 'top': 85, 'width': 78},
#    'scores': {'anger': 0.206884861,
#     'contempt': 0.0132393483,
#     'disgust': 0.0168501474,
#     'fear': 0.0005865478,
#     'happiness': 4.239038e-05,
#     'neutral': 0.7314971,
#     'sadness': 0.0194283146,
#     'surprise': 0.0114713022}}],
#  75: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '7cf12afc-bef2-4022-8e74-ec048d3cd6ca',
#    'faceRectangle': {'height': 72, 'left': 276, 'top': 108, 'width': 72},
#    'scores': {'anger': 0.00568251265,
#     'contempt': 0.00010729934,
#     'disgust': 0.0007476517,
#     'fear': 1.91278741e-05,
#     'happiness': 5.692976e-05,
#     'neutral': 0.7849672,
#     'sadness': 0.2082709,
#     'surprise': 0.000148358755}}],
#  76: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '21d4bd91-5a29-4221-badd-3351917b665a',
#    'faceRectangle': {'height': 71, 'left': 275, 'top': 104, 'width': 71},
#    'scores': {'anger': 0.0115433568,
#     'contempt': 0.000532612263,
#     'disgust': 0.008934352,
#     'fear': 0.000327128655,
#     'happiness': 3.197644e-06,
#     'neutral': 0.6652897,
#     'sadness': 0.308706135,
#     'surprise': 0.00466355076}}],
#  77: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b108d85e-4820-4e9b-907a-68bb9b5492f9',
#    'faceRectangle': {'height': 72, 'left': 277, 'top': 103, 'width': 72},
#    'scores': {'anger': 0.0339910537,
#     'contempt': 0.00111717766,
#     'disgust': 0.0345766842,
#     'fear': 0.000691898749,
#     'happiness': 2.09319041e-05,
#     'neutral': 0.580393136,
#     'sadness': 0.3436837,
#     'surprise': 0.00552542}}],
#  78: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b42c5af5-bb91-411e-8e0b-5b1699f606ab',
#    'faceRectangle': {'height': 81, 'left': 290, 'top': 84, 'width': 81},
#    'scores': {'anger': 0.179673538,
#     'contempt': 0.008103376,
#     'disgust': 0.0618086234,
#     'fear': 0.001692882,
#     'happiness': 0.000123870312,
#     'neutral': 0.6729756,
#     'sadness': 0.027657371,
#     'surprise': 0.0479647145}}],
#  79: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '4c6f8de1-50ef-4cb7-9b2f-ac9c51ba5167',
#    'faceRectangle': {'height': 72, 'left': 312, 'top': 113, 'width': 72},
#    'scores': {'anger': 0.007794817,
#     'contempt': 0.0004649961,
#     'disgust': 0.00387932523,
#     'fear': 0.000102944876,
#     'happiness': 6.53175e-06,
#     'neutral': 0.7348535,
#     'sadness': 0.251110017,
#     'surprise': 0.00178784446}}],
#  80: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '396e4674-0542-424b-abb6-0c6778b25f66',
#    'faceRectangle': {'height': 71, 'left': 259, 'top': 109, 'width': 71},
#    'scores': {'anger': 0.009189459,
#     'contempt': 7.56189038e-05,
#     'disgust': 0.00101705571,
#     'fear': 1.38046771e-05,
#     'happiness': 1.20372488e-06,
#     'neutral': 0.6625538,
#     'sadness': 0.326934874,
#     'surprise': 0.000214200525}}],
#  81: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '41242c95-87b3-4bd2-ab53-ea96b591556a',
#    'faceRectangle': {'height': 77, 'left': 249, 'top': 84, 'width': 77},
#    'scores': {'anger': 0.1270935,
#     'contempt': 0.006249935,
#     'disgust': 0.0185013879,
#     'fear': 9.55151263e-05,
#     'happiness': 5.51078956e-05,
#     'neutral': 0.8352824,
#     'sadness': 0.008949383,
#     'surprise': 0.00377276959}}],
#  82: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9c577e41-7737-4d32-88a4-edc31b83b312',
#    'faceRectangle': {'height': 78, 'left': 235, 'top': 86, 'width': 78},
#    'scores': {'anger': 0.09092488,
#     'contempt': 0.0114114489,
#     'disgust': 0.00383840757,
#     'fear': 3.613368e-07,
#     'happiness': 1.64985067e-05,
#     'neutral': 0.8928073,
#     'sadness': 0.00083722634,
#     'surprise': 0.0001638793}}],
#  83: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '5bed0f45-28cd-4f5d-87da-3af59d51a010',
#    'faceRectangle': {'height': 70, 'left': 260, 'top': 110, 'width': 70},
#    'scores': {'anger': 0.0106630875,
#     'contempt': 0.000651529,
#     'disgust': 0.009676351,
#     'fear': 0.000482953154,
#     'happiness': 2.53564631e-05,
#     'neutral': 0.7648217,
#     'sadness': 0.20847179,
#     'surprise': 0.00520720147}}],
#  84: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '5c366cad-a3f5-4ef2-a59c-f4168b47ef81',
#    'faceRectangle': {'height': 72, 'left': 254, 'top': 107, 'width': 72},
#    'scores': {'anger': 0.004686799,
#     'contempt': 0.000277087762,
#     'disgust': 0.00214081816,
#     'fear': 4.263242e-05,
#     'happiness': 1.50361711e-05,
#     'neutral': 0.782861531,
#     'sadness': 0.208599374,
#     'surprise': 0.00137671712}}],
#  85: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '40d10f62-d144-4460-a879-f0b4518f38e1',
#    'faceRectangle': {'height': 77, 'left': 260, 'top': 93, 'width': 77},
#    'scores': {'anger': 0.08135582,
#     'contempt': 0.00491111167,
#     'disgust': 0.007623443,
#     'fear': 0.000357069046,
#     'happiness': 7.375946e-05,
#     'neutral': 0.885071456,
#     'sadness': 0.00610540574,
#     'surprise': 0.0145019349}}],
#  86: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '484d0a35-6380-4319-bf53-365c57a1161d',
#    'faceRectangle': {'height': 71, 'left': 268, 'top': 109, 'width': 71},
#    'scores': {'anger': 0.009280335,
#     'contempt': 0.000937686535,
#     'disgust': 0.003922899,
#     'fear': 8.36346444e-05,
#     'happiness': 1.60617874e-05,
#     'neutral': 0.7494853,
#     'sadness': 0.234645,
#     'surprise': 0.00162907341}}],
#  87: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'bdc23641-8343-4556-821d-cceef7835105',
#    'faceRectangle': {'height': 71, 'left': 263, 'top': 106, 'width': 71},
#    'scores': {'anger': 0.00145263725,
#     'contempt': 0.000197301168,
#     'disgust': 0.000755633344,
#     'fear': 7.68312748e-06,
#     'happiness': 2.374532e-05,
#     'neutral': 0.8720114,
#     'sadness': 0.125184089,
#     'surprise': 0.000367490225}}],
#  88: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c0ce3460-3914-4e51-8c96-42805c99fe05',
#    'faceRectangle': {'height': 71, 'left': 271, 'top': 110, 'width': 71},
#    'scores': {'anger': 0.00463462947,
#     'contempt': 0.000230659251,
#     'disgust': 0.00123193488,
#     'fear': 1.585362e-05,
#     'happiness': 6.26125e-06,
#     'neutral': 0.7079864,
#     'sadness': 0.285662264,
#     'surprise': 0.000231979328}}],
#  89: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b9d3249d-a25a-4eb8-8ee9-172b7ab66d77',
#    'faceRectangle': {'height': 72, 'left': 268, 'top': 110, 'width': 72},
#    'scores': {'anger': 0.00195049553,
#     'contempt': 8.896455e-05,
#     'disgust': 0.000628692564,
#     'fear': 5.47755826e-06,
#     'happiness': 8.709099e-06,
#     'neutral': 0.793023646,
#     'sadness': 0.204087824,
#     'surprise': 0.000206180353}}],
#  90: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '0e9634e0-afb8-4888-953d-e4fb2524c502',
#    'faceRectangle': {'height': 73, 'left': 267, 'top': 109, 'width': 73},
#    'scores': {'anger': 0.006777096,
#     'contempt': 0.000661336235,
#     'disgust': 0.0007292286,
#     'fear': 1.748216e-05,
#     'happiness': 8.600045e-06,
#     'neutral': 0.841960669,
#     'sadness': 0.14952901,
#     'surprise': 0.000316605263}}],
#  91: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b39e94f3-a1d1-4a90-aa70-ad51980266dc',
#    'faceRectangle': {'height': 70, 'left': 300, 'top': 120, 'width': 70},
#    'scores': {'anger': 0.007832009,
#     'contempt': 0.000102451966,
#     'disgust': 0.0008045632,
#     'fear': 3.953491e-06,
#     'happiness': 1.69285158e-06,
#     'neutral': 0.728156,
#     'sadness': 0.26304996,
#     'surprise': 4.941466e-05}}],
#  92: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '4ee9389b-9267-44b8-99c2-2a8250841df3',
#    'faceRectangle': {'height': 73, 'left': 266, 'top': 103, 'width': 73},
#    'scores': {'anger': 0.0505358353,
#     'contempt': 0.001266806,
#     'disgust': 0.0143935392,
#     'fear': 0.0010775344,
#     'happiness': 8.889312e-05,
#     'neutral': 0.822748244,
#     'sadness': 0.08392879,
#     'surprise': 0.02596036}}],
#  93: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1b76e2b9-de24-4ed6-b556-19effb8b24b1',
#    'faceRectangle': {'height': 72, 'left': 265, 'top': 106, 'width': 72},
#    'scores': {'anger': 0.00270362524,
#     'contempt': 0.000258738,
#     'disgust': 0.0028978514,
#     'fear': 3.50851733e-05,
#     'happiness': 1.84543078e-05,
#     'neutral': 0.752156,
#     'sadness': 0.241268709,
#     'surprise': 0.000661500031}}],
#  94: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b60d73e0-3120-4d33-a59e-ab96df1f617a',
#    'faceRectangle': {'height': 76, 'left': 262, 'top': 77, 'width': 76},
#    'scores': {'anger': 0.03705416,
#     'contempt': 0.005752521,
#     'disgust': 0.009363123,
#     'fear': 4.32334273e-05,
#     'happiness': 0.000224453092,
#     'neutral': 0.9371369,
#     'sadness': 0.00361082121,
#     'surprise': 0.00681479927}}],
#  95: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1ffe476c-62fd-47eb-affa-e68e62e3c4e0',
#    'faceRectangle': {'height': 70, 'left': 270, 'top': 105, 'width': 70},
#    'scores': {'anger': 0.03421253,
#     'contempt': 0.0009151461,
#     'disgust': 0.0281567685,
#     'fear': 0.0006875916,
#     'happiness': 6.001039e-06,
#     'neutral': 0.590918839,
#     'sadness': 0.341144145,
#     'surprise': 0.003958979}}],
#  96: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '818f36ed-b975-4a67-9578-c25281e8e9e2',
#    'faceRectangle': {'height': 71, 'left': 269, 'top': 107, 'width': 71},
#    'scores': {'anger': 0.0201187972,
#     'contempt': 0.0006120542,
#     'disgust': 0.0102700237,
#     'fear': 9.855085e-05,
#     'happiness': 2.71086446e-05,
#     'neutral': 0.8777232,
#     'sadness': 0.08158774,
#     'surprise': 0.009562522}}],
#  97: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '590f24d1-1a09-4a4d-94f6-6b495986c650',
#    'faceRectangle': {'height': 71, 'left': 261, 'top': 109, 'width': 71},
#    'scores': {'anger': 0.00125209941,
#     'contempt': 7.842128e-06,
#     'disgust': 5.12653241e-05,
#     'fear': 2.037582e-07,
#     'happiness': 1.209786e-07,
#     'neutral': 0.804591656,
#     'sadness': 0.194090113,
#     'surprise': 6.685452e-06}}],
#  98: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1da5d487-ca0d-4642-a54a-8d7b2c3b72ef',
#    'faceRectangle': {'height': 72, 'left': 264, 'top': 110, 'width': 72},
#    'scores': {'anger': 0.00274035661,
#     'contempt': 6.781949e-05,
#     'disgust': 0.000204449971,
#     'fear': 2.435136e-06,
#     'happiness': 7.33568959e-06,
#     'neutral': 0.88284,
#     'sadness': 0.114082538,
#     'surprise': 5.50980658e-05}}],
#  99: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b92d683e-06a5-466a-955c-93a091c010fd',
#    'faceRectangle': {'height': 80, 'left': 259, 'top': 84, 'width': 80},
#    'scores': {'anger': 0.268838465,
#     'contempt': 0.00447208341,
#     'disgust': 0.03653569,
#     'fear': 0.000156415743,
#     'happiness': 0.000554123253,
#     'neutral': 0.6222389,
#     'sadness': 0.00253215479,
#     'surprise': 0.06467222}}],
#  100: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '13d2c6c8-0307-48c6-9f33-37142550a181',
#    'faceRectangle': {'height': 75, 'left': 267, 'top': 98, 'width': 75},
#    'scores': {'anger': 0.00289265742,
#     'contempt': 0.00105997827,
#     'disgust': 0.000722077559,
#     'fear': 6.022187e-06,
#     'happiness': 4.303931e-05,
#     'neutral': 0.7697799,
#     'sadness': 0.225410849,
#     'surprise': 8.543111e-05}}],
#  101: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '84da424d-01ff-4d1e-8566-9573cf1d686e',
#    'faceRectangle': {'height': 71, 'left': 270, 'top': 110, 'width': 71},
#    'scores': {'anger': 0.009918509,
#     'contempt': 0.0006129535,
#     'disgust': 0.006617695,
#     'fear': 0.000271646,
#     'happiness': 1.49006164e-05,
#     'neutral': 0.8288774,
#     'sadness': 0.1444453,
#     'surprise': 0.009241585}}],
#  102: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '2c397d07-4fdd-4fab-9e58-822f970edc9c',
#    'faceRectangle': {'height': 72, 'left': 280, 'top': 110, 'width': 72},
#    'scores': {'anger': 0.0027408232,
#     'contempt': 0.000116627984,
#     'disgust': 0.0003399797,
#     'fear': 7.761537e-07,
#     'happiness': 1.50142967e-06,
#     'neutral': 0.8304036,
#     'sadness': 0.1663797,
#     'surprise': 1.69309842e-05}}],
#  103: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'bdffd000-bf6c-4bbf-a260-4b66085d83fb',
#    'faceRectangle': {'height': 73, 'left': 283, 'top': 105, 'width': 73},
#    'scores': {'anger': 0.00209027831,
#     'contempt': 0.0001547873,
#     'disgust': 0.0003238473,
#     'fear': 2.07693779e-06,
#     'happiness': 4.233439e-06,
#     'neutral': 0.7829269,
#     'sadness': 0.2144647,
#     'surprise': 3.314498e-05}}],
#  104: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '93739142-8c49-4ce8-bc5b-f1e2e191e8a6',
#    'faceRectangle': {'height': 73, 'left': 280, 'top': 111, 'width': 73},
#    'scores': {'anger': 0.00588831538,
#     'contempt': 0.000188916747,
#     'disgust': 0.00154408393,
#     'fear': 2.2815706e-05,
#     'happiness': 1.13963e-05,
#     'neutral': 0.8683589,
#     'sadness': 0.123088211,
#     'surprise': 0.0008973554}}],
#  105: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b472999a-e824-48ee-aa06-be5346cb4f37',
#    'faceRectangle': {'height': 71, 'left': 246, 'top': 118, 'width': 71},
#    'scores': {'anger': 0.0165630486,
#     'contempt': 0.000154783353,
#     'disgust': 0.0012221185,
#     'fear': 3.76795651e-05,
#     'happiness': 9.36735e-06,
#     'neutral': 0.824586,
#     'sadness': 0.157155424,
#     'surprise': 0.0002715771}}],
#  106: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6d537318-0c34-418e-9e1f-d9d366a0fc8f',
#    'faceRectangle': {'height': 80, 'left': 223, 'top': 85, 'width': 80},
#    'scores': {'anger': 0.06994896,
#     'contempt': 0.0146999145,
#     'disgust': 0.00203968328,
#     'fear': 6.46845547e-06,
#     'happiness': 8.00476e-05,
#     'neutral': 0.9089633,
#     'sadness': 0.00408332329,
#     'surprise': 0.000178257163}}],
#  107: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '867f79e3-1aa0-41b0-8fcc-689b2c55df6b',
#    'faceRectangle': {'height': 69, 'left': 251, 'top': 117, 'width': 69},
#    'scores': {'anger': 0.01262119,
#     'contempt': 4.33377463e-05,
#     'disgust': 0.0002561969,
#     'fear': 2.81322741e-06,
#     'happiness': 1.07234632e-06,
#     'neutral': 0.639366269,
#     'sadness': 0.3476993,
#     'surprise': 9.781033e-06}}],
#  108: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'cc97a5c8-a531-405c-892b-cb45c4090940',
#    'faceRectangle': {'height': 71, 'left': 251, 'top': 115, 'width': 71},
#    'scores': {'anger': 0.0177393537,
#     'contempt': 0.000402000529,
#     'disgust': 0.00455206027,
#     'fear': 4.57738279e-05,
#     'happiness': 9.094791e-06,
#     'neutral': 0.616171062,
#     'sadness': 0.3608787,
#     'surprise': 0.000201970528}}],
#  109: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '56b5fb7a-4c82-49fa-8adc-7ed9064c0eb4',
#    'faceRectangle': {'height': 73, 'left': 246, 'top': 109, 'width': 73},
#    'scores': {'anger': 0.00456459774,
#     'contempt': 6.78642537e-05,
#     'disgust': 0.000891683332,
#     'fear': 6.07065249e-06,
#     'happiness': 2.442038e-06,
#     'neutral': 0.7523963,
#     'sadness': 0.241822228,
#     'surprise': 0.000248798373}}],
#  110: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1da06179-bddc-4685-a9dc-ee666b4ad4d6',
#    'faceRectangle': {'height': 71, 'left': 258, 'top': 114, 'width': 71},
#    'scores': {'anger': 0.0165628679,
#     'contempt': 0.000336133118,
#     'disgust': 0.004079831,
#     'fear': 7.65814257e-05,
#     'happiness': 2.76580322e-05,
#     'neutral': 0.7515187,
#     'sadness': 0.2265326,
#     'surprise': 0.0008656227}}],
#  111: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'c93ab3b5-6316-496f-b1ba-8f19526eefaa',
#    'faceRectangle': {'height': 71, 'left': 293, 'top': 124, 'width': 71},
#    'scores': {'anger': 0.00109876646,
#     'contempt': 4.526362e-05,
#     'disgust': 0.000105133935,
#     'fear': 3.21293868e-07,
#     'happiness': 1.05194258e-05,
#     'neutral': 0.781082034,
#     'sadness': 0.217655391,
#     'surprise': 2.57483475e-06}}],
#  112: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'df384858-3395-4c32-8778-d87f2ee1bdc5',
#    'faceRectangle': {'height': 77, 'left': 266, 'top': 89, 'width': 77},
#    'scores': {'anger': 0.002063068,
#     'contempt': 0.00481074955,
#     'disgust': 0.002292358,
#     'fear': 3.52113348e-05,
#     'happiness': 9.98894538e-05,
#     'neutral': 0.910968363,
#     'sadness': 0.07915086,
#     'surprise': 0.000579506042}}],
#  113: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e5316fd7-ed5a-4c0f-ab0a-1bc0bfb1adfd',
#    'faceRectangle': {'height': 69, 'left': 273, 'top': 115, 'width': 69},
#    'scores': {'anger': 0.0106608281,
#     'contempt': 6.50030343e-05,
#     'disgust': 0.000666022243,
#     'fear': 8.561373e-05,
#     'happiness': 1.83946722e-05,
#     'neutral': 0.865507543,
#     'sadness': 0.121377587,
#     'surprise': 0.00161902455}}],
#  114: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'a306043c-f022-47e2-9a65-aa1db99575f0',
#    'faceRectangle': {'height': 80, 'left': 254, 'top': 84, 'width': 80},
#    'scores': {'anger': 0.08438294,
#     'contempt': 0.00593616627,
#     'disgust': 0.0286280718,
#     'fear': 0.000262333138,
#     'happiness': 0.000421313744,
#     'neutral': 0.797967851,
#     'sadness': 0.005576874,
#     'surprise': 0.07682443}}],
#  115: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1070af32-c6b5-4143-8c0e-54ea4dd0d71b',
#    'faceRectangle': {'height': 71, 'left': 265, 'top': 115, 'width': 71},
# ...
#     'disgust': 0.0009449288,
#     'fear': 9.890352e-07,
#     'happiness': 7.71191935e-07,
#     'neutral': 0.8971993,
#     'sadness': 0.0272485167,
#     'surprise': 1.04123628e-05}}],
#  1121: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '00dfdc6c-c860-4e5c-bb40-4ec8cf7745ac',
#    'faceRectangle': {'height': 78, 'left': 242, 'top': 98, 'width': 78},
#    'scores': {'anger': 0.07928059,
#     'contempt': 0.000902809668,
#     'disgust': 0.0005264114,
#     'fear': 6.2163e-07,
#     'happiness': 6.280594e-08,
#     'neutral': 0.851751864,
#     'sadness': 0.06753361,
#     'surprise': 4.006877e-06}}],
#  1122: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'adb2ce6e-8705-4841-9525-c585e3402652',
#    'faceRectangle': {'height': 79, 'left': 238, 'top': 93, 'width': 79},
#    'scores': {'anger': 0.128464282,
#     'contempt': 0.005376042,
#     'disgust': 0.0226951726,
#     'fear': 0.000477986585,
#     'happiness': 2.21291448e-05,
#     'neutral': 0.788276851,
#     'sadness': 0.0441917,
#     'surprise': 0.0104958583}}],
#  1126: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'd19474c4-b650-41d4-a103-25df447319bc',
#    'faceRectangle': {'height': 74, 'left': 240, 'top': 90, 'width': 74},
#    'scores': {'anger': 5.258589e-07,
#     'contempt': 1.0383453e-07,
#     'disgust': 2.07898047e-05,
#     'fear': 6.654167e-10,
#     'happiness': 0.999959946,
#     'neutral': 1.617303e-05,
#     'sadness': 1.28502109e-06,
#     'surprise': 1.1991292e-06}}],
#  1127: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '075ca4f7-31d3-491f-9ac7-9f07bd4e306e',
#    'faceRectangle': {'height': 75, 'left': 237, 'top': 88, 'width': 75},
#    'scores': {'anger': 0.0032100603,
#     'contempt': 0.0517128259,
#     'disgust': 0.00779912667,
#     'fear': 7.234555e-05,
#     'happiness': 0.4762503,
#     'neutral': 0.4426332,
#     'sadness': 0.00151336787,
#     'surprise': 0.01680877}}],
#  1128: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '362ff7b1-4d91-4799-95ef-ab6de38c0585',
#    'faceRectangle': {'height': 79, 'left': 234, 'top': 89, 'width': 79},
#    'scores': {'anger': 0.078276664,
#     'contempt': 0.006862496,
#     'disgust': 0.0362953655,
#     'fear': 0.00185022957,
#     'happiness': 0.0758222,
#     'neutral': 0.5982939,
#     'sadness': 0.038987495,
#     'surprise': 0.16361165}}],
#  1129: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'f242b66a-0db9-4175-81e5-298acfdaed56',
#    'faceRectangle': {'height': 78, 'left': 234, 'top': 97, 'width': 78},
#    'scores': {'anger': 0.0148478942,
#     'contempt': 0.00353400339,
#     'disgust': 0.01679553,
#     'fear': 0.000159697272,
#     'happiness': 0.03153526,
#     'neutral': 0.912582636,
#     'sadness': 0.009336049,
#     'surprise': 0.0112089012}}],
#  1130: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'cf9d66ec-db36-4139-a65c-9b5f7af5e322',
#    'faceRectangle': {'height': 77, 'left': 240, 'top': 94, 'width': 77},
#    'scores': {'anger': 0.06490418,
#     'contempt': 0.008157171,
#     'disgust': 0.0426176824,
#     'fear': 0.0004999151,
#     'happiness': 0.002354738,
#     'neutral': 0.8296793,
#     'sadness': 0.0199481584,
#     'surprise': 0.0318388455}}],
#  1131: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e90dc720-df7c-4153-bb70-0bb49ce1b7f7',
#    'faceRectangle': {'height': 75, 'left': 237, 'top': 102, 'width': 75},
#    'scores': {'anger': 0.00753782224,
#     'contempt': 0.0017371315,
#     'disgust': 0.00768054975,
#     'fear': 0.000209675884,
#     'happiness': 0.000321022759,
#     'neutral': 0.913595736,
#     'sadness': 0.0132318512,
#     'surprise': 0.05568624}}],
#  1132: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8c47f10c-6d5c-4b88-9e18-4571d0c244d8',
#    'faceRectangle': {'height': 78, 'left': 240, 'top': 98, 'width': 78},
#    'scores': {'anger': 0.0114759579,
#     'contempt': 0.00588070741,
#     'disgust': 0.00300474046,
#     'fear': 3.50714777e-06,
#     'happiness': 7.264939e-05,
#     'neutral': 0.9715484,
#     'sadness': 0.007844425,
#     'surprise': 0.000169660445}}],
#  1133: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'fe4fe813-8f1c-484e-831b-2ae6f0abdea4',
#    'faceRectangle': {'height': 81, 'left': 241, 'top': 95, 'width': 81},
#    'scores': {'anger': 0.0202939771,
#     'contempt': 0.007503074,
#     'disgust': 0.0137514323,
#     'fear': 4.83308431e-05,
#     'happiness': 0.0009992027,
#     'neutral': 0.9340319,
#     'sadness': 0.0220290516,
#     'surprise': 0.0013430363}}],
#  1134: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'f670da30-ef5a-487e-aac3-b6495caa600f',
#    'faceRectangle': {'height': 78, 'left': 241, 'top': 101, 'width': 78},
#    'scores': {'anger': 0.316994131,
#     'contempt': 0.013351527,
#     'disgust': 0.08114318,
#     'fear': 0.00124005228,
#     'happiness': 6.47267661e-05,
#     'neutral': 0.5429959,
#     'sadness': 0.0264215562,
#     'surprise': 0.0177889075}}],
#  1135: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e1c8926f-9df1-4689-a40b-471d15555f99',
#    'faceRectangle': {'height': 78, 'left': 249, 'top': 101, 'width': 78},
#    'scores': {'anger': 0.0302945226,
#     'contempt': 0.00366124045,
#     'disgust': 0.008507461,
#     'fear': 0.0002671298,
#     'happiness': 0.000219958471,
#     'neutral': 0.924793839,
#     'sadness': 0.01981726,
#     'surprise': 0.0124386111}}],
#  1136: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e72b6f45-4148-4b4a-aac3-3d7d6ac9ba59',
#    'faceRectangle': {'height': 78, 'left': 247, 'top': 93, 'width': 78},
#    'scores': {'anger': 0.0788141638,
#     'contempt': 0.007070642,
#     'disgust': 0.0310290754,
#     'fear': 0.000796446169,
#     'happiness': 0.00342666334,
#     'neutral': 0.8389096,
#     'sadness': 0.0200895518,
#     'surprise': 0.0198638532}}],
#  1137: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'e6ef6e7d-5665-4b7e-8f1c-e93962d5fe24',
#    'faceRectangle': {'height': 75, 'left': 249, 'top': 93, 'width': 75},
#    'scores': {'anger': 0.06073325,
#     'contempt': 0.00620421534,
#     'disgust': 0.0134474114,
#     'fear': 0.000202139447,
#     'happiness': 0.000144505815,
#     'neutral': 0.8553493,
#     'sadness': 0.0590683147,
#     'surprise': 0.00485084252}}],
#  1138: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b4cf4254-a046-429b-9b61-75ce116a76f7',
#    'faceRectangle': {'height': 78, 'left': 243, 'top': 95, 'width': 78},
#    'scores': {'anger': 0.03380361,
#     'contempt': 0.008222178,
#     'disgust': 0.014259899,
#     'fear': 9.52187838e-05,
#     'happiness': 0.00200887956,
#     'neutral': 0.918925166,
#     'sadness': 0.0200577937,
#     'surprise': 0.002627274}}],
#  1139: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '4ac5c91e-0698-4b59-8d18-bac98474fb04',
#    'faceRectangle': {'height': 75, 'left': 246, 'top': 90, 'width': 75},
#    'scores': {'anger': 0.04542935,
#     'contempt': 0.003817089,
#     'disgust': 0.0302725434,
#     'fear': 0.0002987945,
#     'happiness': 0.000377746241,
#     'neutral': 0.8380767,
#     'sadness': 0.01755608,
#     'surprise': 0.06417168}}],
#  1140: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '78e933d2-055d-4beb-a68e-74674ee52ff8',
#    'faceRectangle': {'height': 75, 'left': 264, 'top': 86, 'width': 75},
#    'scores': {'anger': 0.0273440555,
#     'contempt': 0.01007336,
#     'disgust': 0.0199503154,
#     'fear': 5.14080457e-05,
#     'happiness': 0.000366743,
#     'neutral': 0.925218761,
#     'sadness': 0.00629072171,
#     'surprise': 0.0107046142}}],
#  1141: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'd5cc10d9-6c28-4062-8005-3243b9196f50',
#    'faceRectangle': {'height': 77, 'left': 279, 'top': 94, 'width': 77},
#    'scores': {'anger': 0.00445633335,
#     'contempt': 0.003984241,
#     'disgust': 0.00411727838,
#     'fear': 0.000160680866,
#     'happiness': 0.00010240377,
#     'neutral': 0.8259233,
#     'sadness': 0.160010412,
#     'surprise': 0.00124535325}}],
#  1142: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '99ff7eed-46ff-4b1c-ba40-45908a165a59',
#    'faceRectangle': {'height': 77, 'left': 267, 'top': 84, 'width': 77},
#    'scores': {'anger': 0.07681658,
#     'contempt': 0.00387579948,
#     'disgust': 0.045703914,
#     'fear': 0.0010766905,
#     'happiness': 0.000101184931,
#     'neutral': 0.7499825,
#     'sadness': 0.06056402,
#     'surprise': 0.0618793368}}],
#  1143: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6d09ebfe-20fd-4058-8411-1b57d9f27ea5',
#    'faceRectangle': {'height': 76, 'left': 269, 'top': 89, 'width': 76},
#    'scores': {'anger': 0.02572347,
#     'contempt': 0.007577161,
#     'disgust': 0.0185385086,
#     'fear': 0.000372033363,
#     'happiness': 0.000680985861,
#     'neutral': 0.896285057,
#     'sadness': 0.0409776457,
#     'surprise': 0.009845136}}],
#  1144: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'b0b5c563-f831-4003-acc0-da6655d3d21b',
#    'faceRectangle': {'height': 79, 'left': 270, 'top': 90, 'width': 79},
#    'scores': {'anger': 0.09024217,
#     'contempt': 0.004527302,
#     'disgust': 0.0370436832,
#     'fear': 0.000174811488,
#     'happiness': 0.0005220709,
#     'neutral': 0.8414075,
#     'sadness': 0.00843150448,
#     'surprise': 0.017651001}}],
#  1145: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '89d2e7c3-c8df-4ad5-9b5e-7cbdca8689f3',
#    'faceRectangle': {'height': 76, 'left': 276, 'top': 97, 'width': 76},
#    'scores': {'anger': 0.0353182442,
#     'contempt': 0.00480141444,
#     'disgust': 0.01560727,
#     'fear': 0.0002725429,
#     'happiness': 6.77344942e-05,
#     'neutral': 0.7973421,
#     'sadness': 0.145032823,
#     'surprise': 0.001557831}}],
#  1146: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '1b3920b6-102a-42da-9b5a-8dc074b05090',
#    'faceRectangle': {'height': 79, 'left': 275, 'top': 92, 'width': 79},
#    'scores': {'anger': 0.214302987,
#     'contempt': 0.0123895286,
#     'disgust': 0.05876826,
#     'fear': 0.00208155345,
#     'happiness': 0.000257819571,
#     'neutral': 0.645105541,
#     'sadness': 0.02460282,
#     'surprise': 0.04249146}}],
#  1147: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '9815aba6-4945-4672-94c0-f5081af5776f',
#    'faceRectangle': {'height': 79, 'left': 273, 'top': 92, 'width': 79},
#    'scores': {'anger': 0.03373131,
#     'contempt': 0.00604085438,
#     'disgust': 0.00566732371,
#     'fear': 3.68359033e-05,
#     'happiness': 0.000167874983,
#     'neutral': 0.94190985,
#     'sadness': 0.0101997526,
#     'surprise': 0.00224618521}}],
#  1148: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '273c042c-b4e0-4d87-810a-f3cfb1bbb956',
#    'faceRectangle': {'height': 80, 'left': 270, 'top': 91, 'width': 80},
#    'scores': {'anger': 0.157917932,
#     'contempt': 0.00498905824,
#     'disgust': 0.04491656,
#     'fear': 0.000167946433,
#     'happiness': 0.0005112251,
#     'neutral': 0.7347078,
#     'sadness': 0.004930732,
#     'surprise': 0.0518587828}}],
#  1149: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '25d8a232-1333-4ca7-8a17-135514b7f7f7',
#    'faceRectangle': {'height': 77, 'left': 270, 'top': 92, 'width': 77},
#    'scores': {'anger': 0.0763425753,
#     'contempt': 0.0170153826,
#     'disgust': 0.0899324,
#     'fear': 0.00821478851,
#     'happiness': 0.000286678056,
#     'neutral': 0.593796134,
#     'sadness': 0.193341881,
#     'surprise': 0.0210701469}}],
#  1150: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '2386b817-b54e-4248-abae-5fd148934346',
#    'faceRectangle': {'height': 78, 'left': 272, 'top': 91, 'width': 78},
#    'scores': {'anger': 0.05351032,
#     'contempt': 0.00585302245,
#     'disgust': 0.0131698279,
#     'fear': 2.95675673e-05,
#     'happiness': 2.19818048e-05,
#     'neutral': 0.8955983,
#     'sadness': 0.0312597752,
#     'surprise': 0.000557235442}}],
#  1151: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '4d352ba2-21b2-49da-87bb-a47fc3492b17',
#    'faceRectangle': {'height': 72, 'left': 281, 'top': 111, 'width': 72},
#    'scores': {'anger': 0.00459293136,
#     'contempt': 0.00217844988,
#     'disgust': 0.000258095417,
#     'fear': 9.54613e-06,
#     'happiness': 0.000156343754,
#     'neutral': 0.974626958,
#     'sadness': 0.018058924,
#     'surprise': 0.00011876777}}],
#  1152: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '20c1bf60-13c7-427e-9baf-de60d29aa26f',
#    'faceRectangle': {'height': 78, 'left': 290, 'top': 89, 'width': 78},
#    'scores': {'anger': 0.03794735,
#     'contempt': 0.00146581267,
#     'disgust': 0.000105491912,
#     'fear': 2.15701633e-07,
#     'happiness': 5.945691e-07,
#     'neutral': 0.9567118,
#     'sadness': 0.00376417534,
#     'surprise': 4.52542e-06}}],
#  1153: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '8b90f827-83e0-4bd6-bdfe-10a3d1841c12',
#    'faceRectangle': {'height': 76, 'left': 254, 'top': 103, 'width': 76},
#    'scores': {'anger': 0.008981701,
#     'contempt': 0.000423894,
#     'disgust': 0.000104031977,
#     'fear': 1.01898259e-08,
#     'happiness': 2.19108273e-07,
#     'neutral': 0.8165299,
#     'sadness': 0.173960045,
#     'surprise': 1.57414931e-07}}],
#  1154: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'ce55cdde-91ae-44e3-a244-fb3b982cd3fa',
#    'faceRectangle': {'height': 73, 'left': 242, 'top': 106, 'width': 73},
#    'scores': {'anger': 0.00236292,
#     'contempt': 0.000271461875,
#     'disgust': 0.000222908231,
#     'fear': 8.01826957e-07,
#     'happiness': 6.83523876e-06,
#     'neutral': 0.8732135,
#     'sadness': 0.12388286,
#     'surprise': 3.86891224e-05}}],
#  1155: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '58000942-5908-42a5-981b-54e1217973fb',
#    'faceRectangle': {'height': 74, 'left': 242, 'top': 115, 'width': 74},
#    'scores': {'anger': 0.0289968476,
#     'contempt': 0.0007342407,
#     'disgust': 0.000381812279,
#     'fear': 8.93126e-07,
#     'happiness': 4.906519e-06,
#     'neutral': 0.8877644,
#     'sadness': 0.0821067,
#     'surprise': 1.02080958e-05}}],
#  1156: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '89c5b3c4-b3e9-4476-9fc0-9a7ff845bdb9',
#    'faceRectangle': {'height': 78, 'left': 279, 'top': 78, 'width': 78},
#    'scores': {'anger': 0.0003194389,
#     'contempt': 0.000126015817,
#     'disgust': 7.551861e-06,
#     'fear': 1.70657479e-08,
#     'happiness': 8.954886e-08,
#     'neutral': 0.997544348,
#     'sadness': 0.00200145552,
#     'surprise': 1.076386e-06}}],
#  1176: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'a1b4b577-8b6e-42ae-8b30-8fbd2d774471',
#    'faceRectangle': {'height': 77, 'left': 276, 'top': 75, 'width': 77},
#    'scores': {'anger': 0.142299324,
#     'contempt': 0.00224092533,
#     'disgust': 0.070417814,
#     'fear': 0.0003044255,
#     'happiness': 0.00016958348,
#     'neutral': 0.6991618,
#     'sadness': 0.0166499428,
#     'surprise': 0.0687561557}}],
#  1177: [{'faceAttributes': {'gender': 'male'},
#    'faceId': 'fa488b8b-6c91-4971-81e9-83596b21ad95',
#    'faceRectangle': {'height': 77, 'left': 279, 'top': 78, 'width': 77},
#    'scores': {'anger': 0.0676107556,
#     'contempt': 0.00190814864,
#     'disgust': 0.0401669964,
#     'fear': 0.000167273844,
#     'happiness': 6.6550645e-05,
#     'neutral': 0.8124421,
#     'sadness': 0.009065478,
#     'surprise': 0.0685726553}}],
#  1178: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '6f07ceb4-a004-4e09-bc5a-c2de34e03f2e',
#    'faceRectangle': {'height': 77, 'left': 280, 'top': 76, 'width': 77},
#    'scores': {'anger': 0.109655634,
#     'contempt': 0.005549072,
#     'disgust': 0.0520232,
#     'fear': 0.00102321361,
#     'happiness': 0.000183709461,
#     'neutral': 0.7287499,
#     'sadness': 0.0214718953,
#     'surprise': 0.0813434049}}],
#  1179: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '25e84475-d43a-403f-8810-49b4df71b006',
#    'faceRectangle': {'height': 77, 'left': 279, 'top': 80, 'width': 77},
#    'scores': {'anger': 0.132128283,
#     'contempt': 0.004800524,
#     'disgust': 0.06543083,
#     'fear': 0.002812118,
#     'happiness': 4.58869763e-05,
#     'neutral': 0.6314402,
#     'sadness': 0.0508903675,
#     'surprise': 0.11245174}}],
#  1180: [{'faceAttributes': {'gender': 'male'},
#    'faceId': '361dc5c9-a767-4a7a-bbd8-a7de59e41ca3',
#    'faceRectangle': {'height': 77, 'left': 281, 'top': 80, 'width': 77},
#    'scores': {'anger': 0.199696451,
#     'contempt': 0.0134062115,
#     'disgust': 0.0395349041,
#     'fear': 0.000221860813,
#     'happiness': 0.000371872,
#     'neutral': 0.713845849,
#     'sadness': 0.0269105248,
#     'surprise': 0.006012308}}],
#  ...}
# time: 616 ms

# %%
# Save the result as Json
#### ATTNTION ----- update '1_23_17.json' to the name of your current folder #######

import json
with open('/Users/Amiros/GitHub/100_days_of_spice/json/3_22_17.json', 'w') as fp:
    json.dump(face_detection, fp, sort_keys=True)
# Out:
# time: 285 ms

# %% [markdown]
# ## json to csv

# %%
import json
import csv
# Out:
# time: 1.61 ms

# %%
"""
This can probably be improved but serves the purpose of our analysis.
I used Chris's schema so it will be useful for Quarz analysis.

"""

EMOTIONS = [
    'contempt',
    'fear',
    'sadness',
    'disgust',
    'anger',
    'neutral',
    'happiness',
    'surprise',
]


CSV_COLUMNS = [
    'url',
    'frame_time',
    'sean_happiness',
    'sean_neutral',
    'sean_anger',
    'sean_contempt',
    'sean_suprise',
    'sean_sadness',
    'sean_fear'
]
# Out:
# time: 6.51 ms

# %%
with open('/Users/Amiros/GitHub/100_days_of_spice/json/3_22_17.json') as data_file:    
    json_data = json.load(data_file)
    
json_data = {int(k):v for k,v in json_data.items()} #converting keys to integer   
frame_keys = sorted(json_data.keys())
# Out:
# time: 49.1 ms

# %%
csv_data = []
   
for key in frame_keys:
    url = 'https://s3.amazonaws.com/100daysofspice/3_22_17/3_22_17___%d.jpg' % key
    frame = json_data[key]
        
    row = {
        #'frame': frame,
        'url': url,
        'frame_time': key,
    }
    
    if len(frame) > 1:
        for face in frame:
            if face['faceAttributes']['gender'] == 'male':
                prefix = 'sean_'
                try:
                    for emotion in EMOTIONS:
                        row[prefix + emotion] = face['scores'][emotion]
                except:
                    pass
                
            row.pop("frame", None)        
      
    elif len(frame) == 1:
        for face in frame:
            if face['faceAttributes']['gender'] == 'male':
                prefix = 'sean_'
                try:
                    for emotion in EMOTIONS:
                    #print(face['scores'][emotion])
                        row[prefix + emotion] = face['scores'][emotion]
                except:
                    pass
                ### assign emotions vale to each candidate and change the name to the respective one 
          
        row.pop("frame", None)        

    csv_data.append(row)
# Out:
# time: 56.7 ms

# %%
import pandas as pd
df = pd.DataFrame(csv_data)
# Out:
# time: 22.1 ms

# %%
####### change the date here
df['data'] = '3_22_17'
df
# Out:
#       frame_time  sean_anger  sean_contempt  sean_disgust     sean_fear  \
# 0              0    0.001971       0.000020      0.000072  4.600886e-07
# 1              1    0.002132       0.000049      0.000053  1.106104e-07
# 2              2    0.006028       0.000347      0.000146  1.949877e-07
# 3              3    0.012348       0.000360      0.001639  4.256240e-05
# 4              4    0.008697       0.001092      0.001856  6.629707e-06
# 5              5    0.027792       0.001955      0.001930  4.937068e-06
# 6              6    0.269748       0.000919      0.032073  1.116195e-04
# 7              7    0.001417       0.000036      0.000392  9.591283e-07
# 8              8    0.398214       0.027677      0.031652  2.975079e-03
# 9              9    0.044940       0.000759      0.007355  1.926933e-04
# 10            10    0.001836       0.000029      0.000132  2.157805e-07
# 11            11    0.004206       0.000197      0.000946  2.030605e-06
# 12            12    0.204429       0.003538      0.036929  7.093961e-04
# 13            13    0.087371       0.003186      0.015015  4.711084e-04
# 14            14    0.005140       0.000277      0.000064  1.642315e-07
# 15            15    0.012453       0.000509      0.000987  3.649977e-06
# 16            16    0.006086       0.000416      0.003218  4.269221e-05
# 17            17    0.018582       0.000386      0.006343  1.091614e-04
# 18            18    0.033057       0.000326      0.005375  6.021237e-05
# 19            19    0.092852       0.005568      0.034066  2.075214e-04
# 20            20    0.204445       0.003970      0.042008  1.108200e-03
# 21            21    0.001706       0.000018      0.000041  1.279875e-08
# 22            22    0.022602       0.000295      0.001215  2.011550e-05
# 23            23    0.010858       0.000088      0.000696  3.753768e-07
# 24            24    0.006477       0.000059      0.000808  6.812829e-06
# 25            25    0.020334       0.000248      0.001507  7.795873e-06
# 26            26    0.111441       0.007870      0.006809  1.736682e-05
# 27            27    0.234529       0.002555      0.048895  3.211810e-03
# 28            28    0.003037       0.000089      0.000597  2.515575e-06
# 29            29    0.006375       0.000120      0.000365  6.748928e-07
# ...          ...         ...            ...           ...           ...
# 2666        3514    0.143062       0.029278      0.116432  6.364648e-04
# 2667        3515    0.443661       0.004765      0.052364  2.472961e-04
# 2668        3516    0.244819       0.005014      0.085649  8.643213e-04
# 2669        3517    0.511394       0.005811      0.130200  2.301044e-03
# 2670        3518    0.156952       0.006532      0.056434  1.278658e-03
# 2671        3519    0.222530       0.010631      0.063773  1.043854e-03
# 2672        3520    0.151042       0.007755      0.068114  7.501292e-04
# 2673        3521    0.182428       0.013012      0.052805  3.070445e-04
# 2674        3522    0.377258       0.005491      0.075881  1.689041e-04
# 2675        3523    0.001326       0.016409      0.001670  8.288437e-07
# 2676        3524    0.001503       0.007381      0.010589  1.333448e-05
# 2677        3525    0.000025       0.287787      0.000354  6.080883e-08
# 2678        3526    0.000107       0.266856      0.000531  4.593333e-07
# 2679        3527    0.004252       0.004628      0.009916  2.186934e-04
# 2680        3528    0.001728       0.011385      0.004006  5.904546e-06
# 2681        3529    0.111561       0.009784      0.046835  3.859742e-04
# 2682        3530    0.003359       0.004310      0.007094  3.126276e-06
# 2683        3531    0.002456       0.003037      0.000547  6.771320e-06
# 2684        3532    0.052835       0.011045      0.036791  1.812623e-04
# 2685        3533    0.014442       0.006384      0.011120  1.557360e-04
# 2686        3534    0.047262       0.005870      0.031709  2.116668e-04
# 2687        3535    0.228870       0.008967      0.057127  5.271816e-04
# 2688        3536    0.632538       0.000772      0.023040  2.286863e-05
# 2689        3537    0.045500       0.015560      0.028141  1.639694e-04
# 2690        3538    0.049885       0.039705      0.024233  6.259769e-05
# 2691        3539    0.038677       0.004556      0.005207  1.049159e-05
# 2692        3540    0.125039       0.004474      0.050779  4.913762e-04
# 2693        3541    0.040274       0.003690      0.017834  1.971793e-05
# 2694        3542    0.032639       0.004267      0.007349  3.194846e-05
# 2695        3543    0.059377       0.011677      0.036032  1.677865e-03
#
#       sean_happiness  sean_neutral  sean_sadness  sean_surprise  \
# 0       8.646268e-06      0.858477      0.139444   6.350939e-06
# 1       4.388861e-06      0.766861      0.230899   1.298808e-06
# 2       4.907269e-06      0.659116      0.334358   7.423890e-07
# 3       3.797583e-05      0.771054      0.214239   2.785971e-04
# 4       8.013798e-05      0.731819      0.256413   3.454451e-05
# 5       3.020272e-06      0.798141      0.170121   5.392370e-05
# 6       2.599707e-05      0.556938      0.002047   1.381371e-01
# 7       4.831494e-06      0.819688      0.178451   1.055748e-05
# 8       1.755720e-04      0.493176      0.010695   3.543703e-02
# 9       7.369330e-06      0.691186      0.254251   1.308782e-03
# 10      3.276945e-07      0.769768      0.228231   3.241500e-06
# 11      5.707348e-06      0.776498      0.218116   2.873429e-05
# 12      2.315925e-05      0.623336      0.002729   1.283063e-01
# 13      6.443339e-05      0.852972      0.010568   3.035237e-02
# 14      4.281520e-06      0.836789      0.157725   1.495728e-06
# 15      1.790697e-06      0.449463      0.536574   8.298849e-06
# 16      5.105585e-05      0.697657      0.292197   3.323815e-04
# 17      3.114904e-05      0.762573      0.210718   1.257577e-03
# 18      1.482258e-06      0.853045      0.103518   4.617546e-03
# 19      2.088389e-04      0.819004      0.006635   4.145841e-02
# 20      7.905924e-05      0.659804      0.011402   7.718459e-02
# 21      3.764909e-07      0.687277      0.310957   1.415095e-07
# 22      2.117692e-06      0.665141      0.310658   6.704686e-05
# 23      2.046529e-07      0.449791      0.538565   1.866763e-06
# 24      2.884128e-06      0.771783      0.220799   6.334061e-05
# 25      1.173901e-05      0.840219      0.137559   1.132316e-04
# 26      4.005596e-05      0.868243      0.003998   1.582107e-03
# 27      6.005337e-06      0.512172      0.011802   1.868290e-01
# 28      5.245329e-06      0.684193      0.312054   2.193811e-05
# 29      1.349426e-06      0.659930      0.333202   5.566321e-06
# ...              ...           ...           ...            ...
# 2666    2.134380e-04      0.574212      0.013398   1.227678e-01
# 2667    1.340114e-04      0.435348      0.002336   6.114524e-02
# 2668    2.461030e-05      0.490141      0.013502   1.599866e-01
# 2669    3.019534e-05      0.295406      0.037468   1.739030e-02
# 2670    2.375118e-05      0.689429      0.037627   5.172383e-02
# 2671    2.204141e-05      0.613112      0.029849   5.904033e-02
# 2672    2.864133e-04      0.603730      0.012059   1.562642e-01
# 2673    9.382959e-05      0.713378      0.019094   1.888118e-02
# 2674    5.670295e-03      0.442823      0.004191   8.851691e-02
# 2675    5.087363e-01      0.471127      0.000161   5.690595e-04
# 2676    8.327709e-01      0.135116      0.011536   1.090707e-03
# 2677    6.961082e-01      0.015485      0.000031   2.101355e-04
# 2678    6.356496e-01      0.096109      0.000091   6.555580e-04
# 2679    1.567502e-02      0.935478      0.013845   1.598716e-02
# 2680    6.052269e-02      0.918231      0.000836   3.284910e-03
# 2681    2.591496e-02      0.448161      0.006731   3.506270e-01
# 2682    3.489608e-01      0.582834      0.000210   5.322928e-02
# 2683    1.229137e-04      0.992023      0.001018   7.882688e-04
# 2684    1.369124e-02      0.848936      0.004187   3.233323e-02
# 2685    4.090468e-03      0.938922      0.008286   1.659969e-02
# 2686    2.067684e-03      0.858167      0.007974   4.673806e-02
# 2687    3.079250e-03      0.625954      0.007331   6.814467e-02
# 2688    3.656337e-04      0.241850      0.000160   1.012505e-01
# 2689    1.299161e-03      0.883059      0.005697   2.058046e-02
# 2690    2.584636e-03      0.870437      0.010151   2.940175e-03
# 2691    1.475370e-04      0.948555      0.000953   1.894858e-03
# 2692    1.178987e-04      0.765666      0.013010   4.042181e-02
# 2693    1.940345e-03      0.881234      0.000635   5.437388e-02
# 2694    1.142792e-04      0.946299      0.007825   1.473858e-03
# 2695    8.762303e-04      0.820325      0.037526   3.250938e-02
#
#                                                     url     data
# 0     https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 1     https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2     https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 3     https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 4     https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 5     https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 6     https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 7     https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 8     https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 9     https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 10    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 11    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 12    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 13    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 14    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 15    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 16    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 17    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 18    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 19    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 20    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 21    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 22    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 23    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 24    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 25    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 26    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 27    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 28    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 29    https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# ...                                                 ...      ...
# 2666  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2667  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2668  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2669  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2670  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2671  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2672  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2673  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2674  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2675  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2676  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2677  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2678  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2679  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2680  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2681  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2682  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2683  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2684  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2685  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2686  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2687  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2688  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2689  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2690  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2691  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2692  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2693  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2694  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
# 2695  https://s3.amazonaws.com/100daysofspice/3_22_1...  3_22_17
#
# [2696 rows x 11 columns]
# time: 64.7 ms

# %%
#### change the name here
df.to_csv('csv/3_22_17-EMOTIONS.csv', sep=',', index=False)
# Out:
# time: 84.4 ms
